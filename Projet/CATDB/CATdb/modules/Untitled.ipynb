# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
from django.db import models
# Create your models here.
import psycopg2
#from config import config
from django.test.html import Element
import os
import bs4, sys
from urllib.request import urlopen
from bs4 import BeautifulSoup
sys.path.insert(0, "../")

link_experiment="http://urgv.evry.inra.fr/cgi-bin/projects/CATdb/consult_expce.pl?experiment_id="
from configparser import ConfigParser

def config(section='postgresql'):
    #os.getcwd()
    direction='/export/home/gnet/btraore/WWW_DEV/cgi-bin/projects/CATDB/CATdb'
    if os.getcwd()[0:12]!="/home/traore":
    	filename=direction+'/database.ini'
    else:
    	filename=direction+'/database2.ini'
    # create a parser
    parser = ConfigParser()
    # read config file
    parser.read(filename)
    # get section, default to postgresql
    db = {}
    if parser.has_section(section):
        params = parser.items(section)
        for param in params:
            db[param[0]] = param[1]
    else:
        raise Exception('Section {0} not found in the {1} file'.format(section, filename))
 
    return db


def connect():
    """ Connect to the PostgreSQL database server """
    conn = None
    try:
        # read connection parameters
        params = config()
        # connect to the PostgreSQL server
        print('Connecting to the PostgreSQL database...')
        conn = psycopg2.connect(**params)
        # create a cursor
        cur = conn.cursor()
        # execute a statement
        print('PostgreSQL database version:')
        cur.execute('SELECT version()')
        # display the PostgreSQL database server version
        db_version = cur.fetchone()
        print(db_version)
     # close the communication with the PostgreSQL
        cur.close()
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
    finally:
        if conn is not None:
            conn.close()
            print('Database connection closed.')

def read_data_sql(requete):
    """
    input requete outupt data
    requete='select * from chips.experiment;'
    """
    conn = None
    params = config()
    conn = psycopg2.connect(**params)
    cursor = conn.cursor()#cursor_factory=psycopg2.extras.DictCursor
    cursor.execute(requete)
    colnames = [desc[0] for desc in cursor.description]
    memory = cursor.fetchall()
    conn.close()
    cpt=0
    data=dict()
    for ele in range(len(memory)):
        cpt=cpt+1
        col=[]
        for ele1 in memory[ele]:
            col.append(str(ele1))
        dictionary ={'_key':cpt,"_value":dict(zip(colnames,col))}
        data[cpt]=dictionary     
    return data

# %%
def controleur_existance_old_expermiment(link_experiment,experiment_id):
    """permet de connaitre si le projet est present sur le site actuel"""
    html = urlopen(link_experiment+str(experiment_id)) # Insert your URL to extract
    bsObj = BeautifulSoup(html.read());

    for link in bsObj.find_all("div", {"class": 'titre'}):
        text=link.text.replace(' ','')
    if len(text)==0:
        return False
    else:
        return True

# %%
def project_rna_seq_info(experiment_id):
    response={}
    try:
        requete="select * from chips.experiment,chips.project where project.project_id=experiment.project_id and experiment.experiment_id="+str(experiment_id)+";"
        data=read_data_sql(requete)
        response=data[1]['_value']
        if data[1]['_value']['analysis_type']=='RNA-Seq':
            try:
                requete="SELECT * from chips.rnaseqdata where rnaseqdata.project_id="+data[1]['_value']['project_id']+"and rnaseqdata.experiment_id="+data[1]['_value']['experiment_id']+";" 
                current_data=read_data_sql(requete)
                if len(current_data)==1:
                    for element in current_data[1]['_value'].keys():
                        response[element]=current_data[1]['_value'][element]
            except:
                pass
            try:
                requete="SELECT * from chips.rnaseqlibrary where rnaseqlibrary.project_id="+data[1]['_value']['project_id']+"and rnaseqlibrary.experiment_id="+data[1]['_value']['experiment_id']+";" 
                current_data=read_data_sql(requete)
                if len(current_data)==1:
                    for element in current_data[1]['_value'].keys():
                            response[element]=current_data[1]['_value'][element]    
            except:
                pass
            try:
                requete="SELECT * from chips.sample,chips.sample_source,chips.organism,chips.ecotype where organism.organism_id=sample_source.organism_id and ecotype.ecotype_id=sample_source.ecotype_id and sample.project_id=sample_source.project_id and sample_source.sample_source_id=sample.sample_source_id and sample.experiment_id=sample_source.experiment_id and sample.project_id="+data[1]['_value']['project_id']+" and sample.experiment_id="+data[1]['_value']['experiment_id']+";"
                current_data=read_data_sql(requete)
                response['echantillon_nb']=len(current_data)
                response['echantillon']=current_data
            except:
                pass
            ###for publmed
            try:
                requete="SELECT * from chips.project_Biblio,chips.Biblio_list,chips.project where Biblio_list.pubmed_id=project_Biblio.pubmed_id and project.project_id=project_Biblio.project_id and project.project_id="+data[1]['_value']['project_id']+";"
                current_data=read_data_sql(requete)
                if len(current_data)>1:
                    for element in current_data[1]['_value'].keys():
                        response[element]=current_data[1]['_value'][element]
            except:
                pass
            try:
                ###for contact coordiantor
                requete="SELECT * from chips.project_coordinator,chips.contact,chips.project where contact.contact_id=project_coordinator.contact_id and project.project_id=project_coordinator.project_id and project.project_id="+data[1]['_value']['project_id']+";"

                current_data=read_data_sql(requete)
                if len(current_data)>0:
                    response['coordiantor_nb']=len(current_data)
                    for rk in range(1,len(current_data)+1):
                        for element in current_data[rk]['_value'].keys():
                            response['coordiantor_'+str(rk)+'_'+element]=current_data[rk]['_value'][element]
            except:
                pass
            try:
                requete="SELECT * from chips.project,chips.experiment where project.project_id=experiment.project_id and project.project_id="+data[1]['_value']['project_id']+";"         
                current_data=read_data_sql(requete)
                if len(current_data)>0:
                    response['other_experiment_nb']=len(current_data)-1
                    for rk in range(1,len(current_data)):
                        if current_data[rk]['_value']['experiment_id']!=data[1]['_value']['experiment_id']:
                            for element in current_data[rk]['_value'].keys():
                                response['other_experiment_'+str(rk)+'_'+element]=current_data[rk]['_value'][element]
            except:
                pass
                    
            try:
                #protocol
                requete="SELECT * from chips.protocol where protocol.protocol_id="+response['protocol_id']+";"
                current_data=read_data_sql(requete)
                if len(current_data)>1:
                    for element in current_data[1]['_value'].keys():
                        response[element]=current_data[1]['_value'][element]   
            except:
                pass
            try:
                #labelled_extract
                requete="SELECT * from chips.labelled_extract,chips.experiment where labelled_extract.project_id=experiment.project_id and  labelled_extract.experiment_id=experiment.experiment_id and labelled_extract.project_id="+data[1]['_value']['project_id']+" and experiment.experiment_id="+data[1]['_value']['experiment_id']+";"
                current_data=read_data_sql(requete)
                if len(current_data)>1:
                    for element in current_data[1]['_value'].keys():
                        response[element]=current_data[1]['_value'][element] 
            except:
                pass
            #replicats
            requete="SELECT * from chips.replicats,chips.experiment,chips.project where  replicats.experiment_id=experiment.experiment_id and replicats.project_id=experiment.project_id and project.project_id="+data[1]['_value']['project_id']+" and experiment.experiment_id="+data[1]['_value']['experiment_id']+";"
            
            current_data=read_data_sql(requete)
            response['replicats']=len(current_data)
            for rv in range(1,len(current_data)+1):
                response['replicats_'+str(rv)]=current_data[rv]['_value']
                requete="SELECT * from chips.replicats,chips.diff_Analysis_value where diff_Analysis_value.replicat_id=replicats.replicat_id and replicats.replicat_id="+response['replicats_'+str(rv)]['replicat_id']+";"
                current_data1=read_data_sql(requete)
                if (len(current_data1)>0):
                    response['replicats_'+str(rv)+'diff_Analysis_value']=current_data1
                requete="SELECT * from chips.replicats,chips.stat_diff_Analysis where chips.stat_diff_Analysis.replicat_id=replicats.replicat_id and replicats.replicat_id="+response['replicats_'+str(rv)]['replicat_id']+";"
                current_data2=read_data_sql(requete)
    except:
        print("attention")
        pass
    return response

# %%
experiment_id=591
project_rna_seq_info(experiment_id)#['echantillon_nb']
# Out:
# {'analysis_type': 'RNA-Seq',
#  'array_type': 'Illumina',
#  'bankref_desc': 'Populus trichocarpa',
#  'biological_interest': 'Which genes affect biomass yield in poplar ?',
#  'book_ref': 'C67822p101',
#  'comments': 'None',
#  'coordiantor_1_address': '2, rue gaston cremieux, cp5708, 91057 evry cedex  france',
#  'coordiantor_1_biological_interest': 'Which genes affect biomass yield in poplar ?',
#  'coordiantor_1_comments': 'None',
#  'coordiantor_1_contact_id': '7',
#  'coordiantor_1_email': 'sandrine.balzergue@inra.fr',
#  'coordiantor_1_first_name': 'Sandrine',
#  'coordiantor_1_gem2net_id': 'None',
#  'coordiantor_1_institution': "INRA-CNRS-Evry Val-d'Essonne University",
#  'coordiantor_1_is_public': 'no',
#  'coordiantor_1_laboratory': 'Urgv - plant genomics research unit',
#  'coordiantor_1_last_name': 'Balzergue',
#  'coordiantor_1_phone': '+33 (0) 1 60 87 45 28',
#  'coordiantor_1_project_code': 'None',
#  'coordiantor_1_project_id': '413',
#  'coordiantor_1_project_idname': 'P413',
#  'coordiantor_1_project_name': 'JC2013_SYBIOPOP_2014',
#  'coordiantor_1_public_date': '2018-12-31',
#  'coordiantor_1_source': 'Public Institute',
#  'coordiantor_1_submission_date': '2016-07-20',
#  'coordiantor_1_title': 'Sybiopop: A systems biology approach to improve poplar biorefinery feedstock by deciphering the genetic architecture of lignocellulosic biomass production and quality',
#  'coordiantor_1_user_id': '0',
#  'coordiantor_2_address': 'Vincent segura\ninra, ur0588 amélioration, génétique et physiologie forestières\n2163, avenue de la pomme de pin\ncs 40001 \x96 ardon\n45075 orléans cedex 2\ntel : 02 38 41 78 11\nfax : 02 38 41 78 79\nemail : vincent.segura@orleans.inra.fr',
#  'coordiantor_2_biological_interest': 'Which genes affect biomass yield in poplar ?',
#  'coordiantor_2_comments': 'None',
#  'coordiantor_2_contact_id': '403',
#  'coordiantor_2_email': 'vincent.segura@inra.fr',
#  'coordiantor_2_first_name': 'Vincent ',
#  'coordiantor_2_gem2net_id': 'None',
#  'coordiantor_2_institution': 'Inra',
#  'coordiantor_2_is_public': 'no',
#  'coordiantor_2_laboratory': 'Amélioration, génétique et physiologie forestières',
#  'coordiantor_2_last_name': 'Segura',
#  'coordiantor_2_phone': '02 38 41 78 11',
#  'coordiantor_2_project_code': 'None',
#  'coordiantor_2_project_id': '413',
#  'coordiantor_2_project_idname': 'P413',
#  'coordiantor_2_project_name': 'JC2013_SYBIOPOP_2014',
#  'coordiantor_2_public_date': '2018-12-31',
#  'coordiantor_2_source': 'Public Institute',
#  'coordiantor_2_submission_date': '2016-07-20',
#  'coordiantor_2_title': 'Sybiopop: A systems biology approach to improve poplar biorefinery feedstock by deciphering the genetic architecture of lignocellulosic biomass production and quality',
#  'coordiantor_2_user_id': '0',
#  'coordiantor_nb': 2,
#  'echantillon': {1: {'_key': 1,
#    '_value': {'age_db': '1080.0',
#     'age_unit': 'month',
#     'age_value': '36.0',
#     'book_ref': 'None',
#     'dev_stage': 'None',
#     'ecotype_id': '76',
#     'ecotype_name': 'ramieres population',
#     'experiment_id': '591',
#     'genotype': '1-A26',
#     'growth_conditions': 'Common garden, bloc 2.',
#     'harvest_date': 'None',
#     'harvest_plantnb': 'None',
#     'mutant': 'no',
#     'mutant_loci': 'None',
#     'mutant_type': 'None',
#     'note': 'None',
#     'operator_id': '297',
#     'organ': 'cambium,xylem',
#     'organism_id': '41',
#     'organism_name': 'Populus nigra',
#     'planting_date': '2008-05-30',
#     'project_id': '413',
#     'sample_id': '7017',
#     'sample_idname': 'P413E591SS4893S7017',
#     'sample_name': 'Ramieres_1-A26_2',
#     'sample_source_id': '4893',
#     'sample_source_idname': 'P413E591SS4893',
#     'sample_source_name': 'Ramieres_1-A26_2',
#     'submission_date': '2018-07-03',
#     'user_id': '0'}},
#   2: {'_key': 2,
#    '_value': {'age_db': '1080.0',
#     'age_unit': 'month',
#     'age_value': '36.0',
#     'book_ref': 'None',
#     'dev_stage': 'None',
#     'ecotype_id': '76',
#     'ecotype_name': 'ramieres population',
#     'experiment_id': '591',
#     'genotype': '1-A26',
#     'growth_conditions': 'Common garden, bloc 4.',
#     'harvest_date': 'None',
#     'harvest_plantnb': 'None',
#     'mutant': 'no',
#     'mutant_loci': 'None',
#     'mutant_type': 'None',
#     'note': 'None',
#     'operator_id': '297',
#     'organ': 'cambium,xylem',
#     'organism_id': '41',
#     'organism_name': 'Populus nigra',
#     'planting_date': '2008-05-30',
#     'project_id': '413',
#     'sample_id': '7018',
#     'sample_idname': 'P413E591SS4894S7018',
#     'sample_name': 'Ramieres_1-A26_4',
#     'sample_source_id': '4894',
#     'sample_source_idname': 'P413E591SS4894',
#     'sample_source_name': 'Ramieres_1-A26_4',
#     'submission_date': '2018-07-03',
#     'user_id': '0'}},
#   3: {'_key': 3,
#    '_value': {'age_db': '1080.0',
#     'age_unit': 'month',
#     'age_value': '36.0',
#     'book_ref': 'None',
#     'dev_stage': 'None',
#     'ecotype_id': '76',
#     'ecotype_name': 'ramieres population',
#     'experiment_id': '591',
#     'genotype': '1-J31',
#     'growth_conditions': 'Common garden, bloc 2.',
#     'harvest_date': 'None',
#     'harvest_plantnb': 'None',
#     'mutant': 'no',
#     'mutant_loci': 'None',
#     'mutant_type': 'None',
#     'note': 'None',
#     'operator_id': '297',
#     'organ': 'cambium,xylem',
#     'organism_id': '41',
#     'organism_name': 'Populus nigra',
#     'planting_date': '2008-05-30',
#     'project_id': '413',
#     'sample_id': '7020',
#     'sample_idname': 'P413E591SS4896S7020',
#     'sample_name': 'Ramieres_1-J31_2',
#     'sample_source_id': '4896',
#     'sample_source_idname': 'P413E591SS4896',
#     'sample_source_name': 'Ramieres_1-J31_2',
#     'submission_date': '2018-07-03',
#     'user_id': '0'}},
#   4: {'_key': 4,
#    '_value': {'age_db': '1080.0',
#     'age_unit': 'month',
#     'age_value': '36.0',
#     'book_ref': 'None',
#     'dev_stage': 'None',
#     'ecotype_id': '76',
#     'ecotype_name': 'ramieres population',
#     'experiment_id': '591',
#     'genotype': '1-J31',
#     'growth_conditions': 'Common garden, bloc 4.',
#     'harvest_date': 'None',
#     'harvest_plantnb': 'None',
#     'mutant': 'no',
#     'mutant_loci': 'None',
#     'mutant_type': 'None',
#     'note': 'None',
#     'operator_id': '297',
#     'organ': 'cambium,xylem',
#     'organism_id': '41',
#     'organism_name': 'Populus nigra',
#     'planting_date': '2008-05-30',
#     'project_id': '413',
#     'sample_id': '7019',
#     'sample_idname': 'P413E591SS4895S7019',
#     'sample_name': 'Ramieres_1-J31_4',
#     'sample_source_id': '4895',
#     'sample_source_idname': 'P413E591SS4895',
#     'sample_source_name': 'Ramieres_1-J31_4',
#     'submission_date': '2018-07-03',
#     'user_id': '0'}},
#   5: {'_key': 5,
#    '_value': {'age_db': '1080.0',
#     'age_unit': 'month',
#     'age_value': '36.0',
#     'book_ref': 'None',
#     'dev_stage': 'None',
#     'ecotype_id': '78',
#     'ecotype_name': 'ticino population',
#     'experiment_id': '591',
#     'genotype': 'SN-2',
#     'growth_conditions': 'Common garden, bloc 2.',
#     'harvest_date': 'None',
#     'harvest_plantnb': 'None',
#     'mutant': 'no',
#     'mutant_loci': 'None',
#     'mutant_type': 'None',
#     'note': 'None',
#     'operator_id': '297',
#     'organ': 'cambium,xylem',
#     'organism_id': '41',
#     'organism_name': 'Populus nigra',
#     'planting_date': '2008-05-30',
#     'project_id': '413',
#     'sample_id': '7025',
#     'sample_idname': 'P413E591SS4901S7025',
#     'sample_name': 'Ticino_SN-2_2',
#     'sample_source_id': '4901',
#     'sample_source_idname': 'P413E591SS4901',
#     'sample_source_name': 'Ticino_SN-2_2',
#     'submission_date': '2018-07-03',
#     'user_id': '0'}},
#   6: {'_key': 6,
#    '_value': {'age_db': '1080.0',
#     'age_unit': 'month',
#     'age_value': '36.0',
#     'book_ref': 'None',
#     'dev_stage': 'None',
#     'ecotype_id': '78',
#     'ecotype_name': 'ticino population',
#     'experiment_id': '591',
#     'genotype': 'SN-2',
#     'growth_conditions': 'Common garden, bloc 4.',
#     'harvest_date': 'None',
#     'harvest_plantnb': 'None',
#     'mutant': 'no',
#     'mutant_loci': 'None',
#     'mutant_type': 'None',
#     'note': 'None',
#     'operator_id': '297',
#     'organ': 'cambium,xylem',
#     'organism_id': '41',
#     'organism_name': 'Populus nigra',
#     'planting_date': '2008-05-30',
#     'project_id': '413',
#     'sample_id': '7026',
#     'sample_idname': 'P413E591SS4902S7026',
#     'sample_name': 'Ticino_SN-2_4',
#     'sample_source_id': '4902',
#     'sample_source_idname': 'P413E591SS4902',
#     'sample_source_name': 'Ticino_SN-2_4',
#     'submission_date': '2018-07-03',
#     'user_id': '0'}},
#   7: {'_key': 7,
#    '_value': {'age_db': '1080.0',
#     'age_unit': 'month',
#     'age_value': '36.0',
#     'book_ref': 'None',
#     'dev_stage': 'None',
#     'ecotype_id': '78',
#     'ecotype_name': 'ticino population',
#     'experiment_id': '591',
#     'genotype': 'SN-7',
#     'growth_conditions': 'Common garden, bloc 2.',
#     'harvest_date': 'None',
#     'harvest_plantnb': 'None',
#     'mutant': 'no',
#     'mutant_loci': 'None',
#     'mutant_type': 'None',
#     'note': 'None',
#     'operator_id': '297',
#     'organ': 'cambium,xylem',
#     'organism_id': '41',
#     'organism_name': 'Populus nigra',
#     'planting_date': '2008-05-30',
#     'project_id': '413',
#     'sample_id': '7028',
#     'sample_idname': 'P413E591SS4904S7028',
#     'sample_name': 'Ticino_SN-7_2',
#     'sample_source_id': '4904',
#     'sample_source_idname': 'P413E591SS4904',
#     'sample_source_name': 'Ticino_SN-7_2',
#     'submission_date': '2018-07-03',
#     'user_id': '0'}},
#   8: {'_key': 8,
#    '_value': {'age_db': '1080.0',
#     'age_unit': 'month',
#     'age_value': '36.0',
#     'book_ref': 'None',
#     'dev_stage': 'None',
#     'ecotype_id': '78',
#     'ecotype_name': 'ticino population',
#     'experiment_id': '591',
#     'genotype': 'SN-7',
#     'growth_conditions': 'Common garden, bloc 4.',
#     'harvest_date': 'None',
#     'harvest_plantnb': 'None',
#     'mutant': 'no',
#     'mutant_loci': 'None',
#     'mutant_type': 'None',
#     'note': 'None',
#     'operator_id': '297',
#     'organ': 'cambium,xylem',
#     'organism_id': '41',
#     'organism_name': 'Populus nigra',
#     'planting_date': '2008-05-30',
#     'project_id': '413',
#     'sample_id': '7027',
#     'sample_idname': 'P413E591SS4903S7027',
#     'sample_name': 'Ticino_SN-7_4',
#     'sample_source_id': '4903',
#     'sample_source_idname': 'P413E591SS4903',
#     'sample_source_name': 'Ticino_SN-7_4',
#     'submission_date': '2018-07-03',
#     'user_id': '0'}},
#   9: {'_key': 9,
#    '_value': {'age_db': '1080.0',
#     'age_unit': 'month',
#     'age_value': '36.0',
#     'book_ref': 'None',
#     'dev_stage': 'None',
#     'ecotype_id': '73',
#     'ecotype_name': 'adour population',
#     'experiment_id': '591',
#     'genotype': 'AST-05',
#     'growth_conditions': 'Common garden, bloc 2.',
#     'harvest_date': 'None',
#     'harvest_plantnb': 'None',
#     'mutant': 'no',
#     'mutant_loci': 'None',
#     'mutant_type': 'None',
#     'note': 'None',
#     'operator_id': '297',
#     'organ': 'cambium,xylem',
#     'organism_id': '41',
#     'organism_name': 'Populus nigra',
#     'planting_date': '2008-05-30',
#     'project_id': '413',
#     'sample_id': '7005',
#     'sample_idname': 'P413E591SS4881S7005',
#     'sample_name': 'Adour_AST-005_2',
#     'sample_source_id': '4881',
#     'sample_source_idname': 'P413E591SS4881',
#     'sample_source_name': 'Adour_AST-005_2',
#     'submission_date': '2018-07-17',
#     'user_id': '0'}},
#   10: {'_key': 10,
#    '_value': {'age_db': '1080.0',
#     'age_unit': 'month',
#     'age_value': '36.0',
#     'book_ref': 'None',
#     'dev_stage': 'None',
#     'ecotype_id': '73',
#     'ecotype_name': 'adour population',
#     'experiment_id': '591',
#     'genotype': 'AST-05',
#     'growth_conditions': 'Common garden, bloc 4.',
#     'harvest_date': 'None',
#     'harvest_plantnb': 'None',
#     'mutant': 'no',
#     'mutant_loci': 'None',
#     'mutant_type': 'None',
#     'note': 'None',
#     'operator_id': '297',
#     'organ': 'cambium,xylem',
#     'organism_id': '41',
#     'organism_name': 'Populus nigra',
#     'planting_date': '2008-05-30',
#     'project_id': '413',
#     'sample_id': '7006',
#     'sample_idname': 'P413E591SS4882S7006',
#     'sample_name': 'Adour_AST-005_4',
#     'sample_source_id': '4882',
#     'sample_source_idname': 'P413E591SS4882',
#     'sample_source_name': 'Adour_AST-005_4',
#     'submission_date': '2018-07-17',
#     'user_id': '0'}},
#   11: {'_key': 11,
#    '_value': {'age_db': '1080.0',
#     'age_unit': 'month',
#     'age_value': '36.0',
#     'book_ref': 'None',
#     'dev_stage': 'None',
#     'ecotype_id': '73',
#     'ecotype_name': 'adour population',
#     'experiment_id': '591',
#     'genotype': 'BDX-03',
#     'growth_conditions': 'Common garden, bloc 2.',
#     'harvest_date': 'None',
#     'harvest_plantnb': 'None',
#     'mutant': 'no',
#     'mutant_loci': 'None',
#     'mutant_type': 'None',
#     'note': 'None',
#     'operator_id': '297',
#     'organ': 'cambium,xylem',
#     'organism_id': '41',
#     'organism_name': 'Populus nigra',
#     'planting_date': '2008-05-30',
#     'project_id': '413',
#     'sample_id': '7008',
#     'sample_idname': 'P413E591SS4883S7008',
#     'sample_name': 'Adour_BDX-003_2',
#     'sample_source_id': '4883',
#     'sample_source_idname': 'P413E591SS4883',
#     'sample_source_name': 'Adour_BDX-003_2',
#     'submission_date': '2018-07-17',
#     'user_id': '0'}},
#   12: {'_key': 12,
#    '_value': {'age_db': '1080.0',
#     'age_unit': 'month',
#     'age_value': '36.0',
#     'book_ref': 'None',
#     'dev_stage': 'None',
#     'ecotype_id': '73',
#     'ecotype_name': 'adour population',
#     'experiment_id': '591',
#     'genotype': 'BDX-03',
#     'growth_conditions': 'Common garden, bloc 4.',
#     'harvest_date': 'None',
#     'harvest_plantnb': 'None',
#     'mutant': 'no',
#     'mutant_loci': 'None',
#     'mutant_type': 'None',
#     'note': 'None',
#     'operator_id': '297',
#     'organ': 'cambium,xylem',
#     'organism_id': '41',
#     'organism_name': 'Populus nigra',
#     'planting_date': '2008-05-30',
#     'project_id': '413',
#     'sample_id': '7007',
#     'sample_idname': 'P413E591SS4884S7007',
#     'sample_name': 'Adour_BDX-003_4',
#     'sample_source_id': '4884',
#     'sample_source_idname': 'P413E591SS4884',
#     'sample_source_name': 'Adour_BDX-003_4',
#     'submission_date': '2018-07-17',
#     'user_id': '0'}},
#   13: {'_key': 13,
#    '_value': {'age_db': '1080.0',
#     'age_unit': 'month',
#     'age_value': '36.0',
#     'book_ref': 'None',
#     'dev_stage': 'None',
#     'ecotype_id': '74',
#     'ecotype_name': 'dranse population',
#     'experiment_id': '591',
#     'genotype': 'DRA-38',
#     'growth_conditions': 'Common garden, bloc 2.',
#     'harvest_date': 'None',
#     'harvest_plantnb': 'None',
#     'mutant': 'no',
#     'mutant_loci': 'None',
#     'mutant_type': 'None',
#     'note': 'None',
#     'operator_id': '297',
#     'organ': 'cambium,xylem',
#     'organism_id': '41',
#     'organism_name': 'Populus nigra',
#     'planting_date': '2008-05-30',
#     'project_id': '413',
#     'sample_id': '7009',
#     'sample_idname': 'P413E591SS4885S7009',
#     'sample_name': 'Dranse_DRA-038_2',
#     'sample_source_id': '4885',
#     'sample_source_idname': 'P413E591SS4885',
#     'sample_source_name': 'Dranse_DRA-038_2',
#     'submission_date': '2018-07-17',
#     'user_id': '0'}},
#   14: {'_key': 14,
#    '_value': {'age_db': '1080.0',
#     'age_unit': 'month',
#     'age_value': '36.0',
#     'book_ref': 'None',
#     'dev_stage': 'None',
#     'ecotype_id': '74',
#     'ecotype_name': 'dranse population',
#     'experiment_id': '591',
#     'genotype': 'DRA-38',
#     'growth_conditions': 'Common garden, bloc 4.',
#     'harvest_date': 'None',
#     'harvest_plantnb': 'None',
#     'mutant': 'no',
#     'mutant_loci': 'None',
#     'mutant_type': 'None',
#     'note': 'None',
#     'operator_id': '297',
#     'organ': 'cambium,xylem',
#     'organism_id': '41',
#     'organism_name': 'Populus nigra',
#     'planting_date': '2008-05-30',
#     'project_id': '413',
#     'sample_id': '7010',
#     'sample_idname': 'P413E591SS4886S7010',
#     'sample_name': 'Dranse_DRA-038_4',
#     'sample_source_id': '4886',
#     'sample_source_idname': 'P413E591SS4886',
#     'sample_source_name': 'Dranse_DRA-038_4',
#     'submission_date': '2018-07-17',
#     'user_id': '0'}},
#   15: {'_key': 15,
#    '_value': {'age_db': '1080.0',
#     'age_unit': 'month',
#     'age_value': '36.0',
#     'book_ref': 'None',
#     'dev_stage': 'None',
#     'ecotype_id': '74',
#     'ecotype_name': 'dranse population',
#     'experiment_id': '591',
#     'genotype': 'DRA-45',
#     'growth_conditions': 'Common garden, bloc 2.',
#     'harvest_date': 'None',
#     'harvest_plantnb': 'None',
#     'mutant': 'no',
#     'mutant_loci': 'None',
#     'mutant_type': 'None',
#     'note': 'None',
#     'operator_id': '297',
#     'organ': 'cambium,xylem',
#     'organism_id': '41',
#     'organism_name': 'Populus nigra',
#     'planting_date': '2008-05-30',
#     'project_id': '413',
#     'sample_id': '7012',
#     'sample_idname': 'P413E591SS4888S7012',
#     'sample_name': 'Dranse_DRA-045_2',
#     'sample_source_id': '4888',
#     'sample_source_idname': 'P413E591SS4888',
#     'sample_source_name': 'Dranse_DRA-045_2',
#     'submission_date': '2018-07-17',
#     'user_id': '0'}},
#   16: {'_key': 16,
#    '_value': {'age_db': '1080.0',
#     'age_unit': 'month',
#     'age_value': '36.0',
#     'book_ref': 'None',
#     'dev_stage': 'None',
#     'ecotype_id': '74',
#     'ecotype_name': 'dranse population',
#     'experiment_id': '591',
#     'genotype': 'DRA-45',
#     'growth_conditions': 'Common garden, bloc 4.',
#     'harvest_date': 'None',
#     'harvest_plantnb': 'None',
#     'mutant': 'no',
#     'mutant_loci': 'None',
#     'mutant_type': 'None',
#     'note': 'None',
#     'operator_id': '297',
#     'organ': 'cambium,xylem',
#     'organism_id': '41',
#     'organism_name': 'Populus nigra',
#     'planting_date': '2008-05-30',
#     'project_id': '413',
#     'sample_id': '7011',
#     'sample_idname': 'P413E591SS4887S7011',
#     'sample_name': 'Dranse_DRA-045_4',
#     'sample_source_id': '4887',
#     'sample_source_idname': 'P413E591SS4887',
#     'sample_source_name': 'Dranse_DRA-045_4',
#     'submission_date': '2018-07-17',
#     'user_id': '0'}},
#   17: {'_key': 17,
#    '_value': {'age_db': '1080.0',
#     'age_unit': 'month',
#     'age_value': '36.0',
#     'book_ref': 'None',
#     'dev_stage': 'None',
#     'ecotype_id': '75',
#     'ecotype_name': 'loire population',
#     'experiment_id': '591',
#     'genotype': 'LOE-11',
#     'growth_conditions': 'Common garden, bloc 2.',
#     'harvest_date': 'None',
#     'harvest_plantnb': 'None',
#     'mutant': 'no',
#     'mutant_loci': 'None',
#     'mutant_type': 'None',
#     'note': 'None',
#     'operator_id': '297',
#     'organ': 'cambium,xylem',
#     'organism_id': '41',
#     'organism_name': 'Populus nigra',
#     'planting_date': '2008-05-30',
#     'project_id': '413',
#     'sample_id': '7013',
#     'sample_idname': 'P413E591SS4889S7013',
#     'sample_name': 'Loire_LOE-011_2',
#     'sample_source_id': '4889',
#     'sample_source_idname': 'P413E591SS4889',
#     'sample_source_name': 'Loire_LOE-011_2',
#     'submission_date': '2018-07-17',
#     'user_id': '0'}},
#   18: {'_key': 18,
#    '_value': {'age_db': '1080.0',
#     'age_unit': 'month',
#     'age_value': '36.0',
#     'book_ref': 'None',
#     'dev_stage': 'None',
#     'ecotype_id': '75',
#     'ecotype_name': 'loire population',
#     'experiment_id': '591',
#     'genotype': 'LOE-11',
#     'growth_conditions': 'Common garden, bloc 4.',
#     'harvest_date': 'None',
#     'harvest_plantnb': 'None',
#     'mutant': 'no',
#     'mutant_loci': 'None',
#     'mutant_type': 'None',
#     'note': 'None',
#     'operator_id': '297',
#     'organ': 'cambium,xylem',
#     'organism_id': '41',
#     'organism_name': 'Populus nigra',
#     'planting_date': '2008-05-30',
#     'project_id': '413',
#     'sample_id': '7014',
#     'sample_idname': 'P413E591SS4890S7014',
#     'sample_name': 'Loire_LOE-011_4',
#     'sample_source_id': '4890',
#     'sample_source_idname': 'P413E591SS4890',
#     'sample_source_name': 'Loire_LOE-011_4',
#     'submission_date': '2018-07-17',
#     'user_id': '0'}},
#   19: {'_key': 19,
#    '_value': {'age_db': '1080.0',
#     'age_unit': 'month',
#     'age_value': '36.0',
#     'book_ref': 'None',
#     'dev_stage': 'None',
#     'ecotype_id': '75',
#     'ecotype_name': 'loire population',
#     'experiment_id': '591',
#     'genotype': 'VDL-18',
#     'growth_conditions': 'Common garden, bloc 2.',
#     'harvest_date': 'None',
#     'harvest_plantnb': 'None',
#     'mutant': 'no',
#     'mutant_loci': 'None',
#     'mutant_type': 'None',
#     'note': 'None',
#     'operator_id': '297',
#     'organ': 'cambium,xylem',
#     'organism_id': '41',
#     'organism_name': 'Populus nigra',
#     'planting_date': '2008-05-30',
#     'project_id': '413',
#     'sample_id': '7016',
#     'sample_idname': 'P413E591SS4892S7016',
#     'sample_name': 'Loire_VDL-018_2',
#     'sample_source_id': '4892',
#     'sample_source_idname': 'P413E591SS4892',
#     'sample_source_name': 'Loire_VDL-018_2',
#     'submission_date': '2018-07-17',
#     'user_id': '0'}},
#   20: {'_key': 20,
#    '_value': {'age_db': '1080.0',
#     'age_unit': 'month',
#     'age_value': '36.0',
#     'book_ref': 'None',
#     'dev_stage': 'None',
#     'ecotype_id': '75',
#     'ecotype_name': 'loire population',
#     'experiment_id': '591',
#     'genotype': 'VDL-18',
#     'growth_conditions': 'Common garden, bloc 4.',
#     'harvest_date': 'None',
#     'harvest_plantnb': 'None',
#     'mutant': 'no',
#     'mutant_loci': 'None',
#     'mutant_type': 'None',
#     'note': 'None',
#     'operator_id': '297',
#     'organ': 'cambium,xylem',
#     'organism_id': '41',
#     'organism_name': 'Populus nigra',
#     'planting_date': '2008-05-30',
#     'project_id': '413',
#     'sample_id': '7015',
#     'sample_idname': 'P413E591SS4891S7015',
#     'sample_name': 'Loire_VDL-018_4',
#     'sample_source_id': '4891',
#     'sample_source_idname': 'P413E591SS4891',
#     'sample_source_name': 'Loire_VDL-018_4',
#     'submission_date': '2018-07-17',
#     'user_id': '0'}},
#   21: {'_key': 21,
#    '_value': {'age_db': '1080.0',
#     'age_unit': 'month',
#     'age_value': '36.0',
#     'book_ref': 'None',
#     'dev_stage': 'None',
#     'ecotype_id': '77',
#     'ecotype_name': 'rhin population',
#     'experiment_id': '591',
#     'genotype': 'RHN-28',
#     'growth_conditions': 'Common garden, bloc 2.',
#     'harvest_date': 'None',
#     'harvest_plantnb': 'None',
#     'mutant': 'no',
#     'mutant_loci': 'None',
#     'mutant_type': 'None',
#     'note': 'None',
#     'operator_id': '297',
#     'organ': 'cambium,xylem',
#     'organism_id': '41',
#     'organism_name': 'Populus nigra',
#     'planting_date': '2008-05-30',
#     'project_id': '413',
#     'sample_id': '7021',
#     'sample_idname': 'P413E591SS4897S7021',
#     'sample_name': 'Rhin_RHN-028_2',
#     'sample_source_id': '4897',
#     'sample_source_idname': 'P413E591SS4897',
#     'sample_source_name': 'Rhin_RHN-028_2',
#     'submission_date': '2018-07-17',
#     'user_id': '0'}},
#   22: {'_key': 22,
#    '_value': {'age_db': '1080.0',
#     'age_unit': 'month',
#     'age_value': '36.0',
#     'book_ref': 'None',
#     'dev_stage': 'None',
#     'ecotype_id': '77',
#     'ecotype_name': 'rhin population',
#     'experiment_id': '591',
#     'genotype': 'RHN-28',
#     'growth_conditions': 'Common garden, bloc 4.',
#     'harvest_date': 'None',
#     'harvest_plantnb': 'None',
#     'mutant': 'no',
#     'mutant_loci': 'None',
#     'mutant_type': 'None',
#     'note': 'None',
#     'operator_id': '297',
#     'organ': 'cambium,xylem',
#     'organism_id': '41',
#     'organism_name': 'Populus nigra',
#     'planting_date': '2008-05-30',
#     'project_id': '413',
#     'sample_id': '7022',
#     'sample_idname': 'P413E591SS4898S7022',
#     'sample_name': 'Rhin_RHN-028_4',
#     'sample_source_id': '4898',
#     'sample_source_idname': 'P413E591SS4898',
#     'sample_source_name': 'Rhin_RHN-028_4',
#     'submission_date': '2018-07-17',
#     'user_id': '0'}},
#   23: {'_key': 23,
#    '_value': {'age_db': '1080.0',
#     'age_unit': 'month',
#     'age_value': '36.0',
#     'book_ref': 'None',
#     'dev_stage': 'None',
#     'ecotype_id': '77',
#     'ecotype_name': 'rhin population',
#     'experiment_id': '591',
#     'genotype': 'STR-10',
#     'growth_conditions': 'Common garden, bloc 2.',
#     'harvest_date': 'None',
#     'harvest_plantnb': 'None',
#     'mutant': 'no',
#     'mutant_loci': 'None',
#     'mutant_type': 'None',
#     'note': 'None',
#     'operator_id': '297',
#     'organ': 'cambium,xylem',
#     'organism_id': '41',
#     'organism_name': 'Populus nigra',
#     'planting_date': '2008-05-30',
#     'project_id': '413',
#     'sample_id': '7023',
#     'sample_idname': 'P413E591SS4900S7023',
#     'sample_name': 'Rhin_STR-010_2',
#     'sample_source_id': '4900',
#     'sample_source_idname': 'P413E591SS4900',
#     'sample_source_name': 'Rhin_STR-10_2',
#     'submission_date': '2018-07-03',
#     'user_id': '0'}},
#   24: {'_key': 24,
#    '_value': {'age_db': '1080.0',
#     'age_unit': 'month',
#     'age_value': '36.0',
#     'book_ref': 'None',
#     'dev_stage': 'None',
#     'ecotype_id': '77',
#     'ecotype_name': 'rhin population',
#     'experiment_id': '591',
#     'genotype': 'STR-10',
#     'growth_conditions': 'Common garden, bloc 4.',
#     'harvest_date': 'None',
#     'harvest_plantnb': 'None',
#     'mutant': 'no',
#     'mutant_loci': 'None',
#     'mutant_type': 'None',
#     'note': 'None',
#     'operator_id': '297',
#     'organ': 'cambium,xylem',
#     'organism_id': '41',
#     'organism_name': 'Populus nigra',
#     'planting_date': '2008-05-30',
#     'project_id': '413',
#     'sample_id': '7024',
#     'sample_idname': 'P413E591SS4899S7024',
#     'sample_name': 'Rhin_STR-010_4',
#     'sample_source_id': '4899',
#     'sample_source_idname': 'P413E591SS4899',
#     'sample_source_name': 'Rhin_STR-10_4',
#     'submission_date': '2018-07-03',
#     'user_id': '0'}}},
#  'echantillon_nb': 24,
#  'experiment_date': '2014-09-24',
#  'experiment_factors': 'block (2 levels) and population (6 levels)',
#  'experiment_id': '591',
#  'experiment_idname': 'P413E591',
#  'experiment_name': 'Pilot transcriptomic study',
#  'experiment_type': 'genotype and ecotype comparison',
#  'gem2net_id': 'None',
#  'is_public': 'no',
#  'library_strategy': 'RNA-Seq',
#  'log_file': 'JC2013_SYBIOPOP_2014_exp591_MappingCount_24ech_premanip.log',
#  'mapping_type': 'transcriptome',
#  'multihits': 'no',
#  'multiplexing': '8',
#  'note': 'RNA was extracted from young differentiating xylem and cambium collected on 24 4-year-old trees trialed in a common garden experiment at INRA Orléans. The trees corresponded to corresponding to 2 replicates of 12 genotypes from 6 natural populations. After RNA quantification, the RNA from xylem and cambium from the same tree were pooled and subjected to high-throughput sequencing on an Illumina HiSeq 2000 using 100 bp single-read indexing runs. All the samples were sequenced on one Illumina lane, yielding around 20 million of single-reads per sample.',
#  'operator_id': '0',
#  'other_experiment_2_analysis_type': 'RNA-Seq',
#  'other_experiment_2_array_type': 'Illumina',
#  'other_experiment_2_biological_interest': 'Which genes affect biomass yield in poplar ?',
#  'other_experiment_2_comments': 'None',
#  'other_experiment_2_experiment_factors': 'block (2 levels) and population (6 levels)',
#  'other_experiment_2_experiment_id': '623',
#  'other_experiment_2_experiment_idname': 'P413E623',
#  'other_experiment_2_experiment_name': 'Validation of pilot transcriptomic study',
#  'other_experiment_2_experiment_type': 'genotype and ecotype comparison',
#  'other_experiment_2_gem2net_id': 'None',
#  'other_experiment_2_is_public': 'no',
#  'other_experiment_2_note': 'Validation of pilot transcriptomic study',
#  'other_experiment_2_project_code': 'None',
#  'other_experiment_2_project_id': '413',
#  'other_experiment_2_project_idname': 'P413',
#  'other_experiment_2_project_name': 'JC2013_SYBIOPOP_2014',
#  'other_experiment_2_protocol_id': '0',
#  'other_experiment_2_public_date': '2018-12-31',
#  'other_experiment_2_repository_access': 'GSE117347',
#  'other_experiment_2_repository_db': 'GEO',
#  'other_experiment_2_source': 'Public Institute',
#  'other_experiment_2_submission_date': '2018-07-13',
#  'other_experiment_2_title': 'Sybiopop: A systems biology approach to improve poplar biorefinery feedstock by deciphering the genetic architecture of lignocellulosic biomass production and quality',
#  'other_experiment_2_user_id': '0',
#  'other_experiment_nb': 2,
#  'project_code': 'None',
#  'project_file': 'JC2013_SYBIOPOP_2014_exp591.txt',
#  'project_id': '413',
#  'project_idname': 'P413',
#  'project_name': 'JC2013_SYBIOPOP_2014',
#  'protocol_id': '10348',
#  'public_date': '2018-12-31',
#  'replicats': 20,
#  'replicats_1': {'analysis_type': 'RNA-Seq',
#   'array_type': 'Illumina',
#   'biological_interest': 'Which genes affect biomass yield in poplar ?',
#   'comments': 'None',
#   'correlation': 'None',
#   'experiment_factors': 'block (2 levels) and population (6 levels)',
#   'experiment_id': '591',
#   'experiment_idname': 'P413E591',
#   'experiment_name': 'Pilot transcriptomic study',
#   'experiment_type': 'genotype and ecotype comparison',
#   'gem2net_id': 'None',
#   'hyb_cutt_off': 'None',
#   'is_public': 'no',
#   'link_rep': '0',
#   'note': 'RNA was extracted from young differentiating xylem and cambium collected on 24 4-year-old trees trialed in a common garden experiment at INRA Orléans. The trees corresponded to corresponding to 2 replicates of 12 genotypes from 6 natural populations. After RNA quantification, the RNA from xylem and cambium from the same tree were pooled and subjected to high-throughput sequencing on an Illumina HiSeq 2000 using 100 bp single-read indexing runs. All the samples were sequenced on one Illumina lane, yielding around 20 million of single-reads per sample.',
#   'project_code': 'None',
#   'project_id': '413',
#   'project_idname': 'P413',
#   'project_name': 'JC2013_SYBIOPOP_2014',
#   'protocol_id': '0',
#   'public_date': '2018-12-31',
#   'rep_type': 'rep_rnaseq',
#   'replicat_extracts': 'Adour_AST-05_1,Adour_AST-05_2,Adour_AST-05_3,Adour_AST-05_4',
#   'replicat_id': '5625',
#   'replicat_name': 'Adour_AST-05',
#   'repository_access': 'GSE117346',
#   'repository_db': 'GEO',
#   'source': 'Public Institute',
#   'submission_date': '2016-07-20',
#   'title': 'Sybiopop: A systems biology approach to improve poplar biorefinery feedstock by deciphering the genetic architecture of lignocellulosic biomass production and quality',
#   'user_id': '0'},
#  'replicats_10': {'analysis_type': 'RNA-Seq',
#   'array_type': 'Illumina',
#   'biological_interest': 'Which genes affect biomass yield in poplar ?',
#   'comments': 'None',
#   'correlation': 'None',
#   'experiment_factors': 'block (2 levels) and population (6 levels)',
#   'experiment_id': '591',
#   'experiment_idname': 'P413E591',
#   'experiment_name': 'Pilot transcriptomic study',
#   'experiment_type': 'genotype and ecotype comparison',
#   'gem2net_id': 'None',
#   'hyb_cutt_off': 'None',
#   'is_public': 'no',
#   'link_rep': '0',
#   'note': 'RNA was extracted from young differentiating xylem and cambium collected on 24 4-year-old trees trialed in a common garden experiment at INRA Orléans. The trees corresponded to corresponding to 2 replicates of 12 genotypes from 6 natural populations. After RNA quantification, the RNA from xylem and cambium from the same tree were pooled and subjected to high-throughput sequencing on an Illumina HiSeq 2000 using 100 bp single-read indexing runs. All the samples were sequenced on one Illumina lane, yielding around 20 million of single-reads per sample.',
#   'project_code': 'None',
#   'project_id': '413',
#   'project_idname': 'P413',
#   'project_name': 'JC2013_SYBIOPOP_2014',
#   'protocol_id': '0',
#   'public_date': '2018-12-31',
#   'rep_type': 'rep_rnaseq',
#   'replicat_extracts': 'Rhin_STR-10_1,Rhin_STR-10_2,Rhin_STR-10_3,Rhin_STR-10_4',
#   'replicat_id': '5634',
#   'replicat_name': 'Rhin_STR-10',
#   'repository_access': 'GSE117346',
#   'repository_db': 'GEO',
#   'source': 'Public Institute',
#   'submission_date': '2016-07-20',
#   'title': 'Sybiopop: A systems biology approach to improve poplar biorefinery feedstock by deciphering the genetic architecture of lignocellulosic biomass production and quality',
#   'user_id': '0'},
#  'replicats_11': {'analysis_type': 'RNA-Seq',
#   'array_type': 'Illumina',
#   'biological_interest': 'Which genes affect biomass yield in poplar ?',
#   'comments': 'None',
#   'correlation': 'None',
#   'experiment_factors': 'block (2 levels) and population (6 levels)',
#   'experiment_id': '591',
#   'experiment_idname': 'P413E591',
#   'experiment_name': 'Pilot transcriptomic study',
#   'experiment_type': 'genotype and ecotype comparison',
#   'gem2net_id': 'None',
#   'hyb_cutt_off': 'None',
#   'is_public': 'no',
#   'link_rep': '0',
#   'note': 'RNA was extracted from young differentiating xylem and cambium collected on 24 4-year-old trees trialed in a common garden experiment at INRA Orléans. The trees corresponded to corresponding to 2 replicates of 12 genotypes from 6 natural populations. After RNA quantification, the RNA from xylem and cambium from the same tree were pooled and subjected to high-throughput sequencing on an Illumina HiSeq 2000 using 100 bp single-read indexing runs. All the samples were sequenced on one Illumina lane, yielding around 20 million of single-reads per sample.',
#   'project_code': 'None',
#   'project_id': '413',
#   'project_idname': 'P413',
#   'project_name': 'JC2013_SYBIOPOP_2014',
#   'protocol_id': '0',
#   'public_date': '2018-12-31',
#   'rep_type': 'rep_rnaseq',
#   'replicat_extracts': 'Ticino_SN-2_1,Ticino_SN-2_2,Ticino_SN-2_3,Ticino_SN-2_4',
#   'replicat_id': '5635',
#   'replicat_name': 'Ticino_SN-2',
#   'repository_access': 'GSE117346',
#   'repository_db': 'GEO',
#   'source': 'Public Institute',
#   'submission_date': '2016-07-20',
#   'title': 'Sybiopop: A systems biology approach to improve poplar biorefinery feedstock by deciphering the genetic architecture of lignocellulosic biomass production and quality',
#   'user_id': '0'},
#  'replicats_12': {'analysis_type': 'RNA-Seq',
#   'array_type': 'Illumina',
#   'biological_interest': 'Which genes affect biomass yield in poplar ?',
#   'comments': 'None',
#   'correlation': 'None',
#   'experiment_factors': 'block (2 levels) and population (6 levels)',
#   'experiment_id': '591',
#   'experiment_idname': 'P413E591',
#   'experiment_name': 'Pilot transcriptomic study',
#   'experiment_type': 'genotype and ecotype comparison',
#   'gem2net_id': 'None',
#   'hyb_cutt_off': 'None',
#   'is_public': 'no',
#   'link_rep': '0',
#   'note': 'RNA was extracted from young differentiating xylem and cambium collected on 24 4-year-old trees trialed in a common garden experiment at INRA Orléans. The trees corresponded to corresponding to 2 replicates of 12 genotypes from 6 natural populations. After RNA quantification, the RNA from xylem and cambium from the same tree were pooled and subjected to high-throughput sequencing on an Illumina HiSeq 2000 using 100 bp single-read indexing runs. All the samples were sequenced on one Illumina lane, yielding around 20 million of single-reads per sample.',
#   'project_code': 'None',
#   'project_id': '413',
#   'project_idname': 'P413',
#   'project_name': 'JC2013_SYBIOPOP_2014',
#   'protocol_id': '0',
#   'public_date': '2018-12-31',
#   'rep_type': 'rep_rnaseq',
#   'replicat_extracts': 'Ticino_SN-7_1,Ticino_SN-7_2,Ticino_SN-7_3,Ticino_SN-7_4',
#   'replicat_id': '5636',
#   'replicat_name': 'Ticino_SN-7',
#   'repository_access': 'GSE117346',
#   'repository_db': 'GEO',
#   'source': 'Public Institute',
#   'submission_date': '2016-07-20',
#   'title': 'Sybiopop: A systems biology approach to improve poplar biorefinery feedstock by deciphering the genetic architecture of lignocellulosic biomass production and quality',
#   'user_id': '0'},
#  'replicats_13': {'analysis_type': 'RNA-Seq',
#   'array_type': 'Illumina',
#   'biological_interest': 'Which genes affect biomass yield in poplar ?',
#   'comments': 'None',
#   'correlation': 'None',
#   'experiment_factors': 'block (2 levels) and population (6 levels)',
#   'experiment_id': '591',
#   'experiment_idname': 'P413E591',
#   'experiment_name': 'Pilot transcriptomic study',
#   'experiment_type': 'genotype and ecotype comparison',
#   'gem2net_id': 'None',
#   'hyb_cutt_off': 'None',
#   'is_public': 'no',
#   'link_rep': '0',
#   'note': 'RNA was extracted from young differentiating xylem and cambium collected on 24 4-year-old trees trialed in a common garden experiment at INRA Orléans. The trees corresponded to corresponding to 2 replicates of 12 genotypes from 6 natural populations. After RNA quantification, the RNA from xylem and cambium from the same tree were pooled and subjected to high-throughput sequencing on an Illumina HiSeq 2000 using 100 bp single-read indexing runs. All the samples were sequenced on one Illumina lane, yielding around 20 million of single-reads per sample.',
#   'project_code': 'None',
#   'project_id': '413',
#   'project_idname': 'P413',
#   'project_name': 'JC2013_SYBIOPOP_2014',
#   'protocol_id': '0',
#   'public_date': '2018-12-31',
#   'rep_type': 'rep_rnaseq',
#   'replicat_extracts': 'Adour_AST-005_2,Adour_AST-005_4',
#   'replicat_id': '5673',
#   'replicat_name': 'Adour_AST-005',
#   'repository_access': 'GSE117346',
#   'repository_db': 'GEO',
#   'source': 'Public Institute',
#   'submission_date': '2016-07-20',
#   'title': 'Sybiopop: A systems biology approach to improve poplar biorefinery feedstock by deciphering the genetic architecture of lignocellulosic biomass production and quality',
#   'user_id': '0'},
#  'replicats_14': {'analysis_type': 'RNA-Seq',
#   'array_type': 'Illumina',
#   'biological_interest': 'Which genes affect biomass yield in poplar ?',
#   'comments': 'None',
#   'correlation': 'None',
#   'experiment_factors': 'block (2 levels) and population (6 levels)',
#   'experiment_id': '591',
#   'experiment_idname': 'P413E591',
#   'experiment_name': 'Pilot transcriptomic study',
#   'experiment_type': 'genotype and ecotype comparison',
#   'gem2net_id': 'None',
#   'hyb_cutt_off': 'None',
#   'is_public': 'no',
#   'link_rep': '0',
#   'note': 'RNA was extracted from young differentiating xylem and cambium collected on 24 4-year-old trees trialed in a common garden experiment at INRA Orléans. The trees corresponded to corresponding to 2 replicates of 12 genotypes from 6 natural populations. After RNA quantification, the RNA from xylem and cambium from the same tree were pooled and subjected to high-throughput sequencing on an Illumina HiSeq 2000 using 100 bp single-read indexing runs. All the samples were sequenced on one Illumina lane, yielding around 20 million of single-reads per sample.',
#   'project_code': 'None',
#   'project_id': '413',
#   'project_idname': 'P413',
#   'project_name': 'JC2013_SYBIOPOP_2014',
#   'protocol_id': '0',
#   'public_date': '2018-12-31',
#   'rep_type': 'rep_rnaseq',
#   'replicat_extracts': 'Adour_BDX-003_2,Adour_BDX-003_4',
#   'replicat_id': '5674',
#   'replicat_name': 'Adour_BDX-003',
#   'repository_access': 'GSE117346',
#   'repository_db': 'GEO',
#   'source': 'Public Institute',
#   'submission_date': '2016-07-20',
#   'title': 'Sybiopop: A systems biology approach to improve poplar biorefinery feedstock by deciphering the genetic architecture of lignocellulosic biomass production and quality',
#   'user_id': '0'},
#  'replicats_15': {'analysis_type': 'RNA-Seq',
#   'array_type': 'Illumina',
#   'biological_interest': 'Which genes affect biomass yield in poplar ?',
#   'comments': 'None',
#   'correlation': 'None',
#   'experiment_factors': 'block (2 levels) and population (6 levels)',
#   'experiment_id': '591',
#   'experiment_idname': 'P413E591',
#   'experiment_name': 'Pilot transcriptomic study',
#   'experiment_type': 'genotype and ecotype comparison',
#   'gem2net_id': 'None',
#   'hyb_cutt_off': 'None',
#   'is_public': 'no',
#   'link_rep': '0',
#   'note': 'RNA was extracted from young differentiating xylem and cambium collected on 24 4-year-old trees trialed in a common garden experiment at INRA Orléans. The trees corresponded to corresponding to 2 replicates of 12 genotypes from 6 natural populations. After RNA quantification, the RNA from xylem and cambium from the same tree were pooled and subjected to high-throughput sequencing on an Illumina HiSeq 2000 using 100 bp single-read indexing runs. All the samples were sequenced on one Illumina lane, yielding around 20 million of single-reads per sample.',
#   'project_code': 'None',
#   'project_id': '413',
#   'project_idname': 'P413',
#   'project_name': 'JC2013_SYBIOPOP_2014',
#   'protocol_id': '0',
#   'public_date': '2018-12-31',
#   'rep_type': 'rep_rnaseq',
#   'replicat_extracts': 'Dranse_DRA-038_2,Dranse_DRA-038_4',
#   'replicat_id': '5675',
#   'replicat_name': 'Dranse_DRA-038',
#   'repository_access': 'GSE117346',
#   'repository_db': 'GEO',
#   'source': 'Public Institute',
#   'submission_date': '2016-07-20',
#   'title': 'Sybiopop: A systems biology approach to improve poplar biorefinery feedstock by deciphering the genetic architecture of lignocellulosic biomass production and quality',
#   'user_id': '0'},
#  'replicats_16': {'analysis_type': 'RNA-Seq',
#   'array_type': 'Illumina',
#   'biological_interest': 'Which genes affect biomass yield in poplar ?',
#   'comments': 'None',
#   'correlation': 'None',
#   'experiment_factors': 'block (2 levels) and population (6 levels)',
#   'experiment_id': '591',
#   'experiment_idname': 'P413E591',
#   'experiment_name': 'Pilot transcriptomic study',
#   'experiment_type': 'genotype and ecotype comparison',
#   'gem2net_id': 'None',
#   'hyb_cutt_off': 'None',
#   'is_public': 'no',
#   'link_rep': '0',
#   'note': 'RNA was extracted from young differentiating xylem and cambium collected on 24 4-year-old trees trialed in a common garden experiment at INRA Orléans. The trees corresponded to corresponding to 2 replicates of 12 genotypes from 6 natural populations. After RNA quantification, the RNA from xylem and cambium from the same tree were pooled and subjected to high-throughput sequencing on an Illumina HiSeq 2000 using 100 bp single-read indexing runs. All the samples were sequenced on one Illumina lane, yielding around 20 million of single-reads per sample.',
#   'project_code': 'None',
#   'project_id': '413',
#   'project_idname': 'P413',
#   'project_name': 'JC2013_SYBIOPOP_2014',
#   'protocol_id': '0',
#   'public_date': '2018-12-31',
#   'rep_type': 'rep_rnaseq',
#   'replicat_extracts': 'Dranse_DRA-045_2,Dranse_DRA-045_4',
#   'replicat_id': '5676',
#   'replicat_name': 'Dranse_DRA-045',
#   'repository_access': 'GSE117346',
#   'repository_db': 'GEO',
#   'source': 'Public Institute',
#   'submission_date': '2016-07-20',
#   'title': 'Sybiopop: A systems biology approach to improve poplar biorefinery feedstock by deciphering the genetic architecture of lignocellulosic biomass production and quality',
#   'user_id': '0'},
#  'replicats_17': {'analysis_type': 'RNA-Seq',
#   'array_type': 'Illumina',
#   'biological_interest': 'Which genes affect biomass yield in poplar ?',
#   'comments': 'None',
#   'correlation': 'None',
#   'experiment_factors': 'block (2 levels) and population (6 levels)',
#   'experiment_id': '591',
#   'experiment_idname': 'P413E591',
#   'experiment_name': 'Pilot transcriptomic study',
#   'experiment_type': 'genotype and ecotype comparison',
#   'gem2net_id': 'None',
#   'hyb_cutt_off': 'None',
#   'is_public': 'no',
#   'link_rep': '0',
#   'note': 'RNA was extracted from young differentiating xylem and cambium collected on 24 4-year-old trees trialed in a common garden experiment at INRA Orléans. The trees corresponded to corresponding to 2 replicates of 12 genotypes from 6 natural populations. After RNA quantification, the RNA from xylem and cambium from the same tree were pooled and subjected to high-throughput sequencing on an Illumina HiSeq 2000 using 100 bp single-read indexing runs. All the samples were sequenced on one Illumina lane, yielding around 20 million of single-reads per sample.',
#   'project_code': 'None',
#   'project_id': '413',
#   'project_idname': 'P413',
#   'project_name': 'JC2013_SYBIOPOP_2014',
#   'protocol_id': '0',
#   'public_date': '2018-12-31',
#   'rep_type': 'rep_rnaseq',
#   'replicat_extracts': 'Loire_LOE-011_2,Loire_LOE-011_4',
#   'replicat_id': '5677',
#   'replicat_name': 'Loire_LOE-011',
#   'repository_access': 'GSE117346',
#   'repository_db': 'GEO',
#   'source': 'Public Institute',
#   'submission_date': '2016-07-20',
#   'title': 'Sybiopop: A systems biology approach to improve poplar biorefinery feedstock by deciphering the genetic architecture of lignocellulosic biomass production and quality',
#   'user_id': '0'},
#  'replicats_18': {'analysis_type': 'RNA-Seq',
#   'array_type': 'Illumina',
#   'biological_interest': 'Which genes affect biomass yield in poplar ?',
#   'comments': 'None',
#   'correlation': 'None',
#   'experiment_factors': 'block (2 levels) and population (6 levels)',
#   'experiment_id': '591',
#   'experiment_idname': 'P413E591',
#   'experiment_name': 'Pilot transcriptomic study',
#   'experiment_type': 'genotype and ecotype comparison',
#   'gem2net_id': 'None',
#   'hyb_cutt_off': 'None',
#   'is_public': 'no',
#   'link_rep': '0',
#   'note': 'RNA was extracted from young differentiating xylem and cambium collected on 24 4-year-old trees trialed in a common garden experiment at INRA Orléans. The trees corresponded to corresponding to 2 replicates of 12 genotypes from 6 natural populations. After RNA quantification, the RNA from xylem and cambium from the same tree were pooled and subjected to high-throughput sequencing on an Illumina HiSeq 2000 using 100 bp single-read indexing runs. All the samples were sequenced on one Illumina lane, yielding around 20 million of single-reads per sample.',
#   'project_code': 'None',
#   'project_id': '413',
#   'project_idname': 'P413',
#   'project_name': 'JC2013_SYBIOPOP_2014',
#   'protocol_id': '0',
#   'public_date': '2018-12-31',
#   'rep_type': 'rep_rnaseq',
#   'replicat_extracts': 'Loire_VDL-018_2,Loire_VDL-018_4',
#   'replicat_id': '5678',
#   'replicat_name': 'Loire_VDL-018',
#   'repository_access': 'GSE117346',
#   'repository_db': 'GEO',
#   'source': 'Public Institute',
#   'submission_date': '2016-07-20',
#   'title': 'Sybiopop: A systems biology approach to improve poplar biorefinery feedstock by deciphering the genetic architecture of lignocellulosic biomass production and quality',
#   'user_id': '0'},
#  'replicats_19': {'analysis_type': 'RNA-Seq',
#   'array_type': 'Illumina',
#   'biological_interest': 'Which genes affect biomass yield in poplar ?',
#   'comments': 'None',
#   'correlation': 'None',
#   'experiment_factors': 'block (2 levels) and population (6 levels)',
#   'experiment_id': '591',
#   'experiment_idname': 'P413E591',
#   'experiment_name': 'Pilot transcriptomic study',
#   'experiment_type': 'genotype and ecotype comparison',
#   'gem2net_id': 'None',
#   'hyb_cutt_off': 'None',
#   'is_public': 'no',
#   'link_rep': '0',
#   'note': 'RNA was extracted from young differentiating xylem and cambium collected on 24 4-year-old trees trialed in a common garden experiment at INRA Orléans. The trees corresponded to corresponding to 2 replicates of 12 genotypes from 6 natural populations. After RNA quantification, the RNA from xylem and cambium from the same tree were pooled and subjected to high-throughput sequencing on an Illumina HiSeq 2000 using 100 bp single-read indexing runs. All the samples were sequenced on one Illumina lane, yielding around 20 million of single-reads per sample.',
#   'project_code': 'None',
#   'project_id': '413',
#   'project_idname': 'P413',
#   'project_name': 'JC2013_SYBIOPOP_2014',
#   'protocol_id': '0',
#   'public_date': '2018-12-31',
#   'rep_type': 'rep_rnaseq',
#   'replicat_extracts': 'Rhin_RHN-028_2,Rhin_RHN-028_4',
#   'replicat_id': '5679',
#   'replicat_name': 'Rhin_RHN-028',
#   'repository_access': 'GSE117346',
#   'repository_db': 'GEO',
#   'source': 'Public Institute',
#   'submission_date': '2016-07-20',
#   'title': 'Sybiopop: A systems biology approach to improve poplar biorefinery feedstock by deciphering the genetic architecture of lignocellulosic biomass production and quality',
#   'user_id': '0'},
#  'replicats_2': {'analysis_type': 'RNA-Seq',
#   'array_type': 'Illumina',
#   'biological_interest': 'Which genes affect biomass yield in poplar ?',
#   'comments': 'None',
#   'correlation': 'None',
#   'experiment_factors': 'block (2 levels) and population (6 levels)',
#   'experiment_id': '591',
#   'experiment_idname': 'P413E591',
#   'experiment_name': 'Pilot transcriptomic study',
#   'experiment_type': 'genotype and ecotype comparison',
#   'gem2net_id': 'None',
#   'hyb_cutt_off': 'None',
#   'is_public': 'no',
#   'link_rep': '0',
#   'note': 'RNA was extracted from young differentiating xylem and cambium collected on 24 4-year-old trees trialed in a common garden experiment at INRA Orléans. The trees corresponded to corresponding to 2 replicates of 12 genotypes from 6 natural populations. After RNA quantification, the RNA from xylem and cambium from the same tree were pooled and subjected to high-throughput sequencing on an Illumina HiSeq 2000 using 100 bp single-read indexing runs. All the samples were sequenced on one Illumina lane, yielding around 20 million of single-reads per sample.',
#   'project_code': 'None',
#   'project_id': '413',
#   'project_idname': 'P413',
#   'project_name': 'JC2013_SYBIOPOP_2014',
#   'protocol_id': '0',
#   'public_date': '2018-12-31',
#   'rep_type': 'rep_rnaseq',
#   'replicat_extracts': 'Adour_BDX-03_1,Adour_BDX-03_2,Adour_BDX-03_3,Adour_BDX-03_4',
#   'replicat_id': '5626',
#   'replicat_name': 'Adour_BDX-03',
#   'repository_access': 'GSE117346',
#   'repository_db': 'GEO',
#   'source': 'Public Institute',
#   'submission_date': '2016-07-20',
#   'title': 'Sybiopop: A systems biology approach to improve poplar biorefinery feedstock by deciphering the genetic architecture of lignocellulosic biomass production and quality',
#   'user_id': '0'},
#  'replicats_20': {'analysis_type': 'RNA-Seq',
#   'array_type': 'Illumina',
#   'biological_interest': 'Which genes affect biomass yield in poplar ?',
#   'comments': 'None',
#   'correlation': 'None',
#   'experiment_factors': 'block (2 levels) and population (6 levels)',
#   'experiment_id': '591',
#   'experiment_idname': 'P413E591',
#   'experiment_name': 'Pilot transcriptomic study',
#   'experiment_type': 'genotype and ecotype comparison',
#   'gem2net_id': 'None',
#   'hyb_cutt_off': 'None',
#   'is_public': 'no',
#   'link_rep': '0',
#   'note': 'RNA was extracted from young differentiating xylem and cambium collected on 24 4-year-old trees trialed in a common garden experiment at INRA Orléans. The trees corresponded to corresponding to 2 replicates of 12 genotypes from 6 natural populations. After RNA quantification, the RNA from xylem and cambium from the same tree were pooled and subjected to high-throughput sequencing on an Illumina HiSeq 2000 using 100 bp single-read indexing runs. All the samples were sequenced on one Illumina lane, yielding around 20 million of single-reads per sample.',
#   'project_code': 'None',
#   'project_id': '413',
#   'project_idname': 'P413',
#   'project_name': 'JC2013_SYBIOPOP_2014',
#   'protocol_id': '0',
#   'public_date': '2018-12-31',
#   'rep_type': 'rep_rnaseq',
#   'replicat_extracts': 'Rhin_STR-010_2,Rhin_STR-010_4',
#   'replicat_id': '5680',
#   'replicat_name': 'Rhin_STR-010',
#   'repository_access': 'GSE117346',
#   'repository_db': 'GEO',
#   'source': 'Public Institute',
#   'submission_date': '2016-07-20',
#   'title': 'Sybiopop: A systems biology approach to improve poplar biorefinery feedstock by deciphering the genetic architecture of lignocellulosic biomass production and quality',
#   'user_id': '0'},
#  'replicats_3': {'analysis_type': 'RNA-Seq',
#   'array_type': 'Illumina',
#   'biological_interest': 'Which genes affect biomass yield in poplar ?',
#   'comments': 'None',
#   'correlation': 'None',
#   'experiment_factors': 'block (2 levels) and population (6 levels)',
#   'experiment_id': '591',
#   'experiment_idname': 'P413E591',
#   'experiment_name': 'Pilot transcriptomic study',
#   'experiment_type': 'genotype and ecotype comparison',
#   'gem2net_id': 'None',
#   'hyb_cutt_off': 'None',
#   'is_public': 'no',
#   'link_rep': '0',
#   'note': 'RNA was extracted from young differentiating xylem and cambium collected on 24 4-year-old trees trialed in a common garden experiment at INRA Orléans. The trees corresponded to corresponding to 2 replicates of 12 genotypes from 6 natural populations. After RNA quantification, the RNA from xylem and cambium from the same tree were pooled and subjected to high-throughput sequencing on an Illumina HiSeq 2000 using 100 bp single-read indexing runs. All the samples were sequenced on one Illumina lane, yielding around 20 million of single-reads per sample.',
#   'project_code': 'None',
#   'project_id': '413',
#   'project_idname': 'P413',
#   'project_name': 'JC2013_SYBIOPOP_2014',
#   'protocol_id': '0',
#   'public_date': '2018-12-31',
#   'rep_type': 'rep_rnaseq',
#   'replicat_extracts': 'Dranse_DRA-38_1,Dranse_DRA-38_2,Dranse_DRA-38_3,Dranse_DRA-38_4',
#   'replicat_id': '5627',
#   'replicat_name': 'Dranse_DRA-38',
#   'repository_access': 'GSE117346',
#   'repository_db': 'GEO',
#   'source': 'Public Institute',
#   'submission_date': '2016-07-20',
#   'title': 'Sybiopop: A systems biology approach to improve poplar biorefinery feedstock by deciphering the genetic architecture of lignocellulosic biomass production and quality',
#   'user_id': '0'},
#  'replicats_4': {'analysis_type': 'RNA-Seq',
#   'array_type': 'Illumina',
#   'biological_interest': 'Which genes affect biomass yield in poplar ?',
#   'comments': 'None',
#   'correlation': 'None',
#   'experiment_factors': 'block (2 levels) and population (6 levels)',
#   'experiment_id': '591',
#   'experiment_idname': 'P413E591',
#   'experiment_name': 'Pilot transcriptomic study',
#   'experiment_type': 'genotype and ecotype comparison',
#   'gem2net_id': 'None',
#   'hyb_cutt_off': 'None',
#   'is_public': 'no',
#   'link_rep': '0',
#   'note': 'RNA was extracted from young differentiating xylem and cambium collected on 24 4-year-old trees trialed in a common garden experiment at INRA Orléans. The trees corresponded to corresponding to 2 replicates of 12 genotypes from 6 natural populations. After RNA quantification, the RNA from xylem and cambium from the same tree were pooled and subjected to high-throughput sequencing on an Illumina HiSeq 2000 using 100 bp single-read indexing runs. All the samples were sequenced on one Illumina lane, yielding around 20 million of single-reads per sample.',
#   'project_code': 'None',
#   'project_id': '413',
#   'project_idname': 'P413',
#   'project_name': 'JC2013_SYBIOPOP_2014',
#   'protocol_id': '0',
#   'public_date': '2018-12-31',
#   'rep_type': 'rep_rnaseq',
#   'replicat_extracts': 'Dranse_DRA-45_1,Dranse_DRA-45_2,Dranse_DRA-45_3,Dranse_DRA-45_4',
#   'replicat_id': '5628',
#   'replicat_name': 'Dranse_DRA-45',
#   'repository_access': 'GSE117346',
#   'repository_db': 'GEO',
#   'source': 'Public Institute',
#   'submission_date': '2016-07-20',
#   'title': 'Sybiopop: A systems biology approach to improve poplar biorefinery feedstock by deciphering the genetic architecture of lignocellulosic biomass production and quality',
#   'user_id': '0'},
#  'replicats_5': {'analysis_type': 'RNA-Seq',
#   'array_type': 'Illumina',
#   'biological_interest': 'Which genes affect biomass yield in poplar ?',
#   'comments': 'None',
#   'correlation': 'None',
#   'experiment_factors': 'block (2 levels) and population (6 levels)',
#   'experiment_id': '591',
#   'experiment_idname': 'P413E591',
#   'experiment_name': 'Pilot transcriptomic study',
#   'experiment_type': 'genotype and ecotype comparison',
#   'gem2net_id': 'None',
#   'hyb_cutt_off': 'None',
#   'is_public': 'no',
#   'link_rep': '0',
#   'note': 'RNA was extracted from young differentiating xylem and cambium collected on 24 4-year-old trees trialed in a common garden experiment at INRA Orléans. The trees corresponded to corresponding to 2 replicates of 12 genotypes from 6 natural populations. After RNA quantification, the RNA from xylem and cambium from the same tree were pooled and subjected to high-throughput sequencing on an Illumina HiSeq 2000 using 100 bp single-read indexing runs. All the samples were sequenced on one Illumina lane, yielding around 20 million of single-reads per sample.',
#   'project_code': 'None',
#   'project_id': '413',
#   'project_idname': 'P413',
#   'project_name': 'JC2013_SYBIOPOP_2014',
#   'protocol_id': '0',
#   'public_date': '2018-12-31',
#   'rep_type': 'rep_rnaseq',
#   'replicat_extracts': 'Loire_LOE-11_1,Loire_LOE-11_2,Loire_LOE-11_3,Loire_LOE-11_4',
#   'replicat_id': '5629',
#   'replicat_name': 'Loire_LOE-11',
#   'repository_access': 'GSE117346',
#   'repository_db': 'GEO',
#   'source': 'Public Institute',
#   'submission_date': '2016-07-20',
#   'title': 'Sybiopop: A systems biology approach to improve poplar biorefinery feedstock by deciphering the genetic architecture of lignocellulosic biomass production and quality',
#   'user_id': '0'},
#  'replicats_6': {'analysis_type': 'RNA-Seq',
#   'array_type': 'Illumina',
#   'biological_interest': 'Which genes affect biomass yield in poplar ?',
#   'comments': 'None',
#   'correlation': 'None',
#   'experiment_factors': 'block (2 levels) and population (6 levels)',
#   'experiment_id': '591',
#   'experiment_idname': 'P413E591',
#   'experiment_name': 'Pilot transcriptomic study',
#   'experiment_type': 'genotype and ecotype comparison',
#   'gem2net_id': 'None',
#   'hyb_cutt_off': 'None',
#   'is_public': 'no',
#   'link_rep': '0',
#   'note': 'RNA was extracted from young differentiating xylem and cambium collected on 24 4-year-old trees trialed in a common garden experiment at INRA Orléans. The trees corresponded to corresponding to 2 replicates of 12 genotypes from 6 natural populations. After RNA quantification, the RNA from xylem and cambium from the same tree were pooled and subjected to high-throughput sequencing on an Illumina HiSeq 2000 using 100 bp single-read indexing runs. All the samples were sequenced on one Illumina lane, yielding around 20 million of single-reads per sample.',
#   'project_code': 'None',
#   'project_id': '413',
#   'project_idname': 'P413',
#   'project_name': 'JC2013_SYBIOPOP_2014',
#   'protocol_id': '0',
#   'public_date': '2018-12-31',
#   'rep_type': 'rep_rnaseq',
#   'replicat_extracts': 'Loire_VDL-18_1,Loire_VDL-18_2,Loire_VDL-18_3,Loire_VDL-18_4',
#   'replicat_id': '5630',
#   'replicat_name': 'Loire_VDL-18',
#   'repository_access': 'GSE117346',
#   'repository_db': 'GEO',
#   'source': 'Public Institute',
#   'submission_date': '2016-07-20',
#   'title': 'Sybiopop: A systems biology approach to improve poplar biorefinery feedstock by deciphering the genetic architecture of lignocellulosic biomass production and quality',
#   'user_id': '0'},
#  'replicats_7': {'analysis_type': 'RNA-Seq',
#   'array_type': 'Illumina',
#   'biological_interest': 'Which genes affect biomass yield in poplar ?',
#   'comments': 'None',
#   'correlation': 'None',
#   'experiment_factors': 'block (2 levels) and population (6 levels)',
#   'experiment_id': '591',
#   'experiment_idname': 'P413E591',
#   'experiment_name': 'Pilot transcriptomic study',
#   'experiment_type': 'genotype and ecotype comparison',
#   'gem2net_id': 'None',
#   'hyb_cutt_off': 'None',
#   'is_public': 'no',
#   'link_rep': '0',
#   'note': 'RNA was extracted from young differentiating xylem and cambium collected on 24 4-year-old trees trialed in a common garden experiment at INRA Orléans. The trees corresponded to corresponding to 2 replicates of 12 genotypes from 6 natural populations. After RNA quantification, the RNA from xylem and cambium from the same tree were pooled and subjected to high-throughput sequencing on an Illumina HiSeq 2000 using 100 bp single-read indexing runs. All the samples were sequenced on one Illumina lane, yielding around 20 million of single-reads per sample.',
#   'project_code': 'None',
#   'project_id': '413',
#   'project_idname': 'P413',
#   'project_name': 'JC2013_SYBIOPOP_2014',
#   'protocol_id': '0',
#   'public_date': '2018-12-31',
#   'rep_type': 'rep_rnaseq',
#   'replicat_extracts': 'Ramieres_1-A26_1,Ramieres_1-A26_2,Ramieres_1-A26_3,Ramieres_1-A26_4',
#   'replicat_id': '5631',
#   'replicat_name': 'Ramieres_1-A26',
#   'repository_access': 'GSE117346',
#   'repository_db': 'GEO',
#   'source': 'Public Institute',
#   'submission_date': '2016-07-20',
#   'title': 'Sybiopop: A systems biology approach to improve poplar biorefinery feedstock by deciphering the genetic architecture of lignocellulosic biomass production and quality',
#   'user_id': '0'},
#  'replicats_8': {'analysis_type': 'RNA-Seq',
#   'array_type': 'Illumina',
#   'biological_interest': 'Which genes affect biomass yield in poplar ?',
#   'comments': 'None',
#   'correlation': 'None',
#   'experiment_factors': 'block (2 levels) and population (6 levels)',
#   'experiment_id': '591',
#   'experiment_idname': 'P413E591',
#   'experiment_name': 'Pilot transcriptomic study',
#   'experiment_type': 'genotype and ecotype comparison',
#   'gem2net_id': 'None',
#   'hyb_cutt_off': 'None',
#   'is_public': 'no',
#   'link_rep': '0',
#   'note': 'RNA was extracted from young differentiating xylem and cambium collected on 24 4-year-old trees trialed in a common garden experiment at INRA Orléans. The trees corresponded to corresponding to 2 replicates of 12 genotypes from 6 natural populations. After RNA quantification, the RNA from xylem and cambium from the same tree were pooled and subjected to high-throughput sequencing on an Illumina HiSeq 2000 using 100 bp single-read indexing runs. All the samples were sequenced on one Illumina lane, yielding around 20 million of single-reads per sample.',
#   'project_code': 'None',
#   'project_id': '413',
#   'project_idname': 'P413',
#   'project_name': 'JC2013_SYBIOPOP_2014',
#   'protocol_id': '0',
#   'public_date': '2018-12-31',
#   'rep_type': 'rep_rnaseq',
#   'replicat_extracts': 'Ramieres_1-J31_1,Ramieres_1-J31_2,Ramieres_1-J31_3,Ramieres_1-J31_4',
#   'replicat_id': '5632',
#   'replicat_name': 'Ramieres_1-J31',
#   'repository_access': 'GSE117346',
#   'repository_db': 'GEO',
#   'source': 'Public Institute',
#   'submission_date': '2016-07-20',
#   'title': 'Sybiopop: A systems biology approach to improve poplar biorefinery feedstock by deciphering the genetic architecture of lignocellulosic biomass production and quality',
#   'user_id': '0'},
#  'replicats_9': {'analysis_type': 'RNA-Seq',
#   'array_type': 'Illumina',
#   'biological_interest': 'Which genes affect biomass yield in poplar ?',
#   'comments': 'None',
#   'correlation': 'None',
#   'experiment_factors': 'block (2 levels) and population (6 levels)',
#   'experiment_id': '591',
#   'experiment_idname': 'P413E591',
#   'experiment_name': 'Pilot transcriptomic study',
#   'experiment_type': 'genotype and ecotype comparison',
#   'gem2net_id': 'None',
#   'hyb_cutt_off': 'None',
#   'is_public': 'no',
#   'link_rep': '0',
#   'note': 'RNA was extracted from young differentiating xylem and cambium collected on 24 4-year-old trees trialed in a common garden experiment at INRA Orléans. The trees corresponded to corresponding to 2 replicates of 12 genotypes from 6 natural populations. After RNA quantification, the RNA from xylem and cambium from the same tree were pooled and subjected to high-throughput sequencing on an Illumina HiSeq 2000 using 100 bp single-read indexing runs. All the samples were sequenced on one Illumina lane, yielding around 20 million of single-reads per sample.',
#   'project_code': 'None',
#   'project_id': '413',
#   'project_idname': 'P413',
#   'project_name': 'JC2013_SYBIOPOP_2014',
#   'protocol_id': '0',
#   'public_date': '2018-12-31',
#   'rep_type': 'rep_rnaseq',
#   'replicat_extracts': 'Rhin_RHN-28_1,Rhin_RHN-28_2,Rhin_RHN-28_3,Rhin_RHN-28_4',
#   'replicat_id': '5633',
#   'replicat_name': 'Rhin_RHN-28',
#   'repository_access': 'GSE117346',
#   'repository_db': 'GEO',
#   'source': 'Public Institute',
#   'submission_date': '2016-07-20',
#   'title': 'Sybiopop: A systems biology approach to improve poplar biorefinery feedstock by deciphering the genetic architecture of lignocellulosic biomass production and quality',
#   'user_id': '0'},
#  'repository_access': 'GSE117346',
#  'repository_db': 'GEO',
#  'resume_file': 'JC2013_SYBIOPOP_2014_exp591_MappingCount_24ech_premanip.log',
#  'rna_selection': 'selection polyA',
#  'rnaseqdata_id': '14',
#  'rnaseqdata_name': 'JC2013_SYBIOPOP_2014_exp591',
#  'rnaseqlibrary_id': '23',
#  'rnaseqlibrary_name': 'JC2013_SYBIOPOP_2014_exp591',
#  'seq_length': '100',
#  'seq_type': 'paired-end reads',
#  'sequencer': 'Illumina HiSeq 2000',
#  'sizing': '200-500',
#  'source': 'Public Institute',
#  'stranded': 'yes',
#  'submission_date': '2018-07-03',
#  'title': 'Sybiopop: A systems biology approach to improve poplar biorefinery feedstock by deciphering the genetic architecture of lignocellulosic biomass production and quality',
#  'user_id': '0'}
