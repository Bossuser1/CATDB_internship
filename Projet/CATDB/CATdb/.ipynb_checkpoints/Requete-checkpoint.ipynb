# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
from django.db import models
# Create your models here.

import psycopg2
#from config import config
from django.test.html import Element
import os

import os

from configparser import ConfigParser


def config(section='postgresql'):
    if os.getcwd()[0:12]!="/home/traore":
    	filename=os.getcwd()+'/database.ini'
    else:
    	filename=os.getcwd()+'/database2.ini'
    # create a parser
    parser = ConfigParser()
    # read config file
    parser.read(filename)
    # get section, default to postgresql
    db = {}
    if parser.has_section(section):
        params = parser.items(section)
        for param in params:
            db[param[0]] = param[1]
    else:
        raise Exception('Section {0} not found in the {1} file'.format(section, filename))
 
    return db




def connect():
    """ Connect to the PostgreSQL database server """
    conn = None
    try:
        # read connection parameters
        params = config()
        # connect to the PostgreSQL server
        print('Connecting to the PostgreSQL database...')
        conn = psycopg2.connect(**params)
        # create a cursor
        cur = conn.cursor()
        # execute a statement
        print('PostgreSQL database version:')
        cur.execute('SELECT version()')
        # display the PostgreSQL database server version
        db_version = cur.fetchone()
        print(db_version)
     # close the communication with the PostgreSQL
        cur.close()
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
    finally:
        if conn is not None:
            conn.close()
            print('Database connection closed.')


def read_data_sql(requete,element):
    """
    input requete outupt data
    requete='select * from chips.experiment;'
    """
    conn = None
    params = config()
    conn = psycopg2.connect(**params)
    cursor = conn.cursor()#cursor_factory=psycopg2.extras.DictCursor
    cursor.execute(requete)
    colnames = [desc[0] for desc in cursor.description]
    memory = cursor.fetchall()
    conn.close()
    cpt=0
    data=dict()
    for ele in range(len(memory)):
        cpt=cpt+1
        col=[]
        for ele1 in memory[ele]:
            col.append(str(ele1))
        dictionary ={'_key':cpt,"_value":dict(zip(colnames,col))}
        data[cpt]=dictionary
    name=element+'.csv'     
    return data

def lecture_query_tage(file_query):
    """
    function sert a lire les requetes prédefinir seulement
    """
    query_tag=dict()
    with open(file_query,"r") as fiche:
        data=fiche.readlines()
        for line in data:
            if line[0]!="#":
                if line[0:9]=="Tag_query":
                    _key=line[11:].replace('\n','').replace('"','')
                elif line[0:5]=="query":
                    query_tag[_key]=(line[6:].replace('\n','').replace('"',''))            
    return query_tag


repertoire_requete=lecture_query_tage(os.getcwd()+'/query_tag.ini')

def execution_requete(element,value_send,colname_send,order_ele=None):
    ### parametres
    if os.getcwd()[0:12]!="/home/traore":
    	my_ppty="chips"
    else:
    	my_ppty="public" #CHIPS

   
    # creation/tri des infos :(creation de structures de données)
    ###Todo
    
    # Bilan Chiffres nbr de puces par especes
    # pas Arabidopsis dans nouveau champ common_name d'array_type et 
    # analysis_type='Arrays'
    # partie requete
    my_querySpecies="select array_type_name, count(hybridization_id) "+\
    "from "+my_ppty+".hybridization "+\
    "where project_id in (select project_id from "+my_ppty+".project where is_public='yes') "+\
    "and experiment_id in (select experiment_id from "+my_ppty+".experiment "+\
    "where analysis_type='Arrays') "+\
    "and array_type_name in "+\
    "(select a.array_type_name from "+my_ppty+".array_type a where a.common_name<>'Arabidopsis')"+\
    "group by array_type_name order by array_type_name;"
    
    #Pour le nombre de ref biblio
    my_reqstat ="Select count(*) from "+my_ppty+".biblio_list;"
    
    
    #my_req_special="select o.organism_name,count(distinct ss.project_id) from "+my_ppty+".sample_source ss,"+my_ppty+".organism o where ss.project_id in( select project_id from "+my_ppty+".project where is_public='yes')  group by o.organism_name;"
    my_req_special="select o.organism_name,count(distinct ss.project_id) from "+my_ppty+".sample_source ss,"+my_ppty+".organism o where ss.project_id in( select project_id from "+my_ppty+".project ) and ss.organism_id=o.organism_id group by o.organism_name;" #where is_public='yes'
    
    my_req_recherche="SELECT * FROM global_search_element('Arabidopsis',param_schemas:=array['chips']);"
    
    my_req_recherche1="select project_id,Experiment_type,Experiment_name from "+my_ppty+".experiment where project_id in (select project_id from "+my_ppty+".project where is_public='yes');"
    
    #experiement="select * from chips.experiment where project_id in (select project_id from chips.project where is_public='yes'));"
    
    experiement="select * from (select S.project_name,O.project_id,O.experiment_name,O.experiment_type from "+my_ppty+".experiment O,"+my_ppty+".project S where O.project_id in (select project_id from "+my_ppty+".project where is_public='yes')) df limit 100;"
    
    
    try:
        my_req_recherche_av="select * from "+colname_send+" where (is_public='yes' and project_name like '%"+value_send+"%');"
    except:
        pass
    if element=='my_reqinfo':
        requete=my_reqinfo
    elif element=='my_querySpecies':
        requete=my_querySpecies
    elif element=='my_reqstat':
        requete=my_reqstat    
    elif element=='my_req_special':
        requete=my_req_special    
    elif element=='my_req_recherche':
        requete=my_req_recherche        
    elif element=='my_req_recherche_av' and colname_send!=None and value_send!=None:
        requete=my_req_recherche_av     
    elif element=='my_req_recherche1':
        requete=my_req_recherche1
    elif element=='experiement':
        requete=experiement  
    elif (element=='get_project' or element=='get_contact' or element=='my_experience' or 'my_treatment' or 'list_project' or 'type_analysis' or 'type_arrays' or 'all_experiment'):
        requete=repertoire_requete[element].replace('schema.',my_ppty+'.')
        if value_send!=None:
            requete=requete.replace('value_send',value_send)
        else:
            requete=requete
        print(requete)
    else:
        try:
            requete=eval(element)
        except:
            requete=None
            pass
    
    my_req_special="select o.organism_name,count(distinct ss.project_id) from "+my_ppty+".sample_source ss,"+my_ppty+".organism o where ss.project_id in( select project_id from "+my_ppty+".project where is_public='yes') and ss.organism_id=o.organism_id group by o.organism_name;"
    
    
    
    if  element=='my_req_special' and order_ele==None:
         requete=my_req_special  
    elif element=='my_req_special' and order_ele!=None:    
        requete="select * from ("+requete.replace(";",')')+' dfg order by dfg.'+order_ele+";"
    elif  element=='my_querySpecies' and order_ele==None:
         requete=my_querySpecies  
    elif element=='my_querySpecies' and order_ele!=None:    
        requete="select * from ("+requete.replace(";",')')+' dfg order by dfg.'+order_ele+";"
    elif  element=='my_req_recherche1' and order_ele==None:
         requete=my_req_recherche1  
    elif element=='my_req_recherche1' and order_ele!=None:    
        requete="select * from ("+requete.replace(";",')')+' dfg order by dfg.'+order_ele+";"
    if requete!=None:
        return read_data_sql(requete,element)    
    else:
        print("error")

# %%
data=execution_requete('treatment_list','','')
# Out:
# select treatment_type,treatment.project_id from chips.treatment,chips.project where project.project_id=treatment.project_id and project.Is_public='yes';

# %%
data_comp={}
for i in data.keys():
    key=list(data[i]['_value'].keys())
    key=['project_id','treatment_type']
    try:
            key_compt=data[i]['_value'][key[1]].split(',')
            for element in key_compt:
                if element not in data_comp:
                    data_comp[element]=[data[i]['_value'][key[0]]]
                else:
                    current=data_comp[element]
                    current.append(data[i]['_value'][key[0]])
                    data_comp[element]=current       
    except:
        pass

# %%
data_save=[]
for el in data_comp.keys():
    data_save.append({'experiment_type':el,'count':len(data_comp[el])})#,'project_id':data_comp[el]})

# %%
data_save
# Out:
# [{'count': 20, 'experiment_type': 'control buffer'},
#  {'count': 6, 'experiment_type': 'inoculation'},
#  {'count': 3, 'experiment_type': 'hormone treatment'},
#  {'count': 1, 'experiment_type': 'no treatment'},
#  {'count': 40, 'experiment_type': 'abiotic stress'},
#  {'count': 2, 'experiment_type': 'other inoculation '},
#  {'count': 4, 'experiment_type': 'syringe-inoculation'},
#  {'count': 1, 'experiment_type': 'iron deficiency'},
#  {'count': 162, 'experiment_type': 'environmental treatment'},
#  {'count': 2, 'experiment_type': 'inoculation with a. euteiches'},
#  {'count': 4, 'experiment_type': 'nothing'},
#  {'count': 3, 'experiment_type': 'storage -20°c'},
#  {'count': 37, 'experiment_type': 'pathogen'},
#  {'count': 2, 'experiment_type': 'limited nitrogen supply'},
#  {'count': 1, 'experiment_type': 'infection'},
#  {'count': 3, 'experiment_type': 'storage +20°c 2 mois'},
#  {'count': 194, 'experiment_type': 'compound based treatment'},
#  {'count': 27, 'experiment_type': 'biotic stress'},
#  {'count': 2, 'experiment_type': 'compound+pathogen'},
#  {'count': 5, 'experiment_type': 'control'},
#  {'count': 35, 'experiment_type': 'growth conditions'},
#  {'count': 2, 'experiment_type': 'gene induction'},
#  {'count': 42, 'experiment_type': 'time course study'},
#  {'count': 4, 'experiment_type': 'induction'},
#  {'count': 1, 'experiment_type': 'nematode inoculation'},
#  {'count': 2, 'experiment_type': 'sufficient nitrogen supply'},
#  {'count': 1, 'experiment_type': 'iron sufficiency'},
#  {'count': 7, 'experiment_type': 'wounding'},
#  {'count': 4, 'experiment_type': 'genetic treatment'},
#  {'count': 1, 'experiment_type': 'with euteiches'},
#  {'count': 1, 'experiment_type': 'technical'}]

# %%
data=execution_requete('treatment_list','','')
data
# Out:
# select treatment_type,treatment.project_id from chips.treatment,chips.project where project.project_id=treatment.project_id and project.Is_public='yes';
# {1: {'_key': 1,
#   '_value': {'project_id': '1', 'treatment_type': 'environmental treatment'}},
#  2: {'_key': 2,
#   '_value': {'project_id': '0', 'treatment_type': 'environmental treatment'}},
#  3: {'_key': 3,
#   '_value': {'project_id': '0', 'treatment_type': 'environmental treatment'}},
#  4: {'_key': 4,
#   '_value': {'project_id': '10', 'treatment_type': 'environmental treatment'}},
#  5: {'_key': 5,
#   '_value': {'project_id': '10', 'treatment_type': 'environmental treatment'}},
#  6: {'_key': 6,
#   '_value': {'project_id': '15', 'treatment_type': 'environmental treatment'}},
#  7: {'_key': 7, '_value': {'project_id': '221', 'treatment_type': 'pathogen'}},
#  8: {'_key': 8,
#   '_value': {'project_id': '14',
#    'treatment_type': 'compound based treatment'}},
#  9: {'_key': 9,
#   '_value': {'project_id': '14',
#    'treatment_type': 'compound based treatment'}},
#  10: {'_key': 10,
#   '_value': {'project_id': '14',
#    'treatment_type': 'compound based treatment'}},
#  11: {'_key': 11,
#   '_value': {'project_id': '14',
#    'treatment_type': 'compound based treatment'}},
#  12: {'_key': 12,
#   '_value': {'project_id': '19', 'treatment_type': 'environmental treatment'}},
#  13: {'_key': 13,
#   '_value': {'project_id': '25', 'treatment_type': 'pathogen'}},
#  14: {'_key': 14,
#   '_value': {'project_id': '25', 'treatment_type': 'control buffer'}},
#  15: {'_key': 15,
#   '_value': {'project_id': '29', 'treatment_type': 'environmental treatment'}},
#  16: {'_key': 16,
#   '_value': {'project_id': '32',
#    'treatment_type': 'compound based treatment'}},
#  17: {'_key': 17,
#   '_value': {'project_id': '23',
#    'treatment_type': 'compound based treatment'}},
#  18: {'_key': 18,
#   '_value': {'project_id': '34', 'treatment_type': 'growth conditions'}},
#  19: {'_key': 19,
#   '_value': {'project_id': '36', 'treatment_type': 'biotic stress'}},
#  20: {'_key': 20,
#   '_value': {'project_id': '36', 'treatment_type': 'biotic stress'}},
#  21: {'_key': 21,
#   '_value': {'project_id': '36', 'treatment_type': 'biotic stress'}},
#  22: {'_key': 22,
#   '_value': {'project_id': '37', 'treatment_type': 'environmental treatment'}},
#  23: {'_key': 23,
#   '_value': {'project_id': '37', 'treatment_type': 'environmental treatment'}},
#  24: {'_key': 24,
#   '_value': {'project_id': '38', 'treatment_type': 'environmental treatment'}},
#  25: {'_key': 25,
#   '_value': {'project_id': '40',
#    'treatment_type': 'compound based treatment'}},
#  26: {'_key': 26,
#   '_value': {'project_id': '41', 'treatment_type': 'environmental treatment'}},
#  27: {'_key': 27,
#   '_value': {'project_id': '107',
#    'treatment_type': 'compound based treatment'}},
#  28: {'_key': 28,
#   '_value': {'project_id': '42', 'treatment_type': 'environmental treatment'}},
#  29: {'_key': 29,
#   '_value': {'project_id': '42', 'treatment_type': 'environmental treatment'}},
#  30: {'_key': 30,
#   '_value': {'project_id': '43', 'treatment_type': 'environmental treatment'}},
#  31: {'_key': 31,
#   '_value': {'project_id': '43', 'treatment_type': 'environmental treatment'}},
#  32: {'_key': 32,
#   '_value': {'project_id': '43', 'treatment_type': 'environmental treatment'}},
#  33: {'_key': 33,
#   '_value': {'project_id': '43', 'treatment_type': 'environmental treatment'}},
#  34: {'_key': 34,
#   '_value': {'project_id': '43', 'treatment_type': 'environmental treatment'}},
#  35: {'_key': 35,
#   '_value': {'project_id': '43', 'treatment_type': 'environmental treatment'}},
#  36: {'_key': 36,
#   '_value': {'project_id': '43', 'treatment_type': 'environmental treatment'}},
#  37: {'_key': 37,
#   '_value': {'project_id': '44', 'treatment_type': 'time course study'}},
#  38: {'_key': 38,
#   '_value': {'project_id': '43', 'treatment_type': 'control buffer'}},
#  39: {'_key': 39,
#   '_value': {'project_id': '45',
#    'treatment_type': 'compound based treatment'}},
#  40: {'_key': 40,
#   '_value': {'project_id': '45',
#    'treatment_type': 'compound based treatment'}},
#  41: {'_key': 41,
#   '_value': {'project_id': '45',
#    'treatment_type': 'compound based treatment'}},
#  42: {'_key': 42,
#   '_value': {'project_id': '45',
#    'treatment_type': 'compound based treatment'}},
#  43: {'_key': 43,
#   '_value': {'project_id': '48',
#    'treatment_type': 'compound based treatment'}},
#  44: {'_key': 44,
#   '_value': {'project_id': '50',
#    'treatment_type': 'compound based treatment'}},
#  45: {'_key': 45,
#   '_value': {'project_id': '50',
#    'treatment_type': 'compound based treatment'}},
#  46: {'_key': 46,
#   '_value': {'project_id': '50',
#    'treatment_type': 'compound based treatment'}},
#  47: {'_key': 47,
#   '_value': {'project_id': '50',
#    'treatment_type': 'compound based treatment'}},
#  48: {'_key': 48,
#   '_value': {'project_id': '142',
#    'treatment_type': 'compound based treatment'}},
#  49: {'_key': 49,
#   '_value': {'project_id': '50',
#    'treatment_type': 'compound based treatment'}},
#  50: {'_key': 50,
#   '_value': {'project_id': '48', 'treatment_type': 'biotic stress'}},
#  51: {'_key': 51,
#   '_value': {'project_id': '51',
#    'treatment_type': 'compound based treatment'}},
#  52: {'_key': 52,
#   '_value': {'project_id': '51',
#    'treatment_type': 'compound based treatment'}},
#  53: {'_key': 53,
#   '_value': {'project_id': '51',
#    'treatment_type': 'compound based treatment'}},
#  54: {'_key': 54,
#   '_value': {'project_id': '51',
#    'treatment_type': 'compound based treatment'}},
#  55: {'_key': 55,
#   '_value': {'project_id': '48',
#    'treatment_type': 'compound based treatment'}},
#  56: {'_key': 56,
#   '_value': {'project_id': '48',
#    'treatment_type': 'compound based treatment'}},
#  57: {'_key': 57,
#   '_value': {'project_id': '48',
#    'treatment_type': 'compound based treatment'}},
#  58: {'_key': 58,
#   '_value': {'project_id': '48',
#    'treatment_type': 'compound based treatment'}},
#  59: {'_key': 59,
#   '_value': {'project_id': '48', 'treatment_type': 'growth conditions'}},
#  60: {'_key': 60,
#   '_value': {'project_id': '42', 'treatment_type': 'environmental treatment'}},
#  61: {'_key': 61,
#   '_value': {'project_id': '58', 'treatment_type': 'environmental treatment'}},
#  62: {'_key': 62,
#   '_value': {'project_id': '58', 'treatment_type': 'environmental treatment'}},
#  63: {'_key': 63,
#   '_value': {'project_id': '59',
#    'treatment_type': 'compound based treatment'}},
#  64: {'_key': 64,
#   '_value': {'project_id': '59',
#    'treatment_type': 'compound based treatment'}},
#  65: {'_key': 65,
#   '_value': {'project_id': '59',
#    'treatment_type': 'compound based treatment'}},
#  66: {'_key': 66,
#   '_value': {'project_id': '59',
#    'treatment_type': 'compound based treatment'}},
#  67: {'_key': 67,
#   '_value': {'project_id': '200',
#    'treatment_type': 'hormone treatment,biotic stress'}},
#  68: {'_key': 68,
#   '_value': {'project_id': '212', 'treatment_type': 'pathogen'}},
#  69: {'_key': 69,
#   '_value': {'project_id': '244', 'treatment_type': 'technical'}},
#  70: {'_key': 70,
#   '_value': {'project_id': '63', 'treatment_type': 'environmental treatment'}},
#  71: {'_key': 71,
#   '_value': {'project_id': '64',
#    'treatment_type': 'compound based treatment'}},
#  72: {'_key': 72,
#   '_value': {'project_id': '37', 'treatment_type': 'environmental treatment'}},
#  73: {'_key': 73,
#   '_value': {'project_id': '69', 'treatment_type': 'control buffer'}},
#  74: {'_key': 74,
#   '_value': {'project_id': '78', 'treatment_type': 'compound+pathogen'}},
#  75: {'_key': 75,
#   '_value': {'project_id': '64',
#    'treatment_type': 'compound based treatment'}},
#  76: {'_key': 76,
#   '_value': {'project_id': '64',
#    'treatment_type': 'compound based treatment'}},
#  77: {'_key': 77,
#   '_value': {'project_id': '64',
#    'treatment_type': 'compound based treatment'}},
#  78: {'_key': 78,
#   '_value': {'project_id': '64',
#    'treatment_type': 'compound based treatment'}},
#  79: {'_key': 79,
#   '_value': {'project_id': '64',
#    'treatment_type': 'compound based treatment'}},
#  80: {'_key': 80,
#   '_value': {'project_id': '49', 'treatment_type': 'environmental treatment'}},
#  81: {'_key': 81,
#   '_value': {'project_id': '49', 'treatment_type': 'environmental treatment'}},
#  82: {'_key': 82,
#   '_value': {'project_id': '49', 'treatment_type': 'environmental treatment'}},
#  83: {'_key': 83,
#   '_value': {'project_id': '49', 'treatment_type': 'environmental treatment'}},
#  84: {'_key': 84,
#   '_value': {'project_id': '246', 'treatment_type': 'biotic stress'}},
#  85: {'_key': 85,
#   '_value': {'project_id': '37', 'treatment_type': 'environmental treatment'}},
#  86: {'_key': 86,
#   '_value': {'project_id': '48',
#    'treatment_type': 'compound based treatment'}},
#  87: {'_key': 87,
#   '_value': {'project_id': '48',
#    'treatment_type': 'compound based treatment'}},
#  88: {'_key': 88,
#   '_value': {'project_id': '37', 'treatment_type': 'genetic treatment'}},
#  89: {'_key': 89,
#   '_value': {'project_id': '37', 'treatment_type': 'environmental treatment'}},
#  90: {'_key': 90,
#   '_value': {'project_id': '37', 'treatment_type': 'environmental treatment'}},
#  91: {'_key': 91,
#   '_value': {'project_id': '37', 'treatment_type': 'genetic treatment'}},
#  92: {'_key': 92,
#   '_value': {'project_id': '69',
#    'treatment_type': 'compound based treatment'}},
#  93: {'_key': 93,
#   '_value': {'project_id': '69',
#    'treatment_type': 'compound based treatment'}},
#  94: {'_key': 94,
#   '_value': {'project_id': '69',
#    'treatment_type': 'compound based treatment'}},
#  95: {'_key': 95,
#   '_value': {'project_id': '69',
#    'treatment_type': 'compound based treatment'}},
#  96: {'_key': 96,
#   '_value': {'project_id': '69',
#    'treatment_type': 'compound based treatment'}},
#  97: {'_key': 97,
#   '_value': {'project_id': '69',
#    'treatment_type': 'compound based treatment'}},
#  98: {'_key': 98,
#   '_value': {'project_id': '71',
#    'treatment_type': 'compound based treatment'}},
#  99: {'_key': 99,
#   '_value': {'project_id': '71',
#    'treatment_type': 'compound based treatment'}},
#  100: {'_key': 100,
#   '_value': {'project_id': '71',
#    'treatment_type': 'compound based treatment'}},
#  101: {'_key': 101,
#   '_value': {'project_id': '71',
#    'treatment_type': 'compound based treatment'}},
#  102: {'_key': 102,
#   '_value': {'project_id': '71',
#    'treatment_type': 'compound based treatment'}},
#  103: {'_key': 103,
#   '_value': {'project_id': '60', 'treatment_type': 'abiotic stress'}},
#  104: {'_key': 104,
#   '_value': {'project_id': '60', 'treatment_type': 'abiotic stress'}},
#  105: {'_key': 105,
#   '_value': {'project_id': '60', 'treatment_type': 'biotic stress'}},
#  106: {'_key': 106,
#   '_value': {'project_id': '60', 'treatment_type': 'biotic stress'}},
#  107: {'_key': 107,
#   '_value': {'project_id': '60', 'treatment_type': 'biotic stress'}},
#  108: {'_key': 108,
#   '_value': {'project_id': '60', 'treatment_type': 'biotic stress'}},
#  109: {'_key': 109,
#   '_value': {'project_id': '77', 'treatment_type': 'abiotic stress'}},
#  110: {'_key': 110,
#   '_value': {'project_id': '77', 'treatment_type': 'abiotic stress'}},
#  111: {'_key': 111,
#   '_value': {'project_id': '77', 'treatment_type': 'abiotic stress'}},
#  112: {'_key': 112,
#   '_value': {'project_id': '76', 'treatment_type': 'abiotic stress'}},
#  113: {'_key': 113,
#   '_value': {'project_id': '76', 'treatment_type': 'abiotic stress'}},
#  114: {'_key': 114,
#   '_value': {'project_id': '44', 'treatment_type': 'time course study'}},
#  115: {'_key': 115,
#   '_value': {'project_id': '79', 'treatment_type': 'control buffer'}},
#  116: {'_key': 116,
#   '_value': {'project_id': '79',
#    'treatment_type': 'compound based treatment'}},
#  117: {'_key': 117,
#   '_value': {'project_id': '79',
#    'treatment_type': 'compound based treatment'}},
#  118: {'_key': 118,
#   '_value': {'project_id': '79',
#    'treatment_type': 'compound based treatment'}},
#  119: {'_key': 119,
#   '_value': {'project_id': '82', 'treatment_type': 'environmental treatment'}},
#  120: {'_key': 120,
#   '_value': {'project_id': '78',
#    'treatment_type': 'compound based treatment'}},
#  121: {'_key': 121,
#   '_value': {'project_id': '107',
#    'treatment_type': 'compound based treatment'}},
#  122: {'_key': 122,
#   '_value': {'project_id': '78',
#    'treatment_type': 'compound based treatment'}},
#  123: {'_key': 123,
#   '_value': {'project_id': '78',
#    'treatment_type': 'compound+pathogen,pathogen'}},
#  124: {'_key': 124,
#   '_value': {'project_id': '86', 'treatment_type': 'abiotic stress'}},
#  125: {'_key': 125,
#   '_value': {'project_id': '87', 'treatment_type': 'abiotic stress'}},
#  126: {'_key': 126,
#   '_value': {'project_id': '87', 'treatment_type': 'abiotic stress'}},
#  127: {'_key': 127,
#   '_value': {'project_id': '87', 'treatment_type': 'abiotic stress'}},
#  128: {'_key': 128,
#   '_value': {'project_id': '87', 'treatment_type': 'abiotic stress'}},
#  129: {'_key': 129,
#   '_value': {'project_id': '88',
#    'treatment_type': 'compound based treatment'}},
#  130: {'_key': 130,
#   '_value': {'project_id': '92',
#    'treatment_type': 'compound based treatment'}},
#  131: {'_key': 131,
#   '_value': {'project_id': '92',
#    'treatment_type': 'compound based treatment'}},
#  132: {'_key': 132,
#   '_value': {'project_id': '92',
#    'treatment_type': 'compound based treatment'}},
#  133: {'_key': 133,
#   '_value': {'project_id': '100', 'treatment_type': 'pathogen'}},
#  134: {'_key': 134,
#   '_value': {'project_id': '142',
#    'treatment_type': 'compound based treatment'}},
#  135: {'_key': 135,
#   '_value': {'project_id': '59',
#    'treatment_type': 'compound based treatment'}},
#  136: {'_key': 136,
#   '_value': {'project_id': '59',
#    'treatment_type': 'compound based treatment'}},
#  137: {'_key': 137,
#   '_value': {'project_id': '59',
#    'treatment_type': 'compound based treatment'}},
#  138: {'_key': 138,
#   '_value': {'project_id': '59',
#    'treatment_type': 'compound based treatment'}},
#  139: {'_key': 139,
#   '_value': {'project_id': '102',
#    'treatment_type': 'environmental treatment'}},
#  140: {'_key': 140,
#   '_value': {'project_id': '102',
#    'treatment_type': 'environmental treatment'}},
#  141: {'_key': 141,
#   '_value': {'project_id': '104',
#    'treatment_type': 'environmental treatment'}},
#  142: {'_key': 142,
#   '_value': {'project_id': '104',
#    'treatment_type': 'environmental treatment'}},
#  143: {'_key': 143,
#   '_value': {'project_id': '103', 'treatment_type': 'growth conditions'}},
#  144: {'_key': 144,
#   '_value': {'project_id': '103', 'treatment_type': 'growth conditions'}},
#  145: {'_key': 145,
#   '_value': {'project_id': '106',
#    'treatment_type': 'environmental treatment'}},
#  146: {'_key': 146,
#   '_value': {'project_id': '107',
#    'treatment_type': 'compound based treatment'}},
#  147: {'_key': 147,
#   '_value': {'project_id': '107',
#    'treatment_type': 'compound based treatment'}},
#  148: {'_key': 148,
#   '_value': {'project_id': '107',
#    'treatment_type': 'compound based treatment'}},
#  149: {'_key': 149,
#   '_value': {'project_id': '107',
#    'treatment_type': 'compound based treatment'}},
#  150: {'_key': 150,
#   '_value': {'project_id': '108',
#    'treatment_type': 'compound based treatment'}},
#  151: {'_key': 151,
#   '_value': {'project_id': '108',
#    'treatment_type': 'compound based treatment'}},
#  152: {'_key': 152,
#   '_value': {'project_id': '108',
#    'treatment_type': 'compound based treatment'}},
#  153: {'_key': 153,
#   '_value': {'project_id': '108',
#    'treatment_type': 'compound based treatment'}},
#  154: {'_key': 154,
#   '_value': {'project_id': '50',
#    'treatment_type': 'compound based treatment'}},
#  155: {'_key': 155,
#   '_value': {'project_id': '50',
#    'treatment_type': 'compound based treatment'}},
#  156: {'_key': 156,
#   '_value': {'project_id': '142', 'treatment_type': 'abiotic stress'}},
#  157: {'_key': 157,
#   '_value': {'project_id': '50',
#    'treatment_type': 'compound based treatment'}},
#  158: {'_key': 158,
#   '_value': {'project_id': '111', 'treatment_type': 'abiotic stress'}},
#  159: {'_key': 159,
#   '_value': {'project_id': '112',
#    'treatment_type': 'compound based treatment'}},
#  160: {'_key': 160,
#   '_value': {'project_id': '145',
#    'treatment_type': 'compound based treatment'}},
#  161: {'_key': 161,
#   '_value': {'project_id': '114',
#    'treatment_type': 'compound based treatment'}},
#  162: {'_key': 162,
#   '_value': {'project_id': '119',
#    'treatment_type': 'environmental treatment'}},
#  163: {'_key': 163,
#   '_value': {'project_id': '119',
#    'treatment_type': 'environmental treatment'}},
#  164: {'_key': 164,
#   '_value': {'project_id': '119',
#    'treatment_type': 'environmental treatment'}},
#  165: {'_key': 165,
#   '_value': {'project_id': '119',
#    'treatment_type': 'environmental treatment'}},
#  166: {'_key': 166,
#   '_value': {'project_id': '119',
#    'treatment_type': 'environmental treatment'}},
#  167: {'_key': 167,
#   '_value': {'project_id': '119',
#    'treatment_type': 'environmental treatment'}},
#  168: {'_key': 168,
#   '_value': {'project_id': '121', 'treatment_type': 'genetic treatment'}},
#  169: {'_key': 169,
#   '_value': {'project_id': '198',
#    'treatment_type': 'environmental treatment'}},
#  170: {'_key': 170,
#   '_value': {'project_id': '121',
#    'treatment_type': 'compound based treatment'}},
#  171: {'_key': 171,
#   '_value': {'project_id': '121',
#    'treatment_type': 'compound based treatment'}},
#  172: {'_key': 172,
#   '_value': {'project_id': '123',
#    'treatment_type': 'environmental treatment'}},
#  173: {'_key': 173,
#   '_value': {'project_id': '123',
#    'treatment_type': 'environmental treatment'}},
#  174: {'_key': 174,
#   '_value': {'project_id': '124', 'treatment_type': 'time course study'}},
#  175: {'_key': 175,
#   '_value': {'project_id': '97', 'treatment_type': 'abiotic stress'}},
#  176: {'_key': 176,
#   '_value': {'project_id': '113',
#    'treatment_type': 'environmental treatment'}},
#  177: {'_key': 177,
#   '_value': {'project_id': '97', 'treatment_type': 'abiotic stress'}},
#  178: {'_key': 178,
#   '_value': {'project_id': '97', 'treatment_type': 'abiotic stress'}},
#  179: {'_key': 179,
#   '_value': {'project_id': '97', 'treatment_type': 'control buffer'}},
#  180: {'_key': 180,
#   '_value': {'project_id': '97', 'treatment_type': 'control buffer'}},
#  181: {'_key': 181,
#   '_value': {'project_id': '97', 'treatment_type': 'control buffer'}},
#  182: {'_key': 182,
#   '_value': {'project_id': '97', 'treatment_type': 'control buffer'}},
#  183: {'_key': 183,
#   '_value': {'project_id': '97', 'treatment_type': 'control buffer'}},
#  184: {'_key': 184,
#   '_value': {'project_id': '36', 'treatment_type': 'biotic stress'}},
#  185: {'_key': 185,
#   '_value': {'project_id': '36', 'treatment_type': 'biotic stress'}},
#  186: {'_key': 186,
#   '_value': {'project_id': '126', 'treatment_type': 'control buffer'}},
#  187: {'_key': 187,
#   '_value': {'project_id': '126',
#    'treatment_type': 'environmental treatment'}},
#  188: {'_key': 188,
#   '_value': {'project_id': '126',
#    'treatment_type': 'environmental treatment'}},
#  189: {'_key': 189,
#   '_value': {'project_id': '103', 'treatment_type': 'growth conditions'}},
#  190: {'_key': 190,
#   '_value': {'project_id': '126',
#    'treatment_type': 'environmental treatment'}},
#  191: {'_key': 191,
#   '_value': {'project_id': '129',
#    'treatment_type': 'environmental treatment'}},
#  192: {'_key': 192,
#   '_value': {'project_id': '48', 'treatment_type': 'biotic stress'}},
#  193: {'_key': 193,
#   '_value': {'project_id': '48', 'treatment_type': 'biotic stress'}},
#  194: {'_key': 194,
#   '_value': {'project_id': '131',
#    'treatment_type': 'compound based treatment'}},
#  195: {'_key': 195,
#   '_value': {'project_id': '131',
#    'treatment_type': 'compound based treatment'}},
#  196: {'_key': 196,
#   '_value': {'project_id': '131',
#    'treatment_type': 'compound based treatment'}},
#  197: {'_key': 197,
#   '_value': {'project_id': '131',
#    'treatment_type': 'compound based treatment'}},
#  198: {'_key': 198,
#   '_value': {'project_id': '131',
#    'treatment_type': 'compound based treatment'}},
#  199: {'_key': 199,
#   '_value': {'project_id': '131',
#    'treatment_type': 'compound based treatment'}},
#  200: {'_key': 200,
#   '_value': {'project_id': '131',
#    'treatment_type': 'compound based treatment'}},
#  201: {'_key': 201,
#   '_value': {'project_id': '131',
#    'treatment_type': 'compound based treatment'}},
#  202: {'_key': 202,
#   '_value': {'project_id': '103', 'treatment_type': 'growth conditions'}},
#  203: {'_key': 203,
#   '_value': {'project_id': '103', 'treatment_type': 'growth conditions'}},
#  204: {'_key': 204,
#   '_value': {'project_id': '103', 'treatment_type': 'growth conditions'}},
#  205: {'_key': 205,
#   '_value': {'project_id': '103', 'treatment_type': 'growth conditions'}},
#  206: {'_key': 206,
#   '_value': {'project_id': '103', 'treatment_type': 'growth conditions'}},
#  207: {'_key': 207,
#   '_value': {'project_id': '103', 'treatment_type': 'growth conditions'}},
#  208: {'_key': 208,
#   '_value': {'project_id': '144',
#    'treatment_type': 'environmental treatment'}},
#  209: {'_key': 209,
#   '_value': {'project_id': '303',
#    'treatment_type': 'environmental treatment'}},
#  210: {'_key': 210,
#   '_value': {'project_id': '103', 'treatment_type': 'growth conditions'}},
#  211: {'_key': 211,
#   '_value': {'project_id': '103', 'treatment_type': 'growth conditions'}},
#  212: {'_key': 212,
#   '_value': {'project_id': '130',
#    'treatment_type': 'compound based treatment'}},
#  213: {'_key': 213,
#   '_value': {'project_id': '103', 'treatment_type': 'growth conditions'}},
#  214: {'_key': 214,
#   '_value': {'project_id': '103', 'treatment_type': 'growth conditions'}},
#  215: {'_key': 215,
#   '_value': {'project_id': '133', 'treatment_type': 'pathogen'}},
#  216: {'_key': 216,
#   '_value': {'project_id': '133', 'treatment_type': 'pathogen'}},
#  217: {'_key': 217,
#   '_value': {'project_id': '132', 'treatment_type': 'growth conditions'}},
#  218: {'_key': 218,
#   '_value': {'project_id': '132', 'treatment_type': 'growth conditions'}},
#  219: {'_key': 219,
#   '_value': {'project_id': '132', 'treatment_type': 'growth conditions'}},
#  220: {'_key': 220,
#   '_value': {'project_id': '132', 'treatment_type': 'growth conditions'}},
#  221: {'_key': 221,
#   '_value': {'project_id': '132', 'treatment_type': 'growth conditions'}},
#  222: {'_key': 222,
#   '_value': {'project_id': '132', 'treatment_type': 'growth conditions'}},
#  223: {'_key': 223,
#   '_value': {'project_id': '132', 'treatment_type': 'growth conditions'}},
#  224: {'_key': 224,
#   '_value': {'project_id': '132', 'treatment_type': 'growth conditions'}},
#  225: {'_key': 225,
#   '_value': {'project_id': '132', 'treatment_type': 'growth conditions'}},
#  226: {'_key': 226,
#   '_value': {'project_id': '105',
#    'treatment_type': 'compound based treatment'}},
#  227: {'_key': 227,
#   '_value': {'project_id': '117', 'treatment_type': 'growth conditions'}},
#  228: {'_key': 228,
#   '_value': {'project_id': '118', 'treatment_type': 'pathogen'}},
#  229: {'_key': 229,
#   '_value': {'project_id': '118', 'treatment_type': 'control buffer'}},
#  230: {'_key': 230,
#   '_value': {'project_id': '118', 'treatment_type': 'pathogen'}},
#  231: {'_key': 231,
#   '_value': {'project_id': '118', 'treatment_type': 'pathogen'}},
#  232: {'_key': 232,
#   '_value': {'project_id': '149',
#    'treatment_type': 'environmental treatment'}},
#  233: {'_key': 233,
#   '_value': {'project_id': '179',
#    'treatment_type': 'compound based treatment'}},
#  234: {'_key': 234,
#   '_value': {'project_id': '145',
#    'treatment_type': 'compound based treatment'}},
#  235: {'_key': 235,
#   '_value': {'project_id': '179',
#    'treatment_type': 'compound based treatment'}},
#  236: {'_key': 236,
#   '_value': {'project_id': '117', 'treatment_type': 'growth conditions'}},
#  237: {'_key': 237,
#   '_value': {'project_id': '117', 'treatment_type': 'growth conditions'}},
#  238: {'_key': 238,
#   '_value': {'project_id': '147', 'treatment_type': 'genetic treatment'}},
#  239: {'_key': 239,
#   '_value': {'project_id': '117', 'treatment_type': 'growth conditions'}},
#  240: {'_key': 240,
#   '_value': {'project_id': '117', 'treatment_type': 'growth conditions'}},
#  241: {'_key': 241,
#   '_value': {'project_id': '117', 'treatment_type': 'growth conditions'}},
#  242: {'_key': 242,
#   '_value': {'project_id': '179',
#    'treatment_type': 'compound based treatment'}},
#  243: {'_key': 243,
#   '_value': {'project_id': '148', 'treatment_type': 'biotic stress'}},
#  244: {'_key': 244,
#   '_value': {'project_id': '148', 'treatment_type': 'biotic stress'}},
#  245: {'_key': 245,
#   '_value': {'project_id': '148', 'treatment_type': 'control buffer'}},
#  246: {'_key': 246,
#   '_value': {'project_id': '113', 'treatment_type': 'biotic stress'}},
#  247: {'_key': 247,
#   '_value': {'project_id': '179',
#    'treatment_type': 'compound based treatment'}},
#  248: {'_key': 248,
#   '_value': {'project_id': '113',
#    'treatment_type': 'environmental treatment'}},
#  249: {'_key': 249,
#   '_value': {'project_id': '124', 'treatment_type': 'time course study'}},
#  250: {'_key': 250,
#   '_value': {'project_id': '183', 'treatment_type': 'growth conditions'}},
#  251: {'_key': 251,
#   '_value': {'project_id': '144',
#    'treatment_type': 'environmental treatment'}},
#  252: {'_key': 252,
#   '_value': {'project_id': '145',
#    'treatment_type': 'compound based treatment'}},
#  253: {'_key': 253,
#   '_value': {'project_id': '138',
#    'treatment_type': 'environmental treatment'}},
#  254: {'_key': 254,
#   '_value': {'project_id': '165', 'treatment_type': 'control buffer'}},
#  255: {'_key': 255,
#   '_value': {'project_id': '161',
#    'treatment_type': 'compound based treatment'}},
#  256: {'_key': 256,
#   '_value': {'project_id': '160', 'treatment_type': 'pathogen'}},
#  257: {'_key': 257,
#   '_value': {'project_id': '160', 'treatment_type': 'pathogen'}},
#  258: {'_key': 258,
#   '_value': {'project_id': '161',
#    'treatment_type': 'compound based treatment'}},
#  259: {'_key': 259,
#   '_value': {'project_id': '160', 'treatment_type': 'pathogen'}},
#  260: {'_key': 260,
#   '_value': {'project_id': '160', 'treatment_type': 'pathogen'}},
#  261: {'_key': 261,
#   '_value': {'project_id': '161',
#    'treatment_type': 'compound based treatment'}},
#  262: {'_key': 262,
#   '_value': {'project_id': '160', 'treatment_type': 'pathogen'}},
#  263: {'_key': 263,
#   '_value': {'project_id': '160', 'treatment_type': 'pathogen'}},
#  264: {'_key': 264,
#   '_value': {'project_id': '61', 'treatment_type': 'biotic stress'}},
#  265: {'_key': 265,
#   '_value': {'project_id': '61', 'treatment_type': 'biotic stress'}},
#  266: {'_key': 266,
#   '_value': {'project_id': '146',
#    'treatment_type': 'compound based treatment'}},
#  267: {'_key': 267,
#   '_value': {'project_id': '100', 'treatment_type': 'control buffer'}},
#  268: {'_key': 268,
#   '_value': {'project_id': '161',
#    'treatment_type': 'compound based treatment'}},
#  269: {'_key': 269,
#   '_value': {'project_id': '165', 'treatment_type': 'abiotic stress'}},
#  270: {'_key': 270,
#   '_value': {'project_id': '166', 'treatment_type': 'gene induction'}},
#  271: {'_key': 271,
#   '_value': {'project_id': '168', 'treatment_type': 'abiotic stress'}},
#  272: {'_key': 272,
#   '_value': {'project_id': '172', 'treatment_type': 'abiotic stress'}},
#  273: {'_key': 273,
#   '_value': {'project_id': '163',
#    'treatment_type': 'environmental treatment'}},
#  274: {'_key': 274,
#   '_value': {'project_id': '149',
#    'treatment_type': 'environmental treatment'}},
#  275: {'_key': 275,
#   '_value': {'project_id': '186', 'treatment_type': 'control buffer'}},
#  276: {'_key': 276,
#   '_value': {'project_id': '197',
#    'treatment_type': 'compound based treatment'}},
#  277: {'_key': 277,
#   '_value': {'project_id': '149',
#    'treatment_type': 'environmental treatment'}},
#  278: {'_key': 278,
#   '_value': {'project_id': '193',
#    'treatment_type': 'compound based treatment'}},
#  279: {'_key': 279,
#   '_value': {'project_id': '186', 'treatment_type': 'control buffer'}},
#  280: {'_key': 280,
#   '_value': {'project_id': '186',
#    'treatment_type': 'compound based treatment'}},
#  281: {'_key': 281,
#   '_value': {'project_id': '183', 'treatment_type': 'growth conditions'}},
#  282: {'_key': 282,
#   '_value': {'project_id': '186',
#    'treatment_type': 'compound based treatment'}},
#  283: {'_key': 283,
#   '_value': {'project_id': '187', 'treatment_type': 'abiotic stress'}},
#  284: {'_key': 284,
#   '_value': {'project_id': '197',
#    'treatment_type': 'compound based treatment'}},
#  285: {'_key': 285,
#   '_value': {'project_id': '193',
#    'treatment_type': 'compound based treatment'}},
#  286: {'_key': 286,
#   '_value': {'project_id': '188',
#    'treatment_type': 'limited nitrogen supply'}},
#  287: {'_key': 287,
#   '_value': {'project_id': '188',
#    'treatment_type': 'limited nitrogen supply'}},
#  288: {'_key': 288,
#   '_value': {'project_id': '188',
#    'treatment_type': 'sufficient nitrogen supply'}},
#  289: {'_key': 289,
#   '_value': {'project_id': '188',
#    'treatment_type': 'sufficient nitrogen supply'}},
#  290: {'_key': 290,
#   '_value': {'project_id': '197',
#    'treatment_type': 'environmental treatment'}},
#  291: {'_key': 291,
#   '_value': {'project_id': '193',
#    'treatment_type': 'compound based treatment'}},
#  292: {'_key': 292,
#   '_value': {'project_id': '193',
#    'treatment_type': 'environmental treatment'}},
#  293: {'_key': 293,
#   '_value': {'project_id': '193', 'treatment_type': 'control buffer'}},
#  294: {'_key': 294,
#   '_value': {'project_id': '149',
#    'treatment_type': 'environmental treatment'}},
#  295: {'_key': 295,
#   '_value': {'project_id': '154',
#    'treatment_type': 'environmental treatment'}},
#  296: {'_key': 296,
#   '_value': {'project_id': '154',
#    'treatment_type': 'environmental treatment'}},
#  297: {'_key': 297,
#   '_value': {'project_id': '154', 'treatment_type': 'abiotic stress'}},
#  298: {'_key': 298,
#   '_value': {'project_id': '180',
#    'treatment_type': 'environmental treatment'}},
#  299: {'_key': 299,
#   '_value': {'project_id': '180',
#    'treatment_type': 'environmental treatment'}},
#  300: {'_key': 300,
#   '_value': {'project_id': '180',
#    'treatment_type': 'environmental treatment'}},
#  301: {'_key': 301,
#   '_value': {'project_id': '181',
#    'treatment_type': 'environmental treatment'}},
#  302: {'_key': 302,
#   '_value': {'project_id': '210', 'treatment_type': 'syringe-inoculation'}},
#  303: {'_key': 303,
#   '_value': {'project_id': '193',
#    'treatment_type': 'compound based treatment'}},
#  304: {'_key': 304,
#   '_value': {'project_id': '198',
#    'treatment_type': 'environmental treatment'}},
#  305: {'_key': 305,
#   '_value': {'project_id': '198',
#    'treatment_type': 'environmental treatment'}},
#  306: {'_key': 306,
#   '_value': {'project_id': '305', 'treatment_type': 'induction'}},
#  307: {'_key': 307,
#   '_value': {'project_id': '198',
#    'treatment_type': 'environmental treatment'}},
#  308: {'_key': 308,
#   '_value': {'project_id': '198',
#    'treatment_type': 'environmental treatment'}},
#  309: {'_key': 309,
#   '_value': {'project_id': '198',
#    'treatment_type': 'environmental treatment'}},
#  310: {'_key': 310,
#   '_value': {'project_id': '199', 'treatment_type': 'time course study'}},
#  311: {'_key': 311,
#   '_value': {'project_id': '199', 'treatment_type': 'time course study'}},
#  312: {'_key': 312,
#   '_value': {'project_id': '199', 'treatment_type': 'time course study'}},
#  313: {'_key': 313,
#   '_value': {'project_id': '200', 'treatment_type': 'control'}},
#  314: {'_key': 314,
#   '_value': {'project_id': '210', 'treatment_type': 'syringe-inoculation'}},
#  315: {'_key': 315,
#   '_value': {'project_id': '201',
#    'treatment_type': 'environmental treatment'}},
#  316: {'_key': 316,
#   '_value': {'project_id': '203', 'treatment_type': 'abiotic stress'}},
#  317: {'_key': 317,
#   '_value': {'project_id': '203', 'treatment_type': 'abiotic stress'}},
#  318: {'_key': 318,
#   '_value': {'project_id': '202', 'treatment_type': 'control'}},
#  319: {'_key': 319,
#   '_value': {'project_id': '202', 'treatment_type': 'abiotic stress'}},
#  320: {'_key': 320,
#   '_value': {'project_id': '202', 'treatment_type': 'abiotic stress'}},
#  321: {'_key': 321,
#   '_value': {'project_id': '202', 'treatment_type': 'abiotic stress'}},
#  322: {'_key': 322,
#   '_value': {'project_id': '202', 'treatment_type': 'abiotic stress'}},
#  323: {'_key': 323,
#   '_value': {'project_id': '210', 'treatment_type': 'syringe-inoculation'}},
#  324: {'_key': 324,
#   '_value': {'project_id': '211',
#    'treatment_type': 'environmental treatment'}},
#  325: {'_key': 325,
#   '_value': {'project_id': '234', 'treatment_type': 'time course study'}},
#  326: {'_key': 326,
#   '_value': {'project_id': '216', 'treatment_type': 'time course study'}},
#  327: {'_key': 327,
#   '_value': {'project_id': '212', 'treatment_type': 'pathogen'}},
#  328: {'_key': 328,
#   '_value': {'project_id': '144',
#    'treatment_type': 'environmental treatment'}},
#  329: {'_key': 329,
#   '_value': {'project_id': '216', 'treatment_type': 'time course study'}},
#  330: {'_key': 330,
#   '_value': {'project_id': '233', 'treatment_type': 'time course study'}},
#  331: {'_key': 331,
#   '_value': {'project_id': '305', 'treatment_type': 'induction'}},
#  332: {'_key': 332,
#   '_value': {'project_id': '331', 'treatment_type': 'nothing'}},
#  333: {'_key': 333,
#   '_value': {'project_id': '216', 'treatment_type': 'time course study'}},
#  334: {'_key': 334,
#   '_value': {'project_id': '216', 'treatment_type': 'time course study'}},
#  335: {'_key': 335,
#   '_value': {'project_id': '16', 'treatment_type': 'gene induction'}},
#  336: {'_key': 336,
#   '_value': {'project_id': '16', 'treatment_type': 'environmental treatment'}},
#  337: {'_key': 337,
#   '_value': {'project_id': '16', 'treatment_type': 'environmental treatment'}},
#  338: {'_key': 338,
#   '_value': {'project_id': '221', 'treatment_type': 'pathogen'}},
#  339: {'_key': 339,
#   '_value': {'project_id': '224', 'treatment_type': 'biotic stress'}},
#  340: {'_key': 340,
#   '_value': {'project_id': '224', 'treatment_type': 'biotic stress'}},
#  341: {'_key': 341,
#   '_value': {'project_id': '224', 'treatment_type': 'control buffer'}},
#  342: {'_key': 342,
#   '_value': {'project_id': '148', 'treatment_type': 'biotic stress'}},
#  343: {'_key': 343,
#   '_value': {'project_id': '148', 'treatment_type': 'biotic stress'}},
#  344: {'_key': 344,
#   '_value': {'project_id': '231', 'treatment_type': 'nematode inoculation'}},
#  345: {'_key': 345,
#   '_value': {'project_id': '148', 'treatment_type': 'control buffer'}},
#  346: {'_key': 346,
#   '_value': {'project_id': '224', 'treatment_type': 'biotic stress'}},
#  347: {'_key': 347,
#   '_value': {'project_id': '233', 'treatment_type': 'time course study'}},
#  348: {'_key': 348,
#   '_value': {'project_id': '230', 'treatment_type': 'time course study'}},
#  349: {'_key': 349,
#   '_value': {'project_id': '238',
#    'treatment_type': 'environmental treatment'}},
#  350: {'_key': 350,
#   '_value': {'project_id': '230', 'treatment_type': 'time course study'}},
#  351: {'_key': 351,
#   '_value': {'project_id': '222', 'treatment_type': 'hormone treatment'}},
#  352: {'_key': 352,
#   '_value': {'project_id': '234', 'treatment_type': 'time course study'}},
#  353: {'_key': 353,
#   '_value': {'project_id': '234', 'treatment_type': 'time course study'}},
#  354: {'_key': 354,
#   '_value': {'project_id': '233', 'treatment_type': 'time course study'}},
#  355: {'_key': 355,
#   '_value': {'project_id': '238',
#    'treatment_type': 'environmental treatment'}},
#  356: {'_key': 356,
#   '_value': {'project_id': '233', 'treatment_type': 'time course study'}},
#  357: {'_key': 357,
#   '_value': {'project_id': '305', 'treatment_type': 'induction'}},
#  358: {'_key': 358,
#   '_value': {'project_id': '233', 'treatment_type': 'time course study'}},
#  359: {'_key': 359,
#   '_value': {'project_id': '233', 'treatment_type': 'time course study'}},
#  360: {'_key': 360,
#   '_value': {'project_id': '233', 'treatment_type': 'time course study'}},
#  361: {'_key': 361,
#   '_value': {'project_id': '233', 'treatment_type': 'time course study'}},
#  362: {'_key': 362,
#   '_value': {'project_id': '174',
#    'treatment_type': 'compound based treatment'}},
#  363: {'_key': 363,
#   '_value': {'project_id': '174',
#    'treatment_type': 'compound based treatment'}},
#  364: {'_key': 364,
#   '_value': {'project_id': '238',
#    'treatment_type': 'environmental treatment'}},
#  365: {'_key': 365,
#   '_value': {'project_id': '238',
#    'treatment_type': 'environmental treatment'}},
#  366: {'_key': 366,
#   '_value': {'project_id': '246', 'treatment_type': 'biotic stress'}},
#  367: {'_key': 367,
#   '_value': {'project_id': '174',
#    'treatment_type': 'compound based treatment'}},
#  368: {'_key': 368,
#   '_value': {'project_id': '241', 'treatment_type': 'inoculation'}},
#  369: {'_key': 369,
#   '_value': {'project_id': '174',
#    'treatment_type': 'compound based treatment'}},
#  370: {'_key': 370,
#   '_value': {'project_id': '248',
#    'treatment_type': 'compound based treatment'}},
#  371: {'_key': 371,
#   '_value': {'project_id': '263', 'treatment_type': 'inoculation'}},
#  372: {'_key': 372,
#   '_value': {'project_id': '263', 'treatment_type': 'time course study'}},
#  373: {'_key': 373,
#   '_value': {'project_id': '263',
#    'treatment_type': 'with euteiches,inoculation'}},
#  374: {'_key': 374,
#   '_value': {'project_id': '263', 'treatment_type': 'inoculation'}},
#  375: {'_key': 375,
#   '_value': {'project_id': '261',
#    'treatment_type': 'environmental treatment'}},
#  376: {'_key': 376,
#   '_value': {'project_id': '261',
#    'treatment_type': 'environmental treatment'}},
#  377: {'_key': 377,
#   '_value': {'project_id': '265', 'treatment_type': 'control'}},
#  378: {'_key': 378,
#   '_value': {'project_id': '238',
#    'treatment_type': 'environmental treatment'}},
#  379: {'_key': 379,
#   '_value': {'project_id': '62', 'treatment_type': 'abiotic stress'}},
#  380: {'_key': 380,
#   '_value': {'project_id': '238',
#    'treatment_type': 'environmental treatment'}},
#  381: {'_key': 381,
#   '_value': {'project_id': '265', 'treatment_type': 'control buffer'}},
#  382: {'_key': 382,
#   '_value': {'project_id': '240', 'treatment_type': 'pathogen'}},
#  383: {'_key': 383,
#   '_value': {'project_id': '240', 'treatment_type': 'pathogen'}},
#  384: {'_key': 384,
#   '_value': {'project_id': '240', 'treatment_type': 'pathogen'}},
#  385: {'_key': 385,
#   '_value': {'project_id': '240', 'treatment_type': 'control'}},
#  386: {'_key': 386,
#   '_value': {'project_id': '259',
#    'treatment_type': 'compound based treatment'}},
#  387: {'_key': 387,
#   '_value': {'project_id': '259',
#    'treatment_type': 'compound based treatment'}},
#  388: {'_key': 388,
#   '_value': {'project_id': '265',
#    'treatment_type': 'environmental treatment'}},
#  389: {'_key': 389,
#   '_value': {'project_id': '265',
#    'treatment_type': 'environmental treatment'}},
#  390: {'_key': 390,
#   '_value': {'project_id': '265',
#    'treatment_type': 'environmental treatment'}},
#  391: {'_key': 391,
#   '_value': {'project_id': '265',
#    'treatment_type': 'environmental treatment'}},
#  392: {'_key': 392,
#   '_value': {'project_id': '265',
#    'treatment_type': 'environmental treatment'}},
#  393: {'_key': 393,
#   '_value': {'project_id': '265',
#    'treatment_type': 'environmental treatment'}},
#  394: {'_key': 394,
#   '_value': {'project_id': '265',
#    'treatment_type': 'environmental treatment'}},
#  395: {'_key': 395,
#   '_value': {'project_id': '266',
#    'treatment_type': 'environmental treatment'}},
#  396: {'_key': 396,
#   '_value': {'project_id': '266',
#    'treatment_type': 'environmental treatment'}},
#  397: {'_key': 397,
#   '_value': {'project_id': '266',
#    'treatment_type': 'environmental treatment'}},
#  398: {'_key': 398,
#   '_value': {'project_id': '288', 'treatment_type': 'syringe-inoculation'}},
#  399: {'_key': 399,
#   '_value': {'project_id': '300', 'treatment_type': 'time course study'}},
#  400: {'_key': 400,
#   '_value': {'project_id': '266',
#    'treatment_type': 'environmental treatment'}},
#  401: {'_key': 401,
#   '_value': {'project_id': '267',
#    'treatment_type': 'compound based treatment'}},
#  402: {'_key': 402,
#   '_value': {'project_id': '270',
#    'treatment_type': 'compound based treatment'}},
#  403: {'_key': 403,
#   '_value': {'project_id': '270',
#    'treatment_type': 'compound based treatment'}},
#  404: {'_key': 404,
#   '_value': {'project_id': '271',
#    'treatment_type': 'environmental treatment'}},
#  405: {'_key': 405,
#   '_value': {'project_id': '272',
#    'treatment_type': 'environmental treatment'}},
#  406: {'_key': 406,
#   '_value': {'project_id': '272',
#    'treatment_type': 'environmental treatment'}},
#  407: {'_key': 407,
#   '_value': {'project_id': '281',
#    'treatment_type': 'inoculation with a. euteiches,time course study'}},
#  408: {'_key': 408,
#   '_value': {'project_id': '271',
#    'treatment_type': 'environmental treatment'}},
#  409: {'_key': 409,
#   '_value': {'project_id': '271',
#    'treatment_type': 'environmental treatment'}},
#  410: {'_key': 410,
#   '_value': {'project_id': '280', 'treatment_type': 'biotic stress'}},
#  411: {'_key': 411,
#   '_value': {'project_id': '280', 'treatment_type': 'biotic stress'}},
#  412: {'_key': 412,
#   '_value': {'project_id': '286',
#    'treatment_type': 'compound based treatment'}},
#  413: {'_key': 413,
#   '_value': {'project_id': '286',
#    'treatment_type': 'compound based treatment'}},
#  414: {'_key': 414,
#   '_value': {'project_id': '286',
#    'treatment_type': 'compound based treatment'}},
#  415: {'_key': 415,
#   '_value': {'project_id': '286',
#    'treatment_type': 'compound based treatment'}},
#  416: {'_key': 416,
#   '_value': {'project_id': '286',
#    'treatment_type': 'compound based treatment'}},
#  417: {'_key': 417,
#   '_value': {'project_id': '286',
#    'treatment_type': 'compound based treatment'}},
#  418: {'_key': 418,
#   '_value': {'project_id': '286',
#    'treatment_type': 'compound based treatment'}},
#  419: {'_key': 419,
#   '_value': {'project_id': '285',
#    'treatment_type': 'environmental treatment'}},
#  420: {'_key': 420,
#   '_value': {'project_id': '285',
#    'treatment_type': 'environmental treatment'}},
#  421: {'_key': 421,
#   '_value': {'project_id': '285',
#    'treatment_type': 'environmental treatment'}},
#  422: {'_key': 422,
#   '_value': {'project_id': '285',
#    'treatment_type': 'environmental treatment'}},
#  423: {'_key': 423,
#   '_value': {'project_id': '300', 'treatment_type': 'time course study'}},
#  424: {'_key': 424,
#   '_value': {'project_id': '313', 'treatment_type': 'hormone treatment'}},
#  425: {'_key': 425,
#   '_value': {'project_id': '289',
#    'treatment_type': 'compound based treatment'}},
#  426: {'_key': 426,
#   '_value': {'project_id': '289',
#    'treatment_type': 'compound based treatment'}},
#  427: {'_key': 427,
#   '_value': {'project_id': '290',
#    'treatment_type': 'environmental treatment'}},
#  428: {'_key': 428,
#   '_value': {'project_id': '286',
#    'treatment_type': 'compound based treatment'}},
#  429: {'_key': 429,
#   '_value': {'project_id': '286',
#    'treatment_type': 'compound based treatment'}},
#  430: {'_key': 430,
#   '_value': {'project_id': '286',
#    'treatment_type': 'compound based treatment'}},
#  431: {'_key': 431,
#   '_value': {'project_id': '285',
#    'treatment_type': 'environmental treatment'}},
#  432: {'_key': 432,
#   '_value': {'project_id': '290',
#    'treatment_type': 'environmental treatment'}},
#  433: {'_key': 433,
#   '_value': {'project_id': '290',
#    'treatment_type': 'environmental treatment'}},
#  434: {'_key': 434,
#   '_value': {'project_id': '291', 'treatment_type': 'abiotic stress'}},
#  435: {'_key': 435,
#   '_value': {'project_id': '291', 'treatment_type': 'abiotic stress'}},
#  436: {'_key': 436,
#   '_value': {'project_id': '294',
#    'treatment_type': 'environmental treatment'}},
#  437: {'_key': 437,
#   '_value': {'project_id': '294',
#    'treatment_type': 'environmental treatment'}},
#  438: {'_key': 438,
#   '_value': {'project_id': '294',
#    'treatment_type': 'environmental treatment'}},
#  439: {'_key': 439,
#   '_value': {'project_id': '294',
#    'treatment_type': 'environmental treatment'}},
#  440: {'_key': 440,
#   '_value': {'project_id': '297', 'treatment_type': 'induction'}},
#  441: {'_key': 441,
#   '_value': {'project_id': '298',
#    'treatment_type': 'compound based treatment'}},
#  442: {'_key': 442,
#   '_value': {'project_id': '298',
#    'treatment_type': 'compound based treatment'}},
#  443: {'_key': 443,
#   '_value': {'project_id': '300', 'treatment_type': 'time course study'}},
#  444: {'_key': 444,
#   '_value': {'project_id': '307',
#    'treatment_type': 'environmental treatment'}},
#  445: {'_key': 445,
#   '_value': {'project_id': '300', 'treatment_type': 'time course study'}},
#  446: {'_key': 446,
#   '_value': {'project_id': '300', 'treatment_type': 'time course study'}},
#  447: {'_key': 447,
#   '_value': {'project_id': '301',
#    'treatment_type': 'compound based treatment'}},
#  448: {'_key': 448,
#   '_value': {'project_id': '301',
#    'treatment_type': 'compound based treatment'}},
#  449: {'_key': 449,
#   '_value': {'project_id': '301',
#    'treatment_type': 'compound based treatment'}},
#  450: {'_key': 450,
#   '_value': {'project_id': '301',
#    'treatment_type': 'compound based treatment'}},
#  451: {'_key': 451,
#   '_value': {'project_id': '301',
#    'treatment_type': 'compound based treatment'}},
#  452: {'_key': 452,
#   '_value': {'project_id': '299', 'treatment_type': 'pathogen'}},
#  453: {'_key': 453,
#   '_value': {'project_id': '299', 'treatment_type': 'pathogen'}},
#  454: {'_key': 454,
#   '_value': {'project_id': '299', 'treatment_type': 'pathogen'}},
#  455: {'_key': 455,
#   '_value': {'project_id': '299', 'treatment_type': 'pathogen'}},
#  456: {'_key': 456,
#   '_value': {'project_id': '299', 'treatment_type': 'pathogen'}},
#  457: {'_key': 457,
#   '_value': {'project_id': '299', 'treatment_type': 'pathogen'}},
#  458: {'_key': 458,
#   '_value': {'project_id': '299', 'treatment_type': 'pathogen'}},
#  459: {'_key': 459,
#   '_value': {'project_id': '299', 'treatment_type': 'pathogen'}},
#  460: {'_key': 460,
#   '_value': {'project_id': '299', 'treatment_type': 'pathogen'}},
#  461: {'_key': 461,
#   '_value': {'project_id': '299', 'treatment_type': 'pathogen'}},
#  462: {'_key': 462,
#   '_value': {'project_id': '299', 'treatment_type': 'pathogen'}},
#  463: {'_key': 463,
#   '_value': {'project_id': '299', 'treatment_type': 'pathogen'}},
#  464: {'_key': 464,
#   '_value': {'project_id': '299', 'treatment_type': 'pathogen'}},
#  465: {'_key': 465,
#   '_value': {'project_id': '299', 'treatment_type': 'pathogen'}},
#  466: {'_key': 466,
#   '_value': {'project_id': '299', 'treatment_type': 'pathogen'}},
#  467: {'_key': 467,
#   '_value': {'project_id': '303',
#    'treatment_type': 'environmental treatment'}},
#  468: {'_key': 468,
#   '_value': {'project_id': '303',
#    'treatment_type': 'environmental treatment'}},
#  469: {'_key': 469,
#   '_value': {'project_id': '356',
#    'treatment_type': 'compound based treatment'}},
#  470: {'_key': 470,
#   '_value': {'project_id': '308',
#    'treatment_type': 'environmental treatment'}},
#  471: {'_key': 471,
#   '_value': {'project_id': '308',
#    'treatment_type': 'environmental treatment'}},
#  472: {'_key': 472,
#   '_value': {'project_id': '308',
#    'treatment_type': 'compound based treatment'}},
#  473: {'_key': 473,
#   '_value': {'project_id': '310',
#    'treatment_type': 'environmental treatment'}},
#  474: {'_key': 474,
#   '_value': {'project_id': '310',
#    'treatment_type': 'other inoculation ,environmental treatment'}},
#  475: {'_key': 475,
#   '_value': {'project_id': '310', 'treatment_type': 'abiotic stress'}},
#  476: {'_key': 476,
#   '_value': {'project_id': '310',
#    'treatment_type': 'other inoculation ,environmental treatment'}},
#  477: {'_key': 477,
#   '_value': {'project_id': '316',
#    'treatment_type': 'compound based treatment'}},
#  478: {'_key': 478,
#   '_value': {'project_id': '316',
#    'treatment_type': 'compound based treatment'}},
#  479: {'_key': 479,
#   '_value': {'project_id': '316',
#    'treatment_type': 'compound based treatment'}},
#  480: {'_key': 480,
#   '_value': {'project_id': '316',
#    'treatment_type': 'compound based treatment'}},
#  481: {'_key': 481,
#   '_value': {'project_id': '356',
#    'treatment_type': 'compound based treatment'}},
#  482: {'_key': 482,
#   '_value': {'project_id': '321', 'treatment_type': 'storage -20°c'}},
#  483: {'_key': 483,
#   '_value': {'project_id': '321', 'treatment_type': 'storage -20°c'}},
#  484: {'_key': 484,
#   '_value': {'project_id': '321', 'treatment_type': 'storage -20°c'}},
#  485: {'_key': 485,
#   '_value': {'project_id': '321', 'treatment_type': 'storage +20°c 2 mois'}},
#  486: {'_key': 486,
#   '_value': {'project_id': '321', 'treatment_type': 'storage +20°c 2 mois'}},
#  487: {'_key': 487,
#   '_value': {'project_id': '321', 'treatment_type': 'storage +20°c 2 mois'}},
#  488: {'_key': 488,
#   '_value': {'project_id': '320', 'treatment_type': 'inoculation'}},
#  489: {'_key': 489,
#   '_value': {'project_id': '320', 'treatment_type': 'infection'}},
#  490: {'_key': 490,
#   '_value': {'project_id': '320', 'treatment_type': 'pathogen'}},
#  491: {'_key': 491,
#   '_value': {'project_id': '320', 'treatment_type': 'inoculation'}},
#  492: {'_key': 492,
#   '_value': {'project_id': '307',
#    'treatment_type': 'environmental treatment'}},
#  493: {'_key': 493,
#   '_value': {'project_id': '325',
#    'treatment_type': 'compound based treatment'}},
#  494: {'_key': 494,
#   '_value': {'project_id': '325',
#    'treatment_type': 'compound based treatment'}},
#  495: {'_key': 495,
#   '_value': {'project_id': '325',
#    'treatment_type': 'compound based treatment'}},
#  496: {'_key': 496,
#   '_value': {'project_id': '325',
#    'treatment_type': 'compound based treatment'}},
#  497: {'_key': 497,
#   '_value': {'project_id': '325',
#    'treatment_type': 'compound based treatment'}},
#  498: {'_key': 498,
#   '_value': {'project_id': '325',
#    'treatment_type': 'compound based treatment'}},
#  499: {'_key': 499,
#   '_value': {'project_id': '325',
#    'treatment_type': 'compound based treatment'}},
#  500: {'_key': 500,
#   '_value': {'project_id': '325',
#    'treatment_type': 'compound based treatment'}},
#  501: {'_key': 501,
#   '_value': {'project_id': '325',
#    'treatment_type': 'compound based treatment'}},
#  502: {'_key': 502,
#   '_value': {'project_id': '328',
#    'treatment_type': 'environmental treatment'}},
#  503: {'_key': 503,
#   '_value': {'project_id': '328',
#    'treatment_type': 'environmental treatment'}},
#  504: {'_key': 504,
#   '_value': {'project_id': '329', 'treatment_type': 'nothing'}},
#  505: {'_key': 505,
#   '_value': {'project_id': '329', 'treatment_type': 'nothing'}},
#  506: {'_key': 506,
#   '_value': {'project_id': '329', 'treatment_type': 'nothing'}},
#  507: {'_key': 507,
#   '_value': {'project_id': '323',
#    'treatment_type': 'inoculation with a. euteiches,environmental treatment'}},
#  508: {'_key': 508,
#   '_value': {'project_id': '323', 'treatment_type': 'no treatment'}},
#  509: {'_key': 509,
#   '_value': {'project_id': '307',
#    'treatment_type': 'environmental treatment'}},
#  510: {'_key': 510,
#   '_value': {'project_id': '307',
#    'treatment_type': 'environmental treatment'}},
#  511: {'_key': 511,
#   '_value': {'project_id': '307',
#    'treatment_type': 'environmental treatment'}},
#  512: {'_key': 512,
#   '_value': {'project_id': '307',
#    'treatment_type': 'environmental treatment'}},
#  513: {'_key': 513,
#   '_value': {'project_id': '307',
#    'treatment_type': 'environmental treatment'}},
#  514: {'_key': 514,
#   '_value': {'project_id': '332',
#    'treatment_type': 'environmental treatment'}},
#  515: {'_key': 515,
#   '_value': {'project_id': '335',
#    'treatment_type': 'compound based treatment'}},
#  516: {'_key': 516,
#   '_value': {'project_id': '335',
#    'treatment_type': 'compound based treatment'}},
#  517: {'_key': 517,
#   '_value': {'project_id': '338', 'treatment_type': 'abiotic stress'}},
#  518: {'_key': 518,
#   '_value': {'project_id': '339',
#    'treatment_type': 'environmental treatment'}},
#  519: {'_key': 519,
#   '_value': {'project_id': '339',
#    'treatment_type': 'environmental treatment'}},
#  520: {'_key': 520,
#   '_value': {'project_id': '341',
#    'treatment_type': 'compound based treatment'}},
#  521: {'_key': 521,
#   '_value': {'project_id': '341',
#    'treatment_type': 'compound based treatment'}},
#  522: {'_key': 522,
#   '_value': {'project_id': '343', 'treatment_type': 'control'}},
#  523: {'_key': 523,
#   '_value': {'project_id': '344',
#    'treatment_type': 'compound based treatment'}},
#  524: {'_key': 524,
#   '_value': {'project_id': '344',
#    'treatment_type': 'compound based treatment'}},
#  525: {'_key': 525,
#   '_value': {'project_id': '343', 'treatment_type': 'growth conditions'}},
#  526: {'_key': 526,
#   '_value': {'project_id': '343', 'treatment_type': 'growth conditions'}},
#  527: {'_key': 527,
#   '_value': {'project_id': '343', 'treatment_type': 'growth conditions'}},
#  528: {'_key': 528,
#   '_value': {'project_id': '351',
#    'treatment_type': 'compound based treatment'}},
#  529: {'_key': 529,
#   '_value': {'project_id': '351',
#    'treatment_type': 'compound based treatment'}},
#  530: {'_key': 530,
#   '_value': {'project_id': '351',
#    'treatment_type': 'compound based treatment'}},
#  531: {'_key': 531,
#   '_value': {'project_id': '356',
#    'treatment_type': 'compound based treatment'}},
#  532: {'_key': 532,
#   '_value': {'project_id': '354', 'treatment_type': 'wounding'}},
#  533: {'_key': 533,
#   '_value': {'project_id': '354', 'treatment_type': 'wounding'}},
#  534: {'_key': 534,
#   '_value': {'project_id': '354', 'treatment_type': 'wounding'}},
#  535: {'_key': 535,
#   '_value': {'project_id': '354', 'treatment_type': 'wounding'}},
#  536: {'_key': 536,
#   '_value': {'project_id': '354', 'treatment_type': 'wounding'}},
#  537: {'_key': 537,
#   '_value': {'project_id': '354', 'treatment_type': 'wounding'}},
#  538: {'_key': 538,
#   '_value': {'project_id': '354', 'treatment_type': 'wounding'}},
#  539: {'_key': 539,
#   '_value': {'project_id': '355', 'treatment_type': 'abiotic stress'}},
#  540: {'_key': 540,
#   '_value': {'project_id': '360', 'treatment_type': 'abiotic stress'}},
#  541: {'_key': 541,
#   '_value': {'project_id': '362',
#    'treatment_type': 'environmental treatment'}},
#  542: {'_key': 542,
#   '_value': {'project_id': '362',
#    'treatment_type': 'environmental treatment'}},
#  543: {'_key': 543,
#   '_value': {'project_id': '352',
#    'treatment_type': 'environmental treatment'}},
#  544: {'_key': 544,
#   '_value': {'project_id': '356',
#    'treatment_type': 'compound based treatment'}},
#  545: {'_key': 545,
#   '_value': {'project_id': '356',
#    'treatment_type': 'compound based treatment'}},
#  546: {'_key': 546,
#   '_value': {'project_id': '356',
#    'treatment_type': 'compound based treatment'}},
#  547: {'_key': 547,
#   '_value': {'project_id': '356',
#    'treatment_type': 'compound based treatment'}},
#  548: {'_key': 548,
#   '_value': {'project_id': '356',
#    'treatment_type': 'compound based treatment'}},
#  549: {'_key': 549,
#   '_value': {'project_id': '356',
#    'treatment_type': 'compound based treatment'}},
#  550: {'_key': 550,
#   '_value': {'project_id': '356',
#    'treatment_type': 'compound based treatment'}},
#  551: {'_key': 551,
#   '_value': {'project_id': '356',
#    'treatment_type': 'compound based treatment'}},
#  552: {'_key': 552,
#   '_value': {'project_id': '356',
#    'treatment_type': 'compound based treatment'}},
#  553: {'_key': 553,
#   '_value': {'project_id': '356',
#    'treatment_type': 'compound based treatment'}},
#  554: {'_key': 554,
#   '_value': {'project_id': '356',
#    'treatment_type': 'compound based treatment'}},
#  555: {'_key': 555,
#   '_value': {'project_id': '364',
#    'treatment_type': 'compound based treatment'}},
#  556: {'_key': 556,
#   '_value': {'project_id': '364',
#    'treatment_type': 'compound based treatment'}},
#  557: {'_key': 557,
#   '_value': {'project_id': '364',
#    'treatment_type': 'compound based treatment'}},
#  558: {'_key': 558,
#   '_value': {'project_id': '364',
#    'treatment_type': 'compound based treatment'}},
#  559: {'_key': 559,
#   '_value': {'project_id': '372',
#    'treatment_type': 'environmental treatment'}},
#  560: {'_key': 560,
#   '_value': {'project_id': '366', 'treatment_type': 'time course study'}},
#  561: {'_key': 561,
#   '_value': {'project_id': '366', 'treatment_type': 'time course study'}},
#  562: {'_key': 562,
#   '_value': {'project_id': '366', 'treatment_type': 'time course study'}},
#  563: {'_key': 563,
#   '_value': {'project_id': '366', 'treatment_type': 'time course study'}},
#  564: {'_key': 564,
#   '_value': {'project_id': '372',
#    'treatment_type': 'environmental treatment'}},
#  565: {'_key': 565,
#   '_value': {'project_id': '374',
#    'treatment_type': 'environmental treatment'}},
#  566: {'_key': 566,
#   '_value': {'project_id': '376',
#    'treatment_type': 'environmental treatment'}},
#  567: {'_key': 567,
#   '_value': {'project_id': '377',
#    'treatment_type': 'environmental treatment'}},
#  568: {'_key': 568,
#   '_value': {'project_id': '377',
#    'treatment_type': 'environmental treatment'}},
#  569: {'_key': 569,
#   '_value': {'project_id': '374',
#    'treatment_type': 'environmental treatment'}},
#  570: {'_key': 570,
#   '_value': {'project_id': '374',
#    'treatment_type': 'environmental treatment'}},
#  571: {'_key': 571,
#   '_value': {'project_id': '386', 'treatment_type': 'time course study'}},
#  572: {'_key': 572,
#   '_value': {'project_id': '386', 'treatment_type': 'time course study'}},
#  573: {'_key': 573,
#   '_value': {'project_id': '386', 'treatment_type': 'time course study'}},
#  574: {'_key': 574,
#   '_value': {'project_id': '389',
#    'treatment_type': 'compound based treatment'}},
#  575: {'_key': 575,
#   '_value': {'project_id': '389',
#    'treatment_type': 'compound based treatment'}},
#  576: {'_key': 576,
#   '_value': {'project_id': '389',
#    'treatment_type': 'compound based treatment'}},
#  577: {'_key': 577,
#   '_value': {'project_id': '389',
#    'treatment_type': 'compound based treatment'}},
#  578: {'_key': 578,
#   '_value': {'project_id': '380',
#    'treatment_type': 'compound based treatment'}},
#  579: {'_key': 579,
#   '_value': {'project_id': '397',
#    'treatment_type': 'environmental treatment'}},
#  580: {'_key': 580,
#   '_value': {'project_id': '397',
#    'treatment_type': 'environmental treatment'}},
#  581: {'_key': 581,
#   '_value': {'project_id': '374',
#    'treatment_type': 'environmental treatment'}},
#  582: {'_key': 582,
#   '_value': {'project_id': '400', 'treatment_type': 'abiotic stress'}},
#  583: {'_key': 583,
#   '_value': {'project_id': '400', 'treatment_type': 'abiotic stress'}},
#  584: {'_key': 584,
#   '_value': {'project_id': '400', 'treatment_type': 'abiotic stress'}},
#  585: {'_key': 585,
#   '_value': {'project_id': '400', 'treatment_type': 'abiotic stress'}},
#  586: {'_key': 586,
#   '_value': {'project_id': '403',
#    'treatment_type': 'environmental treatment'}},
#  587: {'_key': 587,
#   '_value': {'project_id': '402',
#    'treatment_type': 'environmental treatment'}},
#  588: {'_key': 588,
#   '_value': {'project_id': '402',
#    'treatment_type': 'environmental treatment'}},
#  589: {'_key': 589,
#   '_value': {'project_id': '402',
#    'treatment_type': 'environmental treatment'}},
#  590: {'_key': 590,
#   '_value': {'project_id': '402',
#    'treatment_type': 'environmental treatment'}},
#  591: {'_key': 591,
#   '_value': {'project_id': '405',
#    'treatment_type': 'compound based treatment'}},
#  592: {'_key': 592,
#   '_value': {'project_id': '405',
#    'treatment_type': 'compound based treatment'}},
#  593: {'_key': 593,
#   '_value': {'project_id': '407', 'treatment_type': 'iron deficiency'}},
#  594: {'_key': 594,
#   '_value': {'project_id': '407', 'treatment_type': 'iron sufficiency'}},
#  595: {'_key': 595,
#   '_value': {'project_id': '405',
#    'treatment_type': 'compound based treatment'}},
#  596: {'_key': 596,
#   '_value': {'project_id': '405',
#    'treatment_type': 'compound based treatment'}},
#  597: {'_key': 597,
#   '_value': {'project_id': '406',
#    'treatment_type': 'compound based treatment'}},
#  598: {'_key': 598,
#   '_value': {'project_id': '406',
#    'treatment_type': 'compound based treatment'}},
#  599: {'_key': 599,
#   '_value': {'project_id': '412',
#    'treatment_type': 'environmental treatment'}},
#  600: {'_key': 600,
#   '_value': {'project_id': '415', 'treatment_type': 'abiotic stress'}},
#  601: {'_key': 601,
#   '_value': {'project_id': '416',
#    'treatment_type': 'compound based treatment'}},
#  602: {'_key': 602,
#   '_value': {'project_id': '416',
#    'treatment_type': 'compound based treatment'}},
#  603: {'_key': 603,
#   '_value': {'project_id': '418',
#    'treatment_type': 'compound based treatment'}},
#  604: {'_key': 604,
#   '_value': {'project_id': '423', 'treatment_type': 'time course study'}},
#  605: {'_key': 605,
#   '_value': {'project_id': '370', 'treatment_type': 'time course study'}},
#  606: {'_key': 606,
#   '_value': {'project_id': '346', 'treatment_type': 'time course study'}},
#  607: {'_key': 607,
#   '_value': {'project_id': '423', 'treatment_type': 'time course study'}},
#  608: {'_key': 608,
#   '_value': {'project_id': '442',
#    'treatment_type': 'environmental treatment'}},
#  609: {'_key': 609,
#   '_value': {'project_id': '444',
#    'treatment_type': 'environmental treatment'}},
#  610: {'_key': 610,
#   '_value': {'project_id': '444',
#    'treatment_type': 'environmental treatment'}},
#  611: {'_key': 611,
#   '_value': {'project_id': '451',
#    'treatment_type': 'environmental treatment'}},
#  612: {'_key': 612,
#   '_value': {'project_id': '451',
#    'treatment_type': 'environmental treatment'}}}

# %%
def reference_table():
    dat=dict()
    data=read_data_sql('SELECT conname,pg_catalog.pg_get_constraintdef(r.oid, true) as condef FROM pg_catalog.pg_constraint r;','')
    for key in data.keys():
        if data[key]['_value']['condef'][0:7]=='FOREIGN':
            list_key=[]
            for elemnt in data[key]['_value']['condef'].split('(')[1].split(' '):
                list_key.append(elemnt.replace(')',''))
            dat[data[key]['_value']['conname']]=list_key
    return dat
def recherche_table(col_schear):
    data=read_data_sql("select  constraint_name,column_name from information_schema.key_column_usage where constraint_catalog=current_catalog and table_name='"+col_schear+"' and position_in_unique_constraint notnull;",'')
    return data
ref=reference_table()

# %%
#ref['imagedata_pojectid_fk'][2]
# Python program to print all paths from a source to destination. 
   
from collections import defaultdict 

class Graph: 
   
    def __init__(self,vertices): 
        #No. of vertices 
        self.V= vertices  
          
        # default dictionary to store graph 
        self.graph = defaultdict(list)  
   
    # function to add an edge to graph 
    def addEdge(self,u,v): 
        self.graph[u].append(v) 
   
    ''''''
    def printAllPathsUtil(self, u, d, visited, path): 
        # Mark the current node as visited and store in path 
        visited[u]= True
        path.append(u) 
        # If current vertex is same as destination, then print 
        # current path[] 
        if u ==d: 
            print(path) 
        else: 
            # If current vertex is not destination 
            #Recur for all the vertices adjacent to this vertex 
            for i in self.graph[u]: 
                if visited[i]==False: 
                    self.printAllPathsUtil(i, d, visited, path) 
        # Remove current vertex from path[] and mark it as unvisited 
        path.pop() 
        visited[u]= False
    # Prints all paths from 's' to 'd' 
    def printAllPaths(self,s, d): 
        # Mark all the vertices as not visited 
        visited =[False]*(self.V) 
        # Create an array to store paths 
        path = [] 

        self.printAllPathsUtil(s, d,visited, path)
# Create a graph given in the above diagram 
def initialgraph():
    data=read_data_sql("SELECT table_name FROM information_schema.tables WHERE table_schema='chips';","")
    list_noeud=dict()
    for key in data.keys():
        list_noeud[data[key]['_value']['table_name']]=data[key]['_key']
    g = Graph(len(list_noeud))
    for key in list_noeud.keys():
        current_data=recherche_table(key)
        for key_2 in current_data.keys():
            try:
                key_A=list_noeud[key]
                key_B=list_noeud[ref[current_data[key_2]['_value']['constraint_name']][2].split('.')[1]]
                g.addEdge(key_A,key_B)
                g.addEdge(key_B,key_A)
            except:
                pass
    return g.graph,list_noeud
def find_path(graph, start, end, path=[]):
        path = path + [start]
        if start == end:
            return path
        if start not in graph.keys():
            return None
        for node in graph[start]:
            if node not in path:
                newpath = find_path(graph, node, end, path)
                if newpath: return newpath
        return None
def find_all_paths(graph, start, end, path=[]):
        path = path + [start]
        if start == end:
            return [path]
        if start not in graph.keys():
            return []
        paths = []
        for node in graph[start]:
            if node not in path:
                newpaths = find_all_paths(graph, node, end, path)
                for newpath in newpaths:
                    paths.append(newpath)
        return paths
def find_shortest_path(graph, start, end, path=[]):
        path = path + [start]
        if start == end:
            return path
        if start not in graph.keys():
            return None
        shortest = None
        for node in graph[start]:
            if node not in path:
                newpath = find_shortest_path(graph, node, end, path)
                if newpath:
                    if not shortest or len(newpath) < len(shortest):
                        shortest = newpath
        return shortest

# %%
g,list_noeud=initialgraph()

# %%
s,t="project","experiment"
for key in find_shortest_path(dict(g),list_noeud[t],list_noeud[s], path=[]):
    for key1 in list_noeud.keys():
        if key==list_noeud[key1]:
            print(key1)
# Out:
# experiment
# project

# %%
list_noeud
# Out:
# {'annotation_gene': 26,
#  'annotation_spot': 62,
#  'antibody_name_list': 3,
#  'antibody_ref_list': 7,
#  'array': 27,
#  'array_batch': 28,
#  'array_type': 29,
#  'biblio_list': 16,
#  'calculated_value': 1,
#  'chip_analysis_value': 30,
#  'contact': 37,
#  'control_type_list': 6,
#  'dev_stage_list': 2,
#  'diff_analysis_value': 8,
#  'ecotype': 4,
#  'exp_factor_list': 9,
#  'exp_type_list': 5,
#  'experiment': 39,
#  'extract': 49,
#  'extract_pool': 43,
#  'factor_list': 63,
#  'hybrid_imagedata': 44,
#  'hybrid_labelled_extract': 45,
#  'hybrid_replicats': 57,
#  'hybridization': 46,
#  'image_data_file': 47,
#  'info_catdbindex': 18,
#  'ip': 50,
#  'ip_experiment': 38,
#  'label_name_list': 10,
#  'labelled_extract': 51,
#  'labelled_protocol': 58,
#  'link_replicats': 59,
#  'link_url': 19,
#  'max_value_id': 11,
#  'method_scan_analysis_list': 21,
#  'molecule_type_list': 12,
#  'mutation_type_list': 64,
#  'operator': 35,
#  'organ_list': 17,
#  'organism': 20,
#  'organism_ecotype': 13,
#  'project': 52,
#  'project_biblio': 48,
#  'project_coordinator': 53,
#  'project_source_list': 22,
#  'protocol': 60,
#  'raw_value': 33,
#  'replicats': 61,
#  'rnaseqdata': 31,
#  'rnaseqlibrary': 32,
#  'sample': 40,
#  'sample_extract': 54,
#  'sample_source': 41,
#  'sample_treated': 42,
#  'scananalysis_protocol': 36,
#  'spot': 34,
#  'spot_gene': 65,
#  'spotted_primer': 66,
#  'spotted_sequence': 67,
#  'stat_analysis': 55,
#  'stat_diff_analysis': 68,
#  'stat_param': 23,
#  'stat_param_list': 24,
#  'stat_protocol': 56,
#  'treatment': 69,
#  'treatment_factor_list': 14,
#  'treatment_type_list': 25,
#  'unit_list': 15}

# %%
find_path(dict(g),list_noeud[t],list_noeud[s], path=[])

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-140-ebf9e454483d> in <module>()
# ----> 1 data.has_key(14)
#
# AttributeError: 'dict' object has no attribute 'has_key'
