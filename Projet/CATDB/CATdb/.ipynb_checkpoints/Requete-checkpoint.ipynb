# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
from django.db import models
# Create your models here.

import psycopg2
#from config import config
from django.test.html import Element
import os

import os

from configparser import ConfigParser


def config(section='postgresql'):
    if os.getcwd()[0:12]!="/home/traore":
    	filename=os.getcwd()+'/database.ini'
    else:
    	filename=os.getcwd()+'/database2.ini'
    # create a parser
    parser = ConfigParser()
    # read config file
    parser.read(filename)
    # get section, default to postgresql
    db = {}
    if parser.has_section(section):
        params = parser.items(section)
        for param in params:
            db[param[0]] = param[1]
    else:
        raise Exception('Section {0} not found in the {1} file'.format(section, filename))
 
    return db




def connect():
    """ Connect to the PostgreSQL database server """
    conn = None
    try:
        # read connection parameters
        params = config()
        # connect to the PostgreSQL server
        print('Connecting to the PostgreSQL database...')
        conn = psycopg2.connect(**params)
        # create a cursor
        cur = conn.cursor()
        # execute a statement
        print('PostgreSQL database version:')
        cur.execute('SELECT version()')
        # display the PostgreSQL database server version
        db_version = cur.fetchone()
        print(db_version)
     # close the communication with the PostgreSQL
        cur.close()
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
    finally:
        if conn is not None:
            conn.close()
            print('Database connection closed.')


def read_data_sql(requete,element):
    """
    input requete outupt data
    requete='select * from chips.experiment;'
    """
    conn = None
    params = config()
    conn = psycopg2.connect(**params)
    cursor = conn.cursor()#cursor_factory=psycopg2.extras.DictCursor
    cursor.execute(requete)
    colnames = [desc[0] for desc in cursor.description]
    memory = cursor.fetchall()
    conn.close()
    cpt=0
    data=dict()
    for ele in range(len(memory)):
        cpt=cpt+1
        col=[]
        for ele1 in memory[ele]:
            col.append(str(ele1))
        dictionary ={'_key':cpt,"_value":dict(zip(colnames,col))}
        data[cpt]=dictionary
    name=element+'.csv'     
    return data

def lecture_query_tage(file_query):
    """
    function sert a lire les requetes prédefinir seulement
    """
    query_tag=dict()
    with open(file_query,"r") as fiche:
        data=fiche.readlines()
        for line in data:
            if line[0]!="#":
                if line[0:9]=="Tag_query":
                    _key=line[11:].replace('\n','').replace('"','')
                elif line[0:5]=="query":
                    query_tag[_key]=(line[6:].replace('\n','').replace('"',''))            
    return query_tag


repertoire_requete=lecture_query_tage(os.getcwd()+'/query_tag.ini')

def execution_requete(element,value_send,colname_send,order_ele=None):
    ### parametres
    if os.getcwd()[0:12]!="/home/traore":
    	my_ppty="chips"
    else:
    	my_ppty="public" #CHIPS

   
    # creation/tri des infos :(creation de structures de données)
    ###Todo
    
    # Bilan Chiffres nbr de puces par especes
    # pas Arabidopsis dans nouveau champ common_name d'array_type et 
    # analysis_type='Arrays'
    # partie requete
    my_querySpecies="select array_type_name, count(hybridization_id) "+\
    "from "+my_ppty+".hybridization "+\
    "where project_id in (select project_id from "+my_ppty+".project where is_public='yes') "+\
    "and experiment_id in (select experiment_id from "+my_ppty+".experiment "+\
    "where analysis_type='Arrays') "+\
    "and array_type_name in "+\
    "(select a.array_type_name from "+my_ppty+".array_type a where a.common_name<>'Arabidopsis')"+\
    "group by array_type_name order by array_type_name;"
    
    #Pour le nombre de ref biblio
    my_reqstat ="Select count(*) from "+my_ppty+".biblio_list;"
    
    
    #my_req_special="select o.organism_name,count(distinct ss.project_id) from "+my_ppty+".sample_source ss,"+my_ppty+".organism o where ss.project_id in( select project_id from "+my_ppty+".project where is_public='yes')  group by o.organism_name;"
    my_req_special="select o.organism_name,count(distinct ss.project_id) from "+my_ppty+".sample_source ss,"+my_ppty+".organism o where ss.project_id in( select project_id from "+my_ppty+".project ) and ss.organism_id=o.organism_id group by o.organism_name;" #where is_public='yes'
    
    my_req_recherche="SELECT * FROM global_search_element('Arabidopsis',param_schemas:=array['chips']);"
    
    my_req_recherche1="select project_id,Experiment_type,Experiment_name from "+my_ppty+".experiment where project_id in (select project_id from "+my_ppty+".project where is_public='yes');"
    
    #experiement="select * from chips.experiment where project_id in (select project_id from chips.project where is_public='yes'));"
    
    experiement="select * from (select S.project_name,O.project_id,O.experiment_name,O.experiment_type from "+my_ppty+".experiment O,"+my_ppty+".project S where O.project_id in (select project_id from "+my_ppty+".project where is_public='yes')) df limit 100;"
    
    
    try:
        my_req_recherche_av="select * from "+colname_send+" where (is_public='yes' and project_name like '%"+value_send+"%');"
    except:
        pass
    if element=='my_reqinfo':
        requete=my_reqinfo
    elif element=='my_querySpecies':
        requete=my_querySpecies
    elif element=='my_reqstat':
        requete=my_reqstat    
    elif element=='my_req_special':
        requete=my_req_special    
    elif element=='my_req_recherche':
        requete=my_req_recherche        
    elif element=='my_req_recherche_av' and colname_send!=None and value_send!=None:
        requete=my_req_recherche_av     
    elif element=='my_req_recherche1':
        requete=my_req_recherche1
    elif element=='experiement':
        requete=experiement  
    elif (element=='get_project' or element=='get_contact' or element=='my_experience' or 'my_treatment' or 'list_project' or 'type_analysis' or 'type_arrays' or 'all_experiment'):
        requete=repertoire_requete[element].replace('schema.',my_ppty+'.')
        if value_send!=None:
            requete=requete.replace('value_send',value_send)
        else:
            requete=requete
        print(requete)
    else:
        try:
            requete=eval(element)
        except:
            requete=None
            pass
    
    my_req_special="select o.organism_name,count(distinct ss.project_id) from "+my_ppty+".sample_source ss,"+my_ppty+".organism o where ss.project_id in( select project_id from "+my_ppty+".project where is_public='yes') and ss.organism_id=o.organism_id group by o.organism_name;"
    
    
    
    if  element=='my_req_special' and order_ele==None:
         requete=my_req_special  
    elif element=='my_req_special' and order_ele!=None:    
        requete="select * from ("+requete.replace(";",')')+' dfg order by dfg.'+order_ele+";"
    elif  element=='my_querySpecies' and order_ele==None:
         requete=my_querySpecies  
    elif element=='my_querySpecies' and order_ele!=None:    
        requete="select * from ("+requete.replace(";",')')+' dfg order by dfg.'+order_ele+";"
    elif  element=='my_req_recherche1' and order_ele==None:
         requete=my_req_recherche1  
    elif element=='my_req_recherche1' and order_ele!=None:    
        requete="select * from ("+requete.replace(";",')')+' dfg order by dfg.'+order_ele+";"
    if requete!=None:
        return read_data_sql(requete,element)    
    else:
        print("error") 

# def execution_requete_new(element,value_send,colname_send,order_by):
#     """
#     fonction faite pour envoyer des orders by
#     """
#     my_ppty="CHIPS"
#     
#     my_querySpecies="select * from (select array_type_name, count(hybridization_id) "+\
#     "from "+my_ppty+".hybridization "+\
#     "where project_id in (select project_id from "+my_ppty+".project where is_public='yes') "+\
#     "and experiment_id in (select experiment_id from "+my_ppty+".experiment "+\
#     "where analysis_type='Arrays') "+\
#     "and array_type_name in "+\
#     "(select a.array_type_name from "+my_ppty+".array_type a where a.common_name<>'Arabidopsis')"+\
#     "group by array_type_name order by array_type_name) pf order by pf."+order_by+";"
#     #my_req_recherche1="select project_id,Experiment_type,Experiment_name from chips.experiment where project_id in (select project_id from chips.project where is_public='yes');"
#     return read_data_sql(my_querySpecies,'text')    
#     
# 
# def execution_requete_main_A(element,value_send,colname_send):
#     my_ppty='CHIPS'
#     my_reqstat ="Select count(*) from "+my_ppty+".biblio_list;"
# #    
#    my_sample="SELECT sample.sample_name, sample.organ, sample.age_value, sample.age_unit, sample.age_db FROM "+my_ppty+".sample, "+my_ppty+".project WHERE project.project_id = sample.project_id AND project.is_public = 'yes';"
#    
#    my_sample_source="SELECT sample_source.project_id,sample_source.sample_source_name,organism.organism_name,sample_source.genotype,sample_source.mutant, sample_source.planting_date FROM "+my_ppty+".sample_source, "+my_ppty+".project , "+my_ppty+".organism, "+my_ppty+".Ecotype WHERE project.project_id=sample_source.project_id and project.is_public = 'yes' and Ecotype.ecotype_id=CAST(nullif(sample_source.ecotype_id, '') AS integer);"
#
#    requete=my_sample_source
#    if colname_send!=None:
#    	requete="select * from ("+requete.replace(';','')+") df order by "+colname_send+";" 
#    return read_data_sql(requete,element)

# %%
data=execution_requete('treatment_list','','')
# Out:
# select treatment_type,treatment.project_id from public.treatment,public.project where project.project_id=treatment.project_id and project.Is_public='yes';

# %%
data_comp={}
for i in data.keys():
    key=list(data[i]['_value'].keys())
    key=['project_id','treatment_type']
    try:
            key_compt=data[i]['_value'][key[1]].split(',')
            for element in key_compt:
                if element not in data_comp:
                    data_comp[element]=[data[i]['_value'][key[0]]]
                else:
                    current=data_comp[element]
                    current.append(data[i]['_value'][key[0]])
                    data_comp[element]=current       
    except:
        pass

# %%
data_save=[]
for el in data_comp.keys():
    data_save.append({'experiment_type':el,'count':len(data_comp[el]),'project_id':data_comp[el]})

# %%
data_save
# Out:
# [{'experiment_type': '1',
#   'count': 1,
#   'project_id': ['environmental treatment']},
#  {'experiment_type': '0',
#   'count': 2,
#   'project_id': ['environmental treatment', 'environmental treatment']},
#  {'experiment_type': '10',
#   'count': 2,
#   'project_id': ['environmental treatment', 'environmental treatment']},
#  {'experiment_type': '15',
#   'count': 1,
#   'project_id': ['environmental treatment']},
#  {'experiment_type': '221',
#   'count': 2,
#   'project_id': ['pathogen', 'pathogen']},
#  {'experiment_type': '14',
#   'count': 4,
#   'project_id': ['compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment']},
#  {'experiment_type': '19',
#   'count': 1,
#   'project_id': ['environmental treatment']},
#  {'experiment_type': '25',
#   'count': 2,
#   'project_id': ['pathogen', 'control buffer']},
#  {'experiment_type': '29',
#   'count': 1,
#   'project_id': ['environmental treatment']},
#  {'experiment_type': '32',
#   'count': 1,
#   'project_id': ['compound based treatment']},
#  {'experiment_type': '23',
#   'count': 1,
#   'project_id': ['compound based treatment']},
#  {'experiment_type': '34', 'count': 1, 'project_id': ['growth conditions']},
#  {'experiment_type': '36',
#   'count': 5,
#   'project_id': ['biotic stress',
#    'biotic stress',
#    'biotic stress',
#    'biotic stress',
#    'biotic stress']},
#  {'experiment_type': '37',
#   'count': 8,
#   'project_id': ['environmental treatment',
#    'environmental treatment',
#    'environmental treatment',
#    'genetic treatment',
#    'environmental treatment',
#    'environmental treatment',
#    'environmental treatment',
#    'genetic treatment']},
#  {'experiment_type': '38',
#   'count': 1,
#   'project_id': ['environmental treatment']},
#  {'experiment_type': '40',
#   'count': 1,
#   'project_id': ['compound based treatment']},
#  {'experiment_type': '79',
#   'count': 4,
#   'project_id': ['compound based treatment',
#    'compound based treatment',
#    'control buffer',
#    'compound based treatment']},
#  {'experiment_type': '41',
#   'count': 1,
#   'project_id': ['environmental treatment']},
#  {'experiment_type': '107',
#   'count': 6,
#   'project_id': ['compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment']},
#  {'experiment_type': '42',
#   'count': 3,
#   'project_id': ['environmental treatment',
#    'environmental treatment',
#    'environmental treatment']},
#  {'experiment_type': '43',
#   'count': 8,
#   'project_id': ['environmental treatment',
#    'environmental treatment',
#    'environmental treatment',
#    'environmental treatment',
#    'environmental treatment',
#    'environmental treatment',
#    'environmental treatment',
#    'control buffer']},
#  {'experiment_type': '44',
#   'count': 2,
#   'project_id': ['time course study', 'time course study']},
#  {'experiment_type': '45',
#   'count': 4,
#   'project_id': ['compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment']},
#  {'experiment_type': '48',
#   'count': 11,
#   'project_id': ['compound based treatment',
#    'biotic stress',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'growth conditions',
#    'compound based treatment',
#    'compound based treatment',
#    'biotic stress',
#    'biotic stress']},
#  {'experiment_type': '50',
#   'count': 8,
#   'project_id': ['compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment']},
#  {'experiment_type': '142',
#   'count': 3,
#   'project_id': ['compound based treatment',
#    'compound based treatment',
#    'abiotic stress']},
#  {'experiment_type': '51',
#   'count': 4,
#   'project_id': ['compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment']},
#  {'experiment_type': '58',
#   'count': 2,
#   'project_id': ['environmental treatment', 'environmental treatment']},
#  {'experiment_type': '59',
#   'count': 8,
#   'project_id': ['compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment']},
#  {'experiment_type': '200',
#   'count': 2,
#   'project_id': ['hormone treatment,biotic stress', 'control']},
#  {'experiment_type': '212',
#   'count': 2,
#   'project_id': ['pathogen', 'pathogen']},
#  {'experiment_type': '244', 'count': 1, 'project_id': ['technical']},
#  {'experiment_type': '63',
#   'count': 1,
#   'project_id': ['environmental treatment']},
#  {'experiment_type': '64',
#   'count': 6,
#   'project_id': ['compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment']},
#  {'experiment_type': '69',
#   'count': 7,
#   'project_id': ['control buffer',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment']},
#  {'experiment_type': '78',
#   'count': 4,
#   'project_id': ['compound+pathogen',
#    'compound based treatment',
#    'compound based treatment',
#    'compound+pathogen,pathogen']},
#  {'experiment_type': '49',
#   'count': 4,
#   'project_id': ['environmental treatment',
#    'environmental treatment',
#    'environmental treatment',
#    'environmental treatment']},
#  {'experiment_type': '246',
#   'count': 2,
#   'project_id': ['biotic stress', 'biotic stress']},
#  {'experiment_type': '71',
#   'count': 5,
#   'project_id': ['compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment']},
#  {'experiment_type': '60',
#   'count': 6,
#   'project_id': ['abiotic stress',
#    'abiotic stress',
#    'biotic stress',
#    'biotic stress',
#    'biotic stress',
#    'biotic stress']},
#  {'experiment_type': '77',
#   'count': 3,
#   'project_id': ['abiotic stress', 'abiotic stress', 'abiotic stress']},
#  {'experiment_type': '76',
#   'count': 2,
#   'project_id': ['abiotic stress', 'abiotic stress']},
#  {'experiment_type': '82',
#   'count': 1,
#   'project_id': ['environmental treatment']},
#  {'experiment_type': '86', 'count': 1, 'project_id': ['abiotic stress']},
#  {'experiment_type': '87',
#   'count': 4,
#   'project_id': ['abiotic stress',
#    'abiotic stress',
#    'abiotic stress',
#    'abiotic stress']},
#  {'experiment_type': '88',
#   'count': 1,
#   'project_id': ['compound based treatment']},
#  {'experiment_type': '92',
#   'count': 3,
#   'project_id': ['compound based treatment',
#    'compound based treatment',
#    'compound based treatment']},
#  {'experiment_type': '100',
#   'count': 2,
#   'project_id': ['pathogen', 'control buffer']},
#  {'experiment_type': '102',
#   'count': 2,
#   'project_id': ['environmental treatment', 'environmental treatment']},
#  {'experiment_type': '104',
#   'count': 2,
#   'project_id': ['environmental treatment', 'environmental treatment']},
#  {'experiment_type': '103',
#   'count': 13,
#   'project_id': ['growth conditions',
#    'growth conditions',
#    'growth conditions',
#    'growth conditions',
#    'growth conditions',
#    'growth conditions',
#    'growth conditions',
#    'growth conditions',
#    'growth conditions',
#    'growth conditions',
#    'growth conditions',
#    'growth conditions',
#    'growth conditions']},
#  {'experiment_type': '132',
#   'count': 9,
#   'project_id': ['growth conditions',
#    'growth conditions',
#    'growth conditions',
#    'growth conditions',
#    'growth conditions',
#    'growth conditions',
#    'growth conditions',
#    'growth conditions',
#    'growth conditions']},
#  {'experiment_type': '106',
#   'count': 1,
#   'project_id': ['environmental treatment']},
#  {'experiment_type': '108',
#   'count': 4,
#   'project_id': ['compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment']},
#  {'experiment_type': '111', 'count': 1, 'project_id': ['abiotic stress']},
#  {'experiment_type': '112',
#   'count': 1,
#   'project_id': ['compound based treatment']},
#  {'experiment_type': '145',
#   'count': 3,
#   'project_id': ['compound based treatment',
#    'compound based treatment',
#    'compound based treatment']},
#  {'experiment_type': '114',
#   'count': 1,
#   'project_id': ['compound based treatment']},
#  {'experiment_type': '119',
#   'count': 6,
#   'project_id': ['environmental treatment',
#    'environmental treatment',
#    'environmental treatment',
#    'environmental treatment',
#    'environmental treatment',
#    'environmental treatment']},
#  {'experiment_type': '113',
#   'count': 3,
#   'project_id': ['biotic stress',
#    'environmental treatment',
#    'environmental treatment']},
#  {'experiment_type': '121',
#   'count': 3,
#   'project_id': ['genetic treatment',
#    'compound based treatment',
#    'compound based treatment']},
#  {'experiment_type': '198',
#   'count': 6,
#   'project_id': ['environmental treatment',
#    'environmental treatment',
#    'environmental treatment',
#    'environmental treatment',
#    'environmental treatment',
#    'environmental treatment']},
#  {'experiment_type': '123',
#   'count': 2,
#   'project_id': ['environmental treatment', 'environmental treatment']},
#  {'experiment_type': '124',
#   'count': 2,
#   'project_id': ['time course study', 'time course study']},
#  {'experiment_type': '97',
#   'count': 8,
#   'project_id': ['abiotic stress',
#    'abiotic stress',
#    'abiotic stress',
#    'control buffer',
#    'control buffer',
#    'control buffer',
#    'control buffer',
#    'control buffer']},
#  {'experiment_type': '126',
#   'count': 4,
#   'project_id': ['control buffer',
#    'environmental treatment',
#    'environmental treatment',
#    'environmental treatment']},
#  {'experiment_type': '129',
#   'count': 1,
#   'project_id': ['environmental treatment']},
#  {'experiment_type': '131',
#   'count': 8,
#   'project_id': ['compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment']},
#  {'experiment_type': '179',
#   'count': 4,
#   'project_id': ['compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment']},
#  {'experiment_type': '144',
#   'count': 3,
#   'project_id': ['environmental treatment',
#    'environmental treatment',
#    'environmental treatment']},
#  {'experiment_type': '303',
#   'count': 3,
#   'project_id': ['environmental treatment',
#    'environmental treatment',
#    'environmental treatment']},
#  {'experiment_type': '130',
#   'count': 1,
#   'project_id': ['compound based treatment']},
#  {'experiment_type': '133',
#   'count': 2,
#   'project_id': ['pathogen', 'pathogen']},
#  {'experiment_type': '105',
#   'count': 1,
#   'project_id': ['compound based treatment']},
#  {'experiment_type': '117',
#   'count': 6,
#   'project_id': ['growth conditions',
#    'growth conditions',
#    'growth conditions',
#    'growth conditions',
#    'growth conditions',
#    'growth conditions']},
#  {'experiment_type': '118',
#   'count': 4,
#   'project_id': ['pathogen', 'control buffer', 'pathogen', 'pathogen']},
#  {'experiment_type': '149',
#   'count': 4,
#   'project_id': ['environmental treatment',
#    'environmental treatment',
#    'environmental treatment',
#    'environmental treatment']},
#  {'experiment_type': '147', 'count': 1, 'project_id': ['genetic treatment']},
#  {'experiment_type': '148',
#   'count': 6,
#   'project_id': ['biotic stress',
#    'biotic stress',
#    'control buffer',
#    'biotic stress',
#    'biotic stress',
#    'control buffer']},
#  {'experiment_type': '183',
#   'count': 2,
#   'project_id': ['growth conditions', 'growth conditions']},
#  {'experiment_type': '138',
#   'count': 1,
#   'project_id': ['environmental treatment']},
#  {'experiment_type': '165',
#   'count': 2,
#   'project_id': ['control buffer', 'abiotic stress']},
#  {'experiment_type': '161',
#   'count': 4,
#   'project_id': ['compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment']},
#  {'experiment_type': '160',
#   'count': 6,
#   'project_id': ['pathogen',
#    'pathogen',
#    'pathogen',
#    'pathogen',
#    'pathogen',
#    'pathogen']},
#  {'experiment_type': '61',
#   'count': 2,
#   'project_id': ['biotic stress', 'biotic stress']},
#  {'experiment_type': '146',
#   'count': 1,
#   'project_id': ['compound based treatment']},
#  {'experiment_type': '166', 'count': 1, 'project_id': ['gene induction']},
#  {'experiment_type': '168', 'count': 1, 'project_id': ['abiotic stress']},
#  {'experiment_type': '172', 'count': 1, 'project_id': ['abiotic stress']},
#  {'experiment_type': '154',
#   'count': 3,
#   'project_id': ['abiotic stress',
#    'environmental treatment',
#    'environmental treatment']},
#  {'experiment_type': '163',
#   'count': 1,
#   'project_id': ['environmental treatment']},
#  {'experiment_type': '186',
#   'count': 4,
#   'project_id': ['control buffer',
#    'control buffer',
#    'compound based treatment',
#    'compound based treatment']},
#  {'experiment_type': '197',
#   'count': 3,
#   'project_id': ['compound based treatment',
#    'compound based treatment',
#    'environmental treatment']},
#  {'experiment_type': '193',
#   'count': 6,
#   'project_id': ['compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'environmental treatment',
#    'control buffer',
#    'compound based treatment']},
#  {'experiment_type': '187', 'count': 1, 'project_id': ['abiotic stress']},
#  {'experiment_type': '188',
#   'count': 4,
#   'project_id': ['limited nitrogen supply',
#    'limited nitrogen supply',
#    'sufficient nitrogen supply',
#    'sufficient nitrogen supply']},
#  {'experiment_type': '335',
#   'count': 2,
#   'project_id': ['compound based treatment', 'compound based treatment']},
#  {'experiment_type': '180',
#   'count': 3,
#   'project_id': ['environmental treatment',
#    'environmental treatment',
#    'environmental treatment']},
#  {'experiment_type': '181',
#   'count': 1,
#   'project_id': ['environmental treatment']},
#  {'experiment_type': '210',
#   'count': 3,
#   'project_id': ['syringe-inoculation',
#    'syringe-inoculation',
#    'syringe-inoculation']},
#  {'experiment_type': '305',
#   'count': 3,
#   'project_id': ['induction', 'induction', 'induction']},
#  {'experiment_type': '199',
#   'count': 3,
#   'project_id': ['time course study',
#    'time course study',
#    'time course study']},
#  {'experiment_type': '201',
#   'count': 1,
#   'project_id': ['environmental treatment']},
#  {'experiment_type': '203',
#   'count': 2,
#   'project_id': ['abiotic stress', 'abiotic stress']},
#  {'experiment_type': '202',
#   'count': 5,
#   'project_id': ['control',
#    'abiotic stress',
#    'abiotic stress',
#    'abiotic stress',
#    'abiotic stress']},
#  {'experiment_type': '265',
#   'count': 9,
#   'project_id': ['environmental treatment',
#    'environmental treatment',
#    'control',
#    'control buffer',
#    'environmental treatment',
#    'environmental treatment',
#    'environmental treatment',
#    'environmental treatment',
#    'environmental treatment']},
#  {'experiment_type': '211',
#   'count': 1,
#   'project_id': ['environmental treatment']},
#  {'experiment_type': '234',
#   'count': 3,
#   'project_id': ['time course study',
#    'time course study',
#    'time course study']},
#  {'experiment_type': '216',
#   'count': 4,
#   'project_id': ['time course study',
#    'time course study',
#    'time course study',
#    'time course study']},
#  {'experiment_type': '233',
#   'count': 8,
#   'project_id': ['time course study',
#    'time course study',
#    'time course study',
#    'time course study',
#    'time course study',
#    'time course study',
#    'time course study',
#    'time course study']},
#  {'experiment_type': '331', 'count': 1, 'project_id': ['nothing']},
#  {'experiment_type': '16',
#   'count': 3,
#   'project_id': ['gene induction',
#    'environmental treatment',
#    'environmental treatment']},
#  {'experiment_type': '224',
#   'count': 4,
#   'project_id': ['biotic stress',
#    'biotic stress',
#    'control buffer',
#    'biotic stress']},
#  {'experiment_type': '231',
#   'count': 1,
#   'project_id': ['nematode inoculation']},
#  {'experiment_type': '230',
#   'count': 2,
#   'project_id': ['time course study', 'time course study']},
#  {'experiment_type': '238',
#   'count': 6,
#   'project_id': ['environmental treatment',
#    'environmental treatment',
#    'environmental treatment',
#    'environmental treatment',
#    'environmental treatment',
#    'environmental treatment']},
#  {'experiment_type': '222', 'count': 1, 'project_id': ['hormone treatment']},
#  {'experiment_type': '174',
#   'count': 4,
#   'project_id': ['compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment']},
#  {'experiment_type': '241', 'count': 1, 'project_id': ['inoculation']},
#  {'experiment_type': '248',
#   'count': 1,
#   'project_id': ['compound based treatment']},
#  {'experiment_type': '263',
#   'count': 4,
#   'project_id': ['inoculation',
#    'time course study',
#    'with euteiches,inoculation',
#    'inoculation']},
#  {'experiment_type': '261',
#   'count': 2,
#   'project_id': ['environmental treatment', 'environmental treatment']},
#  {'experiment_type': '62', 'count': 1, 'project_id': ['abiotic stress']},
#  {'experiment_type': '240',
#   'count': 4,
#   'project_id': ['pathogen', 'pathogen', 'pathogen', 'control']},
#  {'experiment_type': '259',
#   'count': 2,
#   'project_id': ['compound based treatment', 'compound based treatment']},
#  {'experiment_type': '266',
#   'count': 4,
#   'project_id': ['environmental treatment',
#    'environmental treatment',
#    'environmental treatment',
#    'environmental treatment']},
#  {'experiment_type': '288', 'count': 1, 'project_id': ['syringe-inoculation']},
#  {'experiment_type': '300',
#   'count': 5,
#   'project_id': ['time course study',
#    'time course study',
#    'time course study',
#    'time course study',
#    'time course study']},
#  {'experiment_type': '267',
#   'count': 1,
#   'project_id': ['compound based treatment']},
#  {'experiment_type': '270',
#   'count': 2,
#   'project_id': ['compound based treatment', 'compound based treatment']},
#  {'experiment_type': '271',
#   'count': 3,
#   'project_id': ['environmental treatment',
#    'environmental treatment',
#    'environmental treatment']},
#  {'experiment_type': '272',
#   'count': 2,
#   'project_id': ['environmental treatment', 'environmental treatment']},
#  {'experiment_type': '281',
#   'count': 1,
#   'project_id': ['inoculation with a. euteiches,time course study']},
#  {'experiment_type': '280',
#   'count': 2,
#   'project_id': ['biotic stress', 'biotic stress']},
#  {'experiment_type': '286',
#   'count': 10,
#   'project_id': ['compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment']},
#  {'experiment_type': '285',
#   'count': 5,
#   'project_id': ['environmental treatment',
#    'environmental treatment',
#    'environmental treatment',
#    'environmental treatment',
#    'environmental treatment']},
#  {'experiment_type': '313', 'count': 1, 'project_id': ['hormone treatment']},
#  {'experiment_type': '289',
#   'count': 2,
#   'project_id': ['compound based treatment', 'compound based treatment']},
#  {'experiment_type': '290',
#   'count': 3,
#   'project_id': ['environmental treatment',
#    'environmental treatment',
#    'environmental treatment']},
#  {'experiment_type': '307',
#   'count': 7,
#   'project_id': ['environmental treatment',
#    'environmental treatment',
#    'environmental treatment',
#    'environmental treatment',
#    'environmental treatment',
#    'environmental treatment',
#    'environmental treatment']},
#  {'experiment_type': '291',
#   'count': 2,
#   'project_id': ['abiotic stress', 'abiotic stress']},
#  {'experiment_type': '294',
#   'count': 4,
#   'project_id': ['environmental treatment',
#    'environmental treatment',
#    'environmental treatment',
#    'environmental treatment']},
#  {'experiment_type': '297', 'count': 1, 'project_id': ['induction']},
#  {'experiment_type': '298',
#   'count': 2,
#   'project_id': ['compound based treatment', 'compound based treatment']},
#  {'experiment_type': '301',
#   'count': 5,
#   'project_id': ['compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment']},
#  {'experiment_type': '299',
#   'count': 15,
#   'project_id': ['pathogen',
#    'pathogen',
#    'pathogen',
#    'pathogen',
#    'pathogen',
#    'pathogen',
#    'pathogen',
#    'pathogen',
#    'pathogen',
#    'pathogen',
#    'pathogen',
#    'pathogen',
#    'pathogen',
#    'pathogen',
#    'pathogen']},
#  {'experiment_type': '380',
#   'count': 1,
#   'project_id': ['compound based treatment']},
#  {'experiment_type': '356',
#   'count': 14,
#   'project_id': ['compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment']},
#  {'experiment_type': '308',
#   'count': 3,
#   'project_id': ['environmental treatment',
#    'environmental treatment',
#    'compound based treatment']},
#  {'experiment_type': '310',
#   'count': 4,
#   'project_id': ['environmental treatment',
#    'other inoculation ,environmental treatment',
#    'abiotic stress',
#    'other inoculation ,environmental treatment']},
#  {'experiment_type': '316',
#   'count': 4,
#   'project_id': ['compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment']},
#  {'experiment_type': '321',
#   'count': 6,
#   'project_id': ['storage -20°c',
#    'storage -20°c',
#    'storage -20°c',
#    'storage +20°c 2 mois',
#    'storage +20°c 2 mois',
#    'storage +20°c 2 mois']},
#  {'experiment_type': '320',
#   'count': 4,
#   'project_id': ['inoculation', 'infection', 'pathogen', 'inoculation']},
#  {'experiment_type': '332',
#   'count': 1,
#   'project_id': ['environmental treatment']},
#  {'experiment_type': '325',
#   'count': 9,
#   'project_id': ['compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment']},
#  {'experiment_type': '328',
#   'count': 2,
#   'project_id': ['environmental treatment', 'environmental treatment']},
#  {'experiment_type': '329',
#   'count': 3,
#   'project_id': ['nothing', 'nothing', 'nothing']},
#  {'experiment_type': '323',
#   'count': 2,
#   'project_id': ['inoculation with a. euteiches,environmental treatment',
#    'no treatment']},
#  {'experiment_type': '338', 'count': 1, 'project_id': ['abiotic stress']},
#  {'experiment_type': '339',
#   'count': 2,
#   'project_id': ['environmental treatment', 'environmental treatment']},
#  {'experiment_type': '341',
#   'count': 2,
#   'project_id': ['compound based treatment', 'compound based treatment']},
#  {'experiment_type': '343',
#   'count': 4,
#   'project_id': ['control',
#    'growth conditions',
#    'growth conditions',
#    'growth conditions']},
#  {'experiment_type': '344',
#   'count': 2,
#   'project_id': ['compound based treatment', 'compound based treatment']},
#  {'experiment_type': '351',
#   'count': 3,
#   'project_id': ['compound based treatment',
#    'compound based treatment',
#    'compound based treatment']},
#  {'experiment_type': '354',
#   'count': 7,
#   'project_id': ['wounding',
#    'wounding',
#    'wounding',
#    'wounding',
#    'wounding',
#    'wounding',
#    'wounding']},
#  {'experiment_type': '355', 'count': 1, 'project_id': ['abiotic stress']},
#  {'experiment_type': '360', 'count': 1, 'project_id': ['abiotic stress']},
#  {'experiment_type': '362',
#   'count': 2,
#   'project_id': ['environmental treatment', 'environmental treatment']},
#  {'experiment_type': '352',
#   'count': 1,
#   'project_id': ['environmental treatment']},
#  {'experiment_type': '364',
#   'count': 4,
#   'project_id': ['compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment']},
#  {'experiment_type': '372',
#   'count': 2,
#   'project_id': ['environmental treatment', 'environmental treatment']},
#  {'experiment_type': '366',
#   'count': 4,
#   'project_id': ['time course study',
#    'time course study',
#    'time course study',
#    'time course study']},
#  {'experiment_type': '374',
#   'count': 4,
#   'project_id': ['environmental treatment',
#    'environmental treatment',
#    'environmental treatment',
#    'environmental treatment']},
#  {'experiment_type': '376',
#   'count': 1,
#   'project_id': ['environmental treatment']},
#  {'experiment_type': '377',
#   'count': 2,
#   'project_id': ['environmental treatment', 'environmental treatment']},
#  {'experiment_type': '386',
#   'count': 3,
#   'project_id': ['time course study',
#    'time course study',
#    'time course study']},
#  {'experiment_type': '389',
#   'count': 4,
#   'project_id': ['compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment']},
#  {'experiment_type': '397',
#   'count': 2,
#   'project_id': ['environmental treatment', 'environmental treatment']},
#  {'experiment_type': '400',
#   'count': 4,
#   'project_id': ['abiotic stress',
#    'abiotic stress',
#    'abiotic stress',
#    'abiotic stress']},
#  {'experiment_type': '403',
#   'count': 1,
#   'project_id': ['environmental treatment']},
#  {'experiment_type': '402',
#   'count': 4,
#   'project_id': ['environmental treatment',
#    'environmental treatment',
#    'environmental treatment',
#    'environmental treatment']},
#  {'experiment_type': '405',
#   'count': 4,
#   'project_id': ['compound based treatment',
#    'compound based treatment',
#    'compound based treatment',
#    'compound based treatment']},
#  {'experiment_type': '407',
#   'count': 2,
#   'project_id': ['iron deficiency', 'iron sufficiency']},
#  {'experiment_type': '406',
#   'count': 2,
#   'project_id': ['compound based treatment', 'compound based treatment']},
#  {'experiment_type': '412',
#   'count': 1,
#   'project_id': ['environmental treatment']},
#  {'experiment_type': '415', 'count': 1, 'project_id': ['abiotic stress']},
#  {'experiment_type': '416',
#   'count': 2,
#   'project_id': ['compound based treatment', 'compound based treatment']},
#  {'experiment_type': '418',
#   'count': 1,
#   'project_id': ['compound based treatment']},
#  {'experiment_type': '423',
#   'count': 2,
#   'project_id': ['time course study', 'time course study']},
#  {'experiment_type': '370', 'count': 1, 'project_id': ['time course study']},
#  {'experiment_type': '346', 'count': 1, 'project_id': ['time course study']},
#  {'experiment_type': '442',
#   'count': 1,
#   'project_id': ['environmental treatment']},
#  {'experiment_type': '444',
#   'count': 2,
#   'project_id': ['environmental treatment', 'environmental treatment']},
#  {'experiment_type': '451',
#   'count': 2,
#   'project_id': ['environmental treatment', 'environmental treatment']}]

# %%
from IPython.display import display, Javascript, HTML
import json

# %%
# %%html
# <div id="d3-container"></div>
# <style>
# circle.node {stroke: #fff; stroke-width: 1.5px;}
# line.link {stroke: #999; stroke-opacity: .6;}
# </style>
# Out:
# <div id="d3-container"></div>
# <style>
# circle.node {stroke: #fff; stroke-width: 1.5px;}
# line.link {stroke: #999; stroke-opacity: .6;}
# </style>

# %%
# %%javascript
# require.config({
#     paths: {
#         d3: 'https://d3js.org/d3.v5.min'
#     }
# });
# (function(element) {
#     require(['d3'], function(d3) {
#
#        data = d3.csvParse('age,population
#     <5,2704659
#     5-13,4499890
#     14-17,2159981
#     18-24,3853788
#     25-44,14106543
#     45-64,8819342
#     ≥65,612463')
#
#         var svg = d3.select(element.get(0)).append('svg')
#
#
#
#     })
# })(element);

# %%
#Javascript(filename='circles.js')
# Out:
#   File "<ipython-input-53-f494f95e2ce3>", line 2
#     %%javascript
#     ^
# SyntaxError: invalid syntax
